# %%
import tensorflow as tf
from tensorflow.keras.metrics import *
from tensorflow.keras.layers import *
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.applications import *
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras.callbacks import *
from tensorflow.keras import backend as K
from hausdorff import hausdorff_distance
from tensorflow.keras.regularizers import l2

import os
import random
import numpy as np
from tqdm import tqdm
from skimage.io import imread,imshow
from skimage.morphology import label
from skimage.transform import resize
import matplotlib.pyplot as plt
import datetime

TRAIN_FLG = False

# %% [markdown]
# # Dataset

# %%
import os, shutil, random
from pathlib import Path

SRC = Path("BUSIS")           # your Kaggle download folder
DST = Path("datasets/BUSIS")  # where the notebook looks
TRAIN_RATIO = 0.8

for split in ["train", "test"]:
    (DST / split / "org").mkdir(parents=True, exist_ok=True)
    (DST / split / "gt").mkdir(parents=True, exist_ok=True)

# Collect all image/mask pairs across all categories
pairs = []
for category in ["Benign", "Malignant", "Normal"]:
    cat_dir = SRC / category
    for f in cat_dir.iterdir():
        if "_mask" not in f.name and f.suffix in [".png", ".bmp"]:
            mask = cat_dir / (f.stem + "_mask" + f.suffix)
            if mask.exists():
                pairs.append((f, mask))

random.seed(42)
random.shuffle(pairs)
split_idx = int(len(pairs) * TRAIN_RATIO)
train_pairs = pairs[:split_idx]
test_pairs  = pairs[split_idx:]

def copy_pair(pairs, split):
    for i, (img, mask) in enumerate(pairs):
        # e.g. img_0001.png and img_0001_GT.png
        new_stem = f"img_{i+1:04d}"
        new_img  = new_stem + img.suffix
        new_mask = new_stem + "_GT" + img.suffix

        shutil.copy(img,  DST / split / "org" / new_img)
        shutil.copy(mask, DST / split / "gt"  / new_mask)

copy_pair(train_pairs, "train")
copy_pair(test_pairs,  "test")

print(f"Train: {len(train_pairs)}, Test: {len(test_pairs)}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[37], line 16
#      14 for category in ["Benign", "Malignant", "Normal"]:
#      15     cat_dir = SRC / category
# ---> 16     for f in cat_dir.iterdir():
#      17         if "_mask" not in f.name and f.suffix in [".png", ".bmp"]:
#      18             mask = cat_dir / (f.stem + "_mask" + f.suffix)
#
# File c:\ProgramData\anaconda3\Lib\pathlib.py:931, in Path.iterdir(self)
#     927 def iterdir(self):
#     928     """Iterate over the files in this directory.  Does not yield any
#     929     result for the special paths '.' and '..'.
#     930     """
# --> 931     for name in os.listdir(self):
#     932         yield self._make_child_relpath(name)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'BUSIS\\Benign'

# %%
import shutil
from pathlib import Path

SRC = Path("KDSBdatasets")
DST = Path("datasets/KDSB")  # where your training script reads from

# Create required structure
for split in ["train", "test"]:
    (DST / split / "org").mkdir(parents=True, exist_ok=True)
    (DST / split / "gt").mkdir(parents=True, exist_ok=True)

def copy_split(split_name, target_split):
    img_dir = SRC / "images" / split_name
    mask_dir = SRC / "annotations" / split_name

    images = sorted(list(img_dir.glob("*")))
    
    for i, img_path in enumerate(images):
        # Match mask (assumes same filename)
        mask_name = img_path.stem + "_segmentation.png"
        mask_path = mask_dir / mask_name
        
        if not mask_path.exists():
            print(f"Missing mask for {img_path.name}")
            continue

        new_stem = f"img_{i+1:04d}"
        
        new_img_name  = new_stem + img_path.suffix
        new_mask_name = new_stem + "_GT.png"  # force consistent format

        shutil.copy(img_path,  DST / target_split / "org" / new_img_name)
        shutil.copy(mask_path, DST / target_split / "gt"  / new_mask_name)

# Train stays train
copy_split("train", "train")

# Combine val + test into test (optional, or keep separate if you modify loader)
copy_split("val", "test")
copy_split("test", "test")

print("Done restructuring dataset.")
# Out:
# Missing mask for ATTRIBUTION.txt
# Missing mask for LICENSE.txt
# Missing mask for ATTRIBUTION.txt
# Missing mask for LICENSE.txt
# Missing mask for ATTRIBUTION.txt
# Missing mask for LICENSE.txt
# Done restructuring dataset.

# %%
TRAIN_PATH="datasets/KDSB/train/"
TEST_PATH="datasets/KDSB/test/"

# %%
train_ids=next(os.walk(TRAIN_PATH+'org/'))[2][:]
test_ids=next(os.walk(TEST_PATH+'org/'))[2][:]
print(len(train_ids))
# Out:
# 2594

# %%
input_height = IMG_HEIGHT = 256
input_width = IMG_WIDTH = 256
IMG_CHANNELS = 3

# %%
SAVE_DIR = "saved_np"  # change if you want to save elsewhere

x_train_path = os.path.join(SAVE_DIR, "KDSB_X_train_256x256.npy")
y_train_path = os.path.join(SAVE_DIR, "KDSB_Y_train_256x256.npy")
x_test_path  = os.path.join(SAVE_DIR, "KDSB_X_test_256x256.npy")
y_test_path  = os.path.join(SAVE_DIR, "KDSB_Y_test_256x256.npy")

if all(os.path.exists(p) for p in [x_train_path, y_train_path, x_test_path, y_test_path]):
    print("Found cached arrays, loading...")
    X_train = np.load(x_train_path)
    Y_train = np.load(y_train_path)
    X_test  = np.load(x_test_path)
    Y_test  = np.load(y_test_path)
    print(f"Loaded — Train: {X_train.shape}, Test: {X_test.shape}")

else:
    print("No cached arrays found, loading and resizing from disk...")
    train_ids = next(os.walk(TRAIN_PATH + 'org/'))[2][:]
    test_ids  = next(os.walk(TEST_PATH  + 'org/'))[2][:]
    print(f"Train images: {len(train_ids)}, Test images: {len(test_ids)}")

    X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.float32)
    Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1),            dtype=np.float32)
    X_test  = np.zeros((len(test_ids),  IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.float32)
    Y_test  = np.zeros((len(test_ids),  IMG_HEIGHT, IMG_WIDTH, 1),            dtype=np.float32)

    for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
        img = imread(TRAIN_PATH + 'org/' + id_)[:, :, :IMG_CHANNELS]
        img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
        X_train[n] = img
        mask = imread(TRAIN_PATH + 'gt/' + id_[:-4] + '_GT.png')
        mask = np.expand_dims(mask, axis=-1)
        mask = resize(mask, (IMG_HEIGHT, IMG_WIDTH, 1), mode='constant', preserve_range=True)
        Y_train[n][mask[:, :, 0] / 255 > 0.] = 1.

    for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
        img = imread(TEST_PATH + 'org/' + id_)[:, :, :IMG_CHANNELS]
        img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
        X_test[n] = img
        mask = imread(TEST_PATH + 'gt/' + id_[:-4] + '_GT.png')
        mask = np.expand_dims(mask, axis=-1)
        mask = resize(mask, (IMG_HEIGHT, IMG_WIDTH, 1), mode='constant', preserve_range=True)
        Y_test[n][mask[:, :, 0] / 255 > 0.] = 1.

    np.save(x_train_path, X_train)
    np.save(y_train_path, Y_train)
    np.save(x_test_path,  X_test)
    np.save(y_test_path,  Y_test)
    print(f"Saved — Train: {X_train.shape}, Test: {X_test.shape}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 SAVE_DIR = "saved_np"  # change if you want to save elsewhere
# ----> 3 x_train_path = os.path.join(SAVE_DIR, "KDSB_X_train_256x256.npy")
#       4 y_train_path = os.path.join(SAVE_DIR, "KDSB_Y_train_256x256.npy")
#       5 x_test_path  = os.path.join(SAVE_DIR, "KDSB_X_test_256x256.npy")
#
# NameError: name 'os' is not defined

# %%
print(X_train.shape, Y_test.shape)
# Out:
# (2594, 256, 256, 3) (1000, 256, 256, 1)

# %%
ix=0
imshow(X_train[ix].astype('int'))
plt.show()
imshow(np.squeeze(Y_train[ix].astype('int')))
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:149: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
plt.figure(figsize=(30,30))
x, y = 5, 4
count=1
for i in range(y):
    for j in range(x):
        plt.subplot(y*2, x, i*2*x+j+1)
        pos = i+j
        plt.imshow(X_train[pos].astype('int'))
        plt.title('Image {}'.format(count))
        plt.axis('off')
        plt.subplot(y*2, x, (i*2+1)*x+j+1)
        plt.imshow(np.squeeze(Y_train[pos].astype('int')))
        plt.title('Mask {}'.format(count))
        plt.axis('off')
        count = count + 1
plt.show()

# %% [markdown]
# # Model

# %%
def expend_as(tensor, rep):
     return Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3),
                          arguments={'repnum': rep})(tensor)

def double_conv_layer(x, filter_size, size, dropout, batch_norm=False):
    axis = 3
    conv = SeparableConv2D(size, (filter_size, filter_size), padding='same')(x)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = SeparableConv2D(size, (filter_size, filter_size), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    if dropout > 0:
        conv = Dropout(dropout)(conv)

    shortcut = Conv2D(size, kernel_size=(1, 1), padding='same')(x)
    if batch_norm is True:
        shortcut = BatchNormalization(axis=axis)(shortcut)

    res_path = add([shortcut, conv])
    return res_path

def encoder(inputs):
    num_filters = [16, 32, 64, 128]
    skip_connections = []
    x = inputs

    for i, f in enumerate(num_filters):
        a = double_conv_layer(x, 3, f, 0.1, True)
        skip_connections.append(a)
        x = MaxPooling2D(pool_size=(2, 2))(a)
    
    return x, skip_connections

def bottleneck(inputs):
    x = inputs
    f = 256
    
    x3 = double_conv_layer(x, 3, f, 0.1, True)
    
    return x3

def decoder(inputs, skip_connections):
    num_filters = [128, 64, 32, 16]
    skip_connections.reverse()
    x = inputs
    batch_norm = True
    
    for i, f in enumerate(num_filters):
        
        x_up = UpSampling2D(size=(2, 2), data_format="channels_last")(x)
        x_att = concatenate([x_up, skip_connections[i]], axis=-1)
        
        x = double_conv_layer(x_att, 3, f, 0.1, True)
    return x

def output(inputs):
    x = Conv2D(1, kernel_size=(1,1))(inputs)
    x = BatchNormalization()(x)
    x = Activation('sigmoid')(x)
    
    return x

# %% [markdown]
# # Pre-training

# %% [markdown]
# ## Data Augmentaiton

# %%
def random_resize_crop(image, scale=[0.75, 1.0], crop_size=128):
    if crop_size == 32:
        image_shape = 48
        image = tf.image.resize(image, (image_shape, image_shape))
    else:
        image_shape = 96
        image = tf.image.resize(image, (image_shape, image_shape))
    size = tf.random.uniform(
        shape=(1,),
        minval=scale[0] * image_shape,
        maxval=scale[1] * image_shape,
        dtype=tf.float32,
    )
    size = tf.cast(size, tf.int32)[0]
    crop = tf.image.random_crop(image, (size, size, 3))
    crop_resize = tf.image.resize(crop, (crop_size, crop_size))
    return crop_resize

def flip_random_crop(image):
    image = tf.image.random_flip_left_right(image)
    image = random_resize_crop(image, crop_size=CROP_TO)
    return image


@tf.function
def float_parameter(level, maxval):
    return tf.cast(level * maxval / 10.0, tf.float32)


@tf.function
def sample_level(n):
    return tf.random.uniform(shape=[1], minval=0.1, maxval=n, dtype=tf.float32)

def rotation(image):
    augmented_image = tf.image.rot90(image)
    return augmented_image

@tf.function
def solarize(image, level=6):
    threshold = float_parameter(sample_level(level), 1)
    return tf.where(image < threshold, image, 255 - image)

def color_jitter(x, strength=0.5):
    x = tf.image.random_brightness(x, max_delta=0.8 * strength)
    x = tf.image.random_contrast(
        x, lower=1 - 0.8 * strength, upper=1 + 0.8 * strength
    )
    x = tf.image.random_saturation(
        x, lower=1 - 0.8 * strength, upper=1 + 0.8 * strength
    )
    x = tf.image.random_hue(x, max_delta=0.2 * strength)
    x = tf.clip_by_value(x, 0, 255)
    return x


def color_drop(x):
    x = tf.image.rgb_to_grayscale(x)
    x = tf.tile(x, [1, 1, 3])
    return x


def random_apply(func, x, p):
    if tf.random.uniform([], minval=0, maxval=1) < p:
        return func(x)
    else:
        return x


def custom_augment(image):
    image = tf.cast(image, tf.float32)
    image = flip_random_crop(image)
    image = random_apply(rotation, image, p=0.5)
    #image = random_apply(color_jitter, image, p=0.9)
    #image = random_apply(color_drop, image, p=0.3)
    #image = random_apply(solarize, image, p=0.3)
    return image

# %%
AUTO = tf.data.AUTOTUNE
CROP_TO = IMG_HEIGHT
SEED = 42
BATCH_SIZE = 4
ssl_ds_one = tf.data.Dataset.from_tensor_slices(X_train)
ssl_ds_one = (
    ssl_ds_one.shuffle(1024, seed=SEED)
    .map(custom_augment, num_parallel_calls=AUTO)
    .batch(BATCH_SIZE)
    .prefetch(AUTO)
)

ssl_ds_two = tf.data.Dataset.from_tensor_slices(X_train)
ssl_ds_two = (
    ssl_ds_two.shuffle(1024, seed=SEED)
    .map(custom_augment, num_parallel_calls=AUTO)
    .batch(BATCH_SIZE)
    .prefetch(AUTO)
)

# We then zip both of these datasets.
ssl_ds = tf.data.Dataset.zip((ssl_ds_one, ssl_ds_two))

# %%
sample_images_one = next(iter(ssl_ds_one))
plt.figure(figsize=(10, 10))
for n in range(2):
    ax = plt.subplot(5, 5, n + 1)
    plt.imshow(sample_images_one[n].numpy().astype("int"))
    #print(sample_images_one[n].numpy().shape)
    plt.axis("off")
plt.show()

# %%
sample_images_two = next(iter(ssl_ds_two))
plt.figure(figsize=(10, 10))
for n in range(2):
    ax = plt.subplot(5, 5, n + 1)
    plt.imshow(sample_images_two[n].numpy().astype("int"))
    plt.axis("off")
plt.show()

# %% [markdown]
# # Barlow Twins

# %%
def off_diagonal(x):
    n = tf.shape(x)[0]
    flattened = tf.reshape(x, [-1])[:-1]
    off_diagonals = tf.reshape(flattened, (n-1, n+1))[:, 1:]
    return tf.reshape(off_diagonals, [-1])


def normalize_repr(z):
    z_norm = (z - tf.reduce_mean(z, axis=0)) / tf.math.reduce_std(z, axis=0)
    return z_norm


def compute_loss(z_a, z_b, lambd):
    # Get batch size and representation dimension.
    batch_size = tf.cast(tf.shape(z_a)[0], z_a.dtype)
    repr_dim = tf.shape(z_a)[1]

    # Normalize the representations along the batch dimension.
    z_a_norm = normalize_repr(z_a)
    z_b_norm = normalize_repr(z_b)

    # Cross-correlation matrix.
    c = tf.matmul(z_a_norm, z_b_norm, transpose_a=True) / batch_size

    # Loss.
    on_diag = tf.linalg.diag_part(c) + (-1)
    on_diag = tf.reduce_sum(tf.pow(on_diag, 2))
    off_diag = off_diagonal(c)
    off_diag = tf.reduce_sum(tf.pow(off_diag, 2))
    loss = on_diag + (lambd * off_diag)
    return loss

# %%
class BarlowTwins(tf.keras.Model):
    def __init__(self, encoder, lambd=5e-3):
        super(BarlowTwins, self).__init__()
        self.encoder = encoder
        self.lambd = lambd
        self.loss_tracker = tf.keras.metrics.Mean(name="loss")

    @property
    def metrics(self):
        return [self.loss_tracker]

    def train_step(self, data):
        # Unpack the data.
        ds_one, ds_two = data

        # Forward pass through the encoder and predictor.
        with tf.GradientTape() as tape:
            z_a, z_b = self.encoder(ds_one, training=True), self.encoder(ds_two, training=True)
            loss = compute_loss(z_a, z_b, self.lambd) 

        # Compute gradients and update the parameters.
        gradients = tape.gradient(loss, self.encoder.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.encoder.trainable_variables))

        # Monitor loss.
        self.loss_tracker.update_state(loss)
        return {"loss": self.loss_tracker.result()}

# %%
class WarmUpCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    """
    Implements an LR scheduler that warms up the learning rate for some training steps
    (usually at the beginning of the training) and then decays it
    with CosineDecay (see https://arxiv.org/abs/1608.03983)
    """

    def __init__(
        self, learning_rate_base, total_steps, warmup_learning_rate, warmup_steps
    ):
        super(WarmUpCosine, self).__init__()

        self.learning_rate_base = learning_rate_base
        self.total_steps = total_steps
        self.warmup_learning_rate = warmup_learning_rate
        self.warmup_steps = warmup_steps
        self.pi = tf.constant(np.pi)

    def __call__(self, step):
        if self.total_steps < self.warmup_steps:
            raise ValueError("Total_steps must be larger or equal to warmup_steps.")
        learning_rate = (
            0.5
            * self.learning_rate_base
            * (
                1
                + tf.cos(
                    self.pi
                    * (tf.cast(step, tf.float32) - self.warmup_steps)
                    / float(self.total_steps - self.warmup_steps)
                )
            )
        )

        if self.warmup_steps > 0:
            if self.learning_rate_base < self.warmup_learning_rate:
                raise ValueError(
                    "Learning_rate_base must be larger or equal to "
                    "warmup_learning_rate."
                )
            slope = (
                self.learning_rate_base - self.warmup_learning_rate
            ) / self.warmup_steps
            warmup_rate = slope * tf.cast(step, tf.float32) + self.warmup_learning_rate
            learning_rate = tf.where(
                step < self.warmup_steps, warmup_rate, learning_rate
            )
        return tf.where(
            step > self.total_steps, 0.0, learning_rate, name="learning_rate"
        )

# %%
PROJECT_DIM = IMG_HEIGHT//2
BATCH_SIZE = 8
EPOCHS = 100
WEIGHT_DECAY = 5e-4
TRAIN_FLG = 0 # 0 - No Training, 1 - Training
val_split = 0.3

STEPS_PER_EPOCH = len(X_train) // BATCH_SIZE
TOTAL_STEPS = STEPS_PER_EPOCH * EPOCHS
WARMUP_EPOCHS = int(EPOCHS * 0.1)
WARMUP_STEPS = int(WARMUP_EPOCHS * STEPS_PER_EPOCH)

lr_decayed_fn = WarmUpCosine(
    learning_rate_base=1e-3,
    total_steps=EPOCHS * STEPS_PER_EPOCH,
    warmup_learning_rate=0.0,
    warmup_steps=WARMUP_STEPS
)

# %%
# Visualize the LR schedule
plt.plot(lr_decayed_fn(tf.range(EPOCHS*STEPS_PER_EPOCH, dtype=tf.float32)))
plt.ylabel("Learning Rate")
plt.xlabel("Train Step")
plt.show()

# %%
def projection_head(x, hidden_dim=128):
    """Constructs the projection head."""
    for i in range(2):
        x = Dense(
            hidden_dim,
            name=f"projection_layer_{i}",
            kernel_regularizer=l2(WEIGHT_DECAY),
        )(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
    outputs = Dense(hidden_dim, name="projection_output")(x)
    return outputs

def build_encoder(shape, hidden_dim=128):
    inputs = Input(shape)
    s = layers.Rescaling(1.0 / 255)(inputs) # Removed Experimental.something because it is not available in the latest TensorFlow version, replaced with Rescaling layer
    #s = inputs
    x, skip_1 = encoder(s)
    
    x = bottleneck(x)
    
    # Projections
    trunk_output = GlobalAvgPool2D()(x)
    projection_outputs = projection_head(trunk_output, hidden_dim=hidden_dim)

    model = Model(inputs, projection_outputs)
    return model, skip_1

# %%
unet_enc, skip_connetions = build_encoder((IMG_WIDTH, IMG_HEIGHT, IMG_CHANNELS), hidden_dim=PROJECT_DIM)
unet_enc.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_3         │ (None, 256, 256,  │          0 │ input_layer_3[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_18 │ (None, 256, 256,  │         91 │ rescaling_3[0][0] │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_19 │ (None, 256, 256,  │        416 │ activation_21[0]… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 256, 256,  │         64 │ rescaling_3[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 256, 256,  │          0 │ activation_22[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 128, 128,  │          0 │ add_9[0][0]       │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_20 │ (None, 128, 128,  │        688 │ max_pooling2d_4[… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_21 │ (None, 128, 128,  │      1,344 │ activation_23[0]… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 128, 128,  │        544 │ max_pooling2d_4[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 128, 128,  │          0 │ activation_24[0]… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 64, 64,    │          0 │ add_10[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_22 │ (None, 64, 64,    │      2,400 │ max_pooling2d_5[… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_23 │ (None, 64, 64,    │      4,736 │ activation_25[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │      2,112 │ max_pooling2d_5[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 64, 64,    │          0 │ activation_26[0]… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ dropout_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 32, 32,    │          0 │ add_11[0][0]      │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_24 │ (None, 32, 32,    │      8,896 │ max_pooling2d_6[… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_25 │ (None, 32, 32,    │     17,664 │ activation_27[0]… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │      8,320 │ max_pooling2d_6[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 32, 32,    │          0 │ activation_28[0]… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ dropout_12[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 16, 16,    │          0 │ add_12[0][0]      │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_26 │ (None, 16, 16,    │     34,176 │ max_pooling2d_7[… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_27 │ (None, 16, 16,    │     68,096 │ activation_29[0]… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 16, 16,    │     33,024 │ max_pooling2d_7[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 16, 16,    │          0 │ activation_30[0]… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ add_13[0][0]      │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ projection_layer_0  │ (None, 128)       │     32,896 │ global_average_p… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ projection_layer… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ projection_layer_1  │ (None, 128)       │     16,512 │ activation_31[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ projection_layer… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ projection_output   │ (None, 128)       │     16,512 │ activation_32[0]… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 255,467 (997.92 KB)
#  Trainable params: 251,979 (984.29 KB)
#  Non-trainable params: 3,488 (13.62 KB)

# %% [markdown]
# # Training BT

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=lr_decayed_fn, momentum=0.9)
barlow_twins = BarlowTwins(unet_enc)
barlow_twins.compile(optimizer=optimizer)
if TRAIN_FLG:
    print("Training")
    barlow_twins.encoder.get_weights()[0]
    history = barlow_twins.fit(ssl_ds, epochs=EPOCHS)
    barlow_twins.encoder.save("barlow_twins_unet.keras")
    plt.plot(history.history["loss"])
    plt.grid()
    plt.title("Barlow Twin Loss")
    plt.show()
elif not TRAIN_FLG:
    print("Loading training weights")
    barlow_twins.encoder.load_weights("barlow_twins_unet.keras")
# Out:
# Loading training weights

# %%
backbone = tf.keras.Model(
    barlow_twins.encoder.input, barlow_twins.encoder.layers[-9].output
)
backbone.layers
# Out:
# [<InputLayer name=input_layer_3, built=True>,
#  <Rescaling name=rescaling_3, built=True>,
#  <SeparableConv2D name=separable_conv2d_18, built=True>,
#  <BatchNormalization name=batch_normalization_30, built=True>,
#  <Activation name=activation_21, built=True>,
#  <SeparableConv2D name=separable_conv2d_19, built=True>,
#  <BatchNormalization name=batch_normalization_31, built=True>,
#  <Conv2D name=conv2d_10, built=True>,
#  <Activation name=activation_22, built=True>,
#  <BatchNormalization name=batch_normalization_32, built=True>,
#  <Dropout name=dropout_9, built=True>,
#  <Add name=add_9, built=True>,
#  <MaxPooling2D name=max_pooling2d_4, built=True>,
#  <SeparableConv2D name=separable_conv2d_20, built=True>,
#  <BatchNormalization name=batch_normalization_33, built=True>,
#  <Activation name=activation_23, built=True>,
#  <SeparableConv2D name=separable_conv2d_21, built=True>,
#  <BatchNormalization name=batch_normalization_34, built=True>,
#  <Conv2D name=conv2d_11, built=True>,
#  <Activation name=activation_24, built=True>,
#  <BatchNormalization name=batch_normalization_35, built=True>,
#  <Dropout name=dropout_10, built=True>,
#  <Add name=add_10, built=True>,
#  <MaxPooling2D name=max_pooling2d_5, built=True>,
#  <SeparableConv2D name=separable_conv2d_22, built=True>,
#  <BatchNormalization name=batch_normalization_36, built=True>,
#  <Activation name=activation_25, built=True>,
#  <SeparableConv2D name=separable_conv2d_23, built=True>,
#  <BatchNormalization name=batch_normalization_37, built=True>,
#  <Conv2D name=conv2d_12, built=True>,
#  <Activation name=activation_26, built=True>,
#  <BatchNormalization name=batch_normalization_38, built=True>,
#  <Dropout name=dropout_11, built=True>,
#  <Add name=add_11, built=True>,
#  <MaxPooling2D name=max_pooling2d_6, built=True>,
#  <SeparableConv2D name=separable_conv2d_24, built=True>,
#  <BatchNormalization name=batch_normalization_39, built=True>,
#  <Activation name=activation_27, built=True>,
#  <SeparableConv2D name=separable_conv2d_25, built=True>,
#  <BatchNormalization name=batch_normalization_40, built=True>,
#  <Conv2D name=conv2d_13, built=True>,
#  <Activation name=activation_28, built=True>,
#  <BatchNormalization name=batch_normalization_41, built=True>,
#  <Dropout name=dropout_12, built=True>,
#  <Add name=add_12, built=True>,
#  <MaxPooling2D name=max_pooling2d_7, built=True>,
#  <SeparableConv2D name=separable_conv2d_26, built=True>,
#  <BatchNormalization name=batch_normalization_42, built=True>,
#  <Activation name=activation_29, built=True>,
#  <SeparableConv2D name=separable_conv2d_27, built=True>,
#  <BatchNormalization name=batch_normalization_43, built=True>,
#  <Conv2D name=conv2d_14, built=True>,
#  <Activation name=activation_30, built=True>,
#  <BatchNormalization name=batch_normalization_44, built=True>,
#  <Dropout name=dropout_13, built=True>,
#  <Add name=add_13, built=True>]

# %%
backbone.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_3         │ (None, 256, 256,  │          0 │ input_layer_3[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_18 │ (None, 256, 256,  │         91 │ rescaling_3[0][0] │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_19 │ (None, 256, 256,  │        416 │ activation_21[0]… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 256, 256,  │         64 │ rescaling_3[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 256, 256,  │          0 │ activation_22[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 128, 128,  │          0 │ add_9[0][0]       │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_20 │ (None, 128, 128,  │        688 │ max_pooling2d_4[… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_21 │ (None, 128, 128,  │      1,344 │ activation_23[0]… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 128, 128,  │        544 │ max_pooling2d_4[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 128, 128,  │          0 │ activation_24[0]… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 64, 64,    │          0 │ add_10[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_22 │ (None, 64, 64,    │      2,400 │ max_pooling2d_5[… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_23 │ (None, 64, 64,    │      4,736 │ activation_25[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │      2,112 │ max_pooling2d_5[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 64, 64,    │          0 │ activation_26[0]… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ dropout_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 32, 32,    │          0 │ add_11[0][0]      │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_24 │ (None, 32, 32,    │      8,896 │ max_pooling2d_6[… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_25 │ (None, 32, 32,    │     17,664 │ activation_27[0]… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │      8,320 │ max_pooling2d_6[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 32, 32,    │          0 │ activation_28[0]… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ dropout_12[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 16, 16,    │          0 │ add_12[0][0]      │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_26 │ (None, 16, 16,    │     34,176 │ max_pooling2d_7[… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_27 │ (None, 16, 16,    │     68,096 │ activation_29[0]… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 16, 16,    │     33,024 │ max_pooling2d_7[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 16, 16,    │          0 │ activation_30[0]… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ dropout_13[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 188,523 (736.42 KB)
#  Trainable params: 185,547 (724.79 KB)
#  Non-trainable params: 2,976 (11.62 KB)

# %%
new_skip_connections = [backbone.get_layer(index=11).output, 
                        backbone.get_layer(index=22).output, 
                        backbone.get_layer(index=33).output, 
                        backbone.get_layer(index=44).output]

# %%
new_skip_connections
# Out:
# [<KerasTensor shape=(None, 256, 256, 16), dtype=float32, sparse=False, ragged=False, name=keras_tensor_130>,
#  <KerasTensor shape=(None, 128, 128, 32), dtype=float32, sparse=False, ragged=False, name=keras_tensor_141>,
#  <KerasTensor shape=(None, 64, 64, 64), dtype=float32, sparse=False, ragged=False, name=keras_tensor_152>,
#  <KerasTensor shape=(None, 32, 32, 128), dtype=float32, sparse=False, ragged=False, name=keras_tensor_163>]

# %%
backbone.output
# Out:
# <KerasTensor shape=(None, 16, 16, 256), dtype=float32, sparse=False, ragged=False, name=keras_tensor_174>

# %% [markdown]
# # Complete model

# %%
backbone.trainable=True
x = backbone.output
#x = bottleneck(x)
x = decoder(x, new_skip_connections)
outputs = output(x)
model = Model(barlow_twins.encoder.input, outputs)

# %%
model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_3         │ (None, 256, 256,  │          0 │ input_layer_3[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_18 │ (None, 256, 256,  │         91 │ rescaling_3[0][0] │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_19 │ (None, 256, 256,  │        416 │ activation_21[0]… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 256, 256,  │         64 │ rescaling_3[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 256, 256,  │          0 │ activation_22[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 128, 128,  │          0 │ add_9[0][0]       │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_20 │ (None, 128, 128,  │        688 │ max_pooling2d_4[… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_21 │ (None, 128, 128,  │      1,344 │ activation_23[0]… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 128, 128,  │        544 │ max_pooling2d_4[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 128, 128,  │          0 │ activation_24[0]… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 64, 64,    │          0 │ add_10[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_22 │ (None, 64, 64,    │      2,400 │ max_pooling2d_5[… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_23 │ (None, 64, 64,    │      4,736 │ activation_25[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │      2,112 │ max_pooling2d_5[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 64, 64,    │          0 │ activation_26[0]… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ dropout_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 32, 32,    │          0 │ add_11[0][0]      │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_24 │ (None, 32, 32,    │      8,896 │ max_pooling2d_6[… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_25 │ (None, 32, 32,    │     17,664 │ activation_27[0]… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │      8,320 │ max_pooling2d_6[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 32, 32,    │          0 │ activation_28[0]… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ dropout_12[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 16, 16,    │          0 │ add_12[0][0]      │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_26 │ (None, 16, 16,    │     34,176 │ max_pooling2d_7[… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_27 │ (None, 16, 16,    │     68,096 │ activation_29[0]… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 16, 16,    │     33,024 │ max_pooling2d_7[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 16, 16,    │          0 │ activation_30[0]… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (None, 32, 32,    │          0 │ add_13[0][0]      │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 32, 32,    │          0 │ up_sampling2d_4[… │
# │ (Concatenate)       │ 384)              │            │ add_12[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_28 │ (None, 32, 32,    │     52,736 │ concatenate_4[0]… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_29 │ (None, 32, 32,    │     17,664 │ activation_33[0]… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 32, 32,    │     49,280 │ concatenate_4[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 32, 32,    │          0 │ activation_34[0]… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ dropout_14[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_5     │ (None, 64, 64,    │          0 │ add_14[0][0]      │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 64, 64,    │          0 │ up_sampling2d_5[… │
# │ (Concatenate)       │ 192)              │            │ add_11[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_30 │ (None, 64, 64,    │     14,080 │ concatenate_5[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_31 │ (None, 64, 64,    │      4,736 │ activation_35[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 64, 64,    │     12,352 │ concatenate_5[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_36       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 64, 64,    │          0 │ activation_36[0]… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ dropout_15[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_6     │ (None, 128, 128,  │          0 │ add_15[0][0]      │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 128, 128,  │          0 │ up_sampling2d_6[… │
# │ (Concatenate)       │ 96)               │            │ add_10[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_32 │ (None, 128, 128,  │      3,968 │ concatenate_6[0]… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_33 │ (None, 128, 128,  │      1,344 │ activation_37[0]… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 128, 128,  │      3,104 │ concatenate_6[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_38       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 128, 128,  │          0 │ activation_38[0]… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ dropout_16[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_7     │ (None, 256, 256,  │          0 │ add_16[0][0]      │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 256, 256,  │          0 │ up_sampling2d_7[… │
# │ (Concatenate)       │ 48)               │            │ add_9[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_34 │ (None, 256, 256,  │      1,216 │ concatenate_7[0]… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_39       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_35 │ (None, 256, 256,  │        416 │ activation_39[0]… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │        784 │ concatenate_7[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_40       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 256, 256,  │          0 │ activation_40[0]… │
# │ (Dropout)           │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ dropout_17[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 256, 256,  │         17 │ add_17[0][0]      │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │          4 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_41       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 353,104 (1.35 MB)
#  Trainable params: 348,686 (1.33 MB)
#  Non-trainable params: 4,418 (17.26 KB)

# %% [markdown]
# # Metrics

# %%
def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = label(y_true_in > 0.5)
    y_pred = label(y_pred_in > 0.5)
    
    true_objects = len(np.unique(labels))
    pred_objects = len(np.unique(y_pred))

    intersection = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))[0]

    # Compute areas (needed for finding the union between all objects)
    area_true = np.histogram(labels, bins = true_objects)[0]
    area_pred = np.histogram(y_pred, bins = pred_objects)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection

    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union
    #print('IOU {}'.format(iou))
    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
    
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    value = 0.
    for batch in range(batch_size):
        value = value + iou_metric(y_true_in[batch], y_pred_in[batch])
    return value/batch_size

def my_iou_metric(label, pred):
    metric_value = tf.py_function(iou_metric_batch, [label, pred], tf.float32)
    return metric_value

def my_iou_metric_loss(label, pred):
    loss = 1-tf.py_function(iou_metric_batch, [label, pred], tf.float32)
    #loss = -tf.map_fn(my_iou_metric_loss(label, pred), tf.range(tf.shape(pred)[0]))
    loss.set_shape((None,))

    return loss

def dice_coeff(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score

def haud_dist(y_true, y_pred):
    y_true = np.squeeze(y_true)
    y_pred = np.squeeze(y_pred)
    
    return hausdorff_distance(y_true,y_pred)

def haud_dist_batch(y_true, y_pred):
    if len(y_true.shape)==2:
        return haud_dist(y_true, y_pred)
    else:
        batch_size = y_true.shape[0]
    hd = 0.
    for batch in range(batch_size):
        hd = hd + haud_dist(y_true[batch], y_pred[batch])
    return hd/batch_size

def my_haud_dist(label, pred):
    metric_value = tf.py_function(haud_dist_batch, [label, pred], tf.float32)
    return metric_value

def evalResult(gt,pred,target_size=(256,256),flag_multi_class = False,num_class = 2):
    gt = np.squeeze(gt)
    pred = np.squeeze(pred)
    
    acc = Accuracy()
    acc.update_state(np.squeeze(gt), np.squeeze(pred))
    r_acc = acc.result().numpy()
    
    pr = Precision()
    pr.update_state(np.squeeze(gt), np.squeeze(pred))
    r_pr = pr.result().numpy()
    
    rc = Recall()
    rc.update_state(np.squeeze(gt), np.squeeze(pred))
    r_rc = rc.result().numpy()
    
    mi = MeanIoU(num_class)
    mi.update_state(np.squeeze(gt), np.squeeze(pred))
    r_mi = mi.result().numpy()
    
    dc = 0.
    for img in range(gt.shape[0]):
        dc = dc + dice_coeff(gt[img], pred[img]).numpy()
    dc = dc / gt.shape[0]
    
    hd = haud_dist_batch(gt,pred)
    
    miou = iou_metric_batch(gt,pred)
    
    mae = MeanAbsoluteError()
    r_mae = mae(np.squeeze(gt), np.squeeze(pred)).numpy()

    print("Accuracy=",r_acc, "Precision=",r_pr, "Recall=",r_rc, "MeanIoU=",r_mi, "DiceCoefficient=",dc, "HD=",hd, "MyIoU=",miou, "MAE=",r_mae)

# %% [markdown]
# # Loss

# %%
def focal_loss(target_tensor, prediction_tensor, weights=None, alpha=0.25, gamma=2):
    sigmoid_p = tf.nn.sigmoid(prediction_tensor)
    zeros = array_ops.zeros_like(sigmoid_p, dtype=sigmoid_p.dtype)
    
    # For poitive prediction, only need consider front part loss, back part is 0;
    # target_tensor > zeros <=> z=1, so poitive coefficient = z - p.
    pos_p_sub = array_ops.where(target_tensor > zeros, target_tensor - sigmoid_p, zeros)
    
    # For negative prediction, only need consider back part loss, front part is 0;
    # target_tensor > zeros <=> z=1, so negative coefficient = 0.
    neg_p_sub = array_ops.where(target_tensor > zeros, zeros, sigmoid_p)
    per_entry_cross_ent = - alpha * (pos_p_sub ** gamma) * tf.math.log(tf.clip_by_value(sigmoid_p, 1e-8, 1.0))                           - (1 - alpha) * (neg_p_sub ** gamma) * tf.math.log(tf.clip_by_value(1.0 - sigmoid_p, 1e-8, 1.0))
    return tf.reduce_sum(per_entry_cross_ent)

def mean_iou_loss(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.compat.v1.to_int32(y_pred > t)
        score, up_opt = tf.compat.v1.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return -tf.math.log(K.mean(K.stack(prec), axis=0))

def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss

def bce_dice_loss(y_true, y_pred):
    loss = 0.4*categorical_crossentropy(y_true, y_pred) + 0.6*dice_loss(y_true, y_pred)
    return loss

def bce_dice_loss2(y_true, y_pred):
    fl = focal_loss(y_true, y_pred, gamma=5)
    loss = 0.2*categorical_crossentropy(y_true, y_pred) + 0.3*dice_loss(y_true, y_pred) + 0.5*fl
    return loss

# %% [markdown]
# # Callbacks

# %%
log_path = "logs/"
keyname = "BT-Unet_5"
cur_date = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tb_log_dir = log_path + "fit/" + keyname + '_' + cur_date 
tensorboard_callback = TensorBoard(log_dir=tb_log_dir, histogram_freq=0)
model_checkpoint = ModelCheckpoint('model_'+keyname+'.keras', monitor='loss',verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor='loss', verbose=1, patience=20)
csv_logger = CSVLogger(log_path + keyname + '_' + cur_date + '.log', separator=',', append=False)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10)

# %% [markdown]
# # Training

# %%
model.compile(
    loss=bce_dice_loss,
    optimizer=Adam(),
    metrics=['accuracy', Precision(), MeanIoU(num_classes=2), Recall(), dice_coeff, MeanAbsoluteError()]
   )
X_train_20 = X_train[:int(X_train.shape[0]*0.05)]
Y_train_20 = Y_train[:int(Y_train.shape[0]*0.05)]
TRAIN_FLG = True
if TRAIN_FLG:
    print("Training")
    callbacks = [
        model_checkpoint,
        reduce_lr,
        csv_logger,
        tensorboard_callback,
        early_stopping
    ]
    results = model.fit(X_train_20, Y_train_20, validation_split=val_split, batch_size=8, epochs=200, callbacks=callbacks)
elif not TRAIN_FLG:
    print("Loading training weights")
    model.load_weights('model_'+keyname+'.hdf5')
# Out:
# Training
# Epoch 1/200
# C:\Users\ujai264\AppData\Local\Temp\ipykernel_13968\3548703083.py:31: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 256, 256, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   loss = 0.4*categorical_crossentropy(y_true, y_pred) + 0.6*dice_loss(y_true, y_pred)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.6488 - dice_coeff: 0.4532 - loss: 0.3273 - mean_absolute_error: 0.4310 - mean_io_u_16: 0.3537 - precision_16: 0.4530 - recall_16: 0.7620
# Epoch 1: loss improved from None to 0.29556, saving model to model_BT-Unet_5.keras
#
# Epoch 1: finished saving model to model_BT-Unet_5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 503ms/step - accuracy: 0.7492 - dice_coeff: 0.4911 - loss: 0.2956 - mean_absolute_error: 0.3900 - mean_io_u_16: 0.3483 - precision_16: 0.5590 - recall_16: 0.8217 - val_accuracy: 0.8137 - val_dice_coeff: 0.4709 - val_loss: 0.3189 - val_mean_absolute_error: 0.1929 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8490 - val_recall_16: 0.3533 - learning_rate: 0.0010
# Epoch 2/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.8724 - dice_coeff: 0.5650 - loss: 0.2607 - mean_absolute_error: 0.3438 - mean_io_u_16: 0.3444 - precision_16: 0.7742 - recall_16: 0.8348
# Epoch 2: loss improved from 0.29556 to 0.26834, saving model to model_BT-Unet_5.keras
#
# Epoch 2: finished saving model to model_BT-Unet_5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 423ms/step - accuracy: 0.8510 - dice_coeff: 0.5465 - loss: 0.2683 - mean_absolute_error: 0.3506 - mean_io_u_16: 0.3483 - precision_16: 0.7216 - recall_16: 0.8285 - val_accuracy: 0.8379 - val_dice_coeff: 0.5539 - val_loss: 0.2688 - val_mean_absolute_error: 0.1745 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8726 - val_recall_16: 0.4479 - learning_rate: 0.0010
# Epoch 3/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.8542 - dice_coeff: 0.5797 - loss: 0.2523 - mean_absolute_error: 0.3383 - mean_io_u_16: 0.3380 - precision_16: 0.7285 - recall_16: 0.8784
# Epoch 3: loss improved from 0.26834 to 0.26327, saving model to model_BT-Unet_5.keras
#
# Epoch 3: finished saving model to model_BT-Unet_5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 427ms/step - accuracy: 0.8472 - dice_coeff: 0.5638 - loss: 0.2633 - mean_absolute_error: 0.3430 - mean_io_u_16: 0.3483 - precision_16: 0.6938 - recall_16: 0.8883 - val_accuracy: 0.8461 - val_dice_coeff: 0.5591 - val_loss: 0.2656 - val_mean_absolute_error: 0.1877 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8755 - val_recall_16: 0.4824 - learning_rate: 0.0010
# Epoch 4/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.8575 - dice_coeff: 0.5645 - loss: 0.2615 - mean_absolute_error: 0.3382 - mean_io_u_16: 0.3505 - precision_16: 0.7138 - recall_16: 0.8737
# Epoch 4: loss improved from 0.26327 to 0.25729, saving model to model_BT-Unet_5.keras
#
# Epoch 4: finished saving model to model_BT-Unet_5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 434ms/step - accuracy: 0.8660 - dice_coeff: 0.5738 - loss: 0.2573 - mean_absolute_error: 0.3341 - mean_io_u_16: 0.3483 - precision_16: 0.7304 - recall_16: 0.8851 - val_accuracy: 0.8845 - val_dice_coeff: 0.5763 - val_loss: 0.2552 - val_mean_absolute_error: 0.2174 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8984 - val_recall_16: 0.6315 - learning_rate: 0.0010
# Epoch 5/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.8792 - dice_coeff: 0.5590 - loss: 0.2638 - mean_absolute_error: 0.3288 - mean_io_u_16: 0.3603 - precision_16: 0.7262 - recall_16: 0.9146
# Epoch 5: loss improved from 0.25729 to 0.25532, saving model to model_BT-Unet_5.keras
#
# Epoch 5: finished saving model to model_BT-Unet_5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 434ms/step - accuracy: 0.8798 - dice_coeff: 0.5588 - loss: 0.2553 - mean_absolute_error: 0.3274 - mean_io_u_16: 0.3483 - precision_16: 0.7565 - recall_16: 0.8903 - val_accuracy: 0.9025 - val_dice_coeff: 0.5930 - val_loss: 0.2451 - val_mean_absolute_error: 0.2267 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8893 - val_recall_16: 0.7179 - learning_rate: 0.0010
# Epoch 6/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.8799 - dice_coeff: 0.5934 - loss: 0.2441 - mean_absolute_error: 0.3214 - mean_io_u_16: 0.3414 - precision_16: 0.7571 - recall_16: 0.9135
# Epoch 6: loss improved from 0.25532 to 0.24898, saving model to model_BT-Unet_5.keras
#
# Epoch 6: finished saving model to model_BT-Unet_5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 453ms/step - accuracy: 0.8830 - dice_coeff: 0.5889 - loss: 0.2490 - mean_absolute_error: 0.3216 - mean_io_u_16: 0.3483 - precision_16: 0.7560 - recall_16: 0.9072 - val_accuracy: 0.9152 - val_dice_coeff: 0.5358 - val_loss: 0.2794 - val_mean_absolute_error: 0.2906 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8943 - val_recall_16: 0.7676 - learning_rate: 0.0010
# Epoch 7/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.8794 - dice_coeff: 0.5901 - loss: 0.2460 - mean_absolute_error: 0.3206 - mean_io_u_16: 0.3426 - precision_16: 0.7693 - recall_16: 0.8842
# Epoch 7: loss improved from 0.24898 to 0.24734, saving model to model_BT-Unet_5.keras
#
# Epoch 7: finished saving model to model_BT-Unet_5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 458ms/step - accuracy: 0.8937 - dice_coeff: 0.5883 - loss: 0.2473 - mean_absolute_error: 0.3165 - mean_io_u_16: 0.3483 - precision_16: 0.7847 - recall_16: 0.8950 - val_accuracy: 0.9128 - val_dice_coeff: 0.5298 - val_loss: 0.2830 - val_mean_absolute_error: 0.3044 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8744 - val_recall_16: 0.7796 - learning_rate: 0.0010
# Epoch 8/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.9123 - dice_coeff: 0.5967 - loss: 0.2421 - mean_absolute_error: 0.3086 - mean_io_u_16: 0.3470 - precision_16: 0.8291 - recall_16: 0.8986
# Epoch 8: loss did not improve from 0.24734
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - accuracy: 0.8982 - dice_coeff: 0.5897 - loss: 0.2478 - mean_absolute_error: 0.3144 - mean_io_u_16: 0.3483 - precision_16: 0.8012 - recall_16: 0.8838 - val_accuracy: 0.9125 - val_dice_coeff: 0.5193 - val_loss: 0.2892 - val_mean_absolute_error: 0.3284 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8328 - val_recall_16: 0.8342 - learning_rate: 0.0010
# Epoch 9/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.8789 - dice_coeff: 0.5990 - loss: 0.2402 - mean_absolute_error: 0.3148 - mean_io_u_16: 0.3402 - precision_16: 0.7666 - recall_16: 0.8936
# Epoch 9: loss improved from 0.24734 to 0.24299, saving model to model_BT-Unet_5.keras
#
# Epoch 9: finished saving model to model_BT-Unet_5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 453ms/step - accuracy: 0.8879 - dice_coeff: 0.5877 - loss: 0.2430 - mean_absolute_error: 0.3108 - mean_io_u_16: 0.3483 - precision_16: 0.7643 - recall_16: 0.9119 - val_accuracy: 0.9152 - val_dice_coeff: 0.5029 - val_loss: 0.2990 - val_mean_absolute_error: 0.3453 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8511 - val_recall_16: 0.8203 - learning_rate: 0.0010
# Epoch 10/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9113 - dice_coeff: 0.5976 - loss: 0.2418 - mean_absolute_error: 0.3036 - mean_io_u_16: 0.3512 - precision_16: 0.8118 - recall_16: 0.9142
# Epoch 10: loss improved from 0.24299 to 0.24091, saving model to model_BT-Unet_5.keras
#
# Epoch 10: finished saving model to model_BT-Unet_5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 451ms/step - accuracy: 0.9037 - dice_coeff: 0.6044 - loss: 0.2409 - mean_absolute_error: 0.3054 - mean_io_u_16: 0.3483 - precision_16: 0.8047 - recall_16: 0.9013 - val_accuracy: 0.8976 - val_dice_coeff: 0.5085 - val_loss: 0.2955 - val_mean_absolute_error: 0.3503 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.7776 - val_recall_16: 0.8541 - learning_rate: 0.0010
# Epoch 11/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.9100 - dice_coeff: 0.6160 - loss: 0.2305 - mean_absolute_error: 0.2977 - mean_io_u_16: 0.3415 - precision_16: 0.8294 - recall_16: 0.9005
# Epoch 11: loss improved from 0.24091 to 0.23712, saving model to model_BT-Unet_5.keras
#
# Epoch 11: finished saving model to model_BT-Unet_5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 450ms/step - accuracy: 0.9050 - dice_coeff: 0.6068 - loss: 0.2371 - mean_absolute_error: 0.3004 - mean_io_u_16: 0.3483 - precision_16: 0.8066 - recall_16: 0.9036 - val_accuracy: 0.9112 - val_dice_coeff: 0.5028 - val_loss: 0.2990 - val_mean_absolute_error: 0.3536 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8267 - val_recall_16: 0.8372 - learning_rate: 0.0010
# Epoch 12/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9028 - dice_coeff: 0.6007 - loss: 0.2396 - mean_absolute_error: 0.2996 - mean_io_u_16: 0.3512 - precision_16: 0.8020 - recall_16: 0.8959
# Epoch 12: loss improved from 0.23712 to 0.23607, saving model to model_BT-Unet_5.keras
#
# Epoch 12: finished saving model to model_BT-Unet_5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 449ms/step - accuracy: 0.9076 - dice_coeff: 0.6070 - loss: 0.2361 - mean_absolute_error: 0.2970 - mean_io_u_16: 0.3483 - precision_16: 0.8118 - recall_16: 0.9053 - val_accuracy: 0.9073 - val_dice_coeff: 0.5079 - val_loss: 0.2959 - val_mean_absolute_error: 0.3507 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8140 - val_recall_16: 0.8384 - learning_rate: 0.0010
# Epoch 13/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.8968 - dice_coeff: 0.6048 - loss: 0.2368 - mean_absolute_error: 0.2979 - mean_io_u_16: 0.3457 - precision_16: 0.7937 - recall_16: 0.8989
# Epoch 13: loss improved from 0.23607 to 0.23472, saving model to model_BT-Unet_5.keras
#
# Epoch 13: finished saving model to model_BT-Unet_5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 446ms/step - accuracy: 0.9088 - dice_coeff: 0.6025 - loss: 0.2347 - mean_absolute_error: 0.2933 - mean_io_u_16: 0.3483 - precision_16: 0.8093 - recall_16: 0.9150 - val_accuracy: 0.9076 - val_dice_coeff: 0.5017 - val_loss: 0.2996 - val_mean_absolute_error: 0.3577 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8132 - val_recall_16: 0.8410 - learning_rate: 0.0010
# Epoch 14/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.9288 - dice_coeff: 0.6383 - loss: 0.2170 - mean_absolute_error: 0.2803 - mean_io_u_16: 0.3361 - precision_16: 0.8695 - recall_16: 0.9195
# Epoch 14: loss improved from 0.23472 to 0.23095, saving model to model_BT-Unet_5.keras
#
# Epoch 14: finished saving model to model_BT-Unet_5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 448ms/step - accuracy: 0.9136 - dice_coeff: 0.6160 - loss: 0.2309 - mean_absolute_error: 0.2882 - mean_io_u_16: 0.3483 - precision_16: 0.8173 - recall_16: 0.9210 - val_accuracy: 0.8983 - val_dice_coeff: 0.5009 - val_loss: 0.3001 - val_mean_absolute_error: 0.3606 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.7782 - val_recall_16: 0.8569 - learning_rate: 0.0010
# Epoch 15/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9257 - dice_coeff: 0.6264 - loss: 0.2237 - mean_absolute_error: 0.2814 - mean_io_u_16: 0.3428 - precision_16: 0.8548 - recall_16: 0.9189
# Epoch 15: loss did not improve from 0.23095
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 431ms/step - accuracy: 0.9163 - dice_coeff: 0.6061 - loss: 0.2312 - mean_absolute_error: 0.2868 - mean_io_u_16: 0.3483 - precision_16: 0.8361 - recall_16: 0.9007 - val_accuracy: 0.9115 - val_dice_coeff: 0.4941 - val_loss: 0.3041 - val_mean_absolute_error: 0.3626 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8233 - val_recall_16: 0.8442 - learning_rate: 0.0010
# Epoch 16/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9157 - dice_coeff: 0.6205 - loss: 0.2279 - mean_absolute_error: 0.2827 - mean_io_u_16: 0.3502 - precision_16: 0.8167 - recall_16: 0.9267
# Epoch 16: loss improved from 0.23095 to 0.22596, saving model to model_BT-Unet_5.keras
#
# Epoch 16: finished saving model to model_BT-Unet_5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 446ms/step - accuracy: 0.9202 - dice_coeff: 0.6269 - loss: 0.2260 - mean_absolute_error: 0.2812 - mean_io_u_16: 0.3483 - precision_16: 0.8271 - recall_16: 0.9318 - val_accuracy: 0.9112 - val_dice_coeff: 0.4944 - val_loss: 0.3039 - val_mean_absolute_error: 0.3623 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8197 - val_recall_16: 0.8485 - learning_rate: 1.0000e-04
# Epoch 17/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.9204 - dice_coeff: 0.6219 - loss: 0.2271 - mean_absolute_error: 0.2810 - mean_io_u_16: 0.3507 - precision_16: 0.8280 - recall_16: 0.9261
# Epoch 17: loss did not improve from 0.22596
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 430ms/step - accuracy: 0.9204 - dice_coeff: 0.6266 - loss: 0.2266 - mean_absolute_error: 0.2815 - mean_io_u_16: 0.3483 - precision_16: 0.8378 - recall_16: 0.9149 - val_accuracy: 0.9159 - val_dice_coeff: 0.4968 - val_loss: 0.3025 - val_mean_absolute_error: 0.3579 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8439 - val_recall_16: 0.8341 - learning_rate: 1.0000e-04
# Epoch 18/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.9225 - dice_coeff: 0.6125 - loss: 0.2324 - mean_absolute_error: 0.2820 - mean_io_u_16: 0.3568 - precision_16: 0.8264 - recall_16: 0.9251
# Epoch 18: loss did not improve from 0.22596
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 433ms/step - accuracy: 0.9217 - dice_coeff: 0.6211 - loss: 0.2265 - mean_absolute_error: 0.2813 - mean_io_u_16: 0.3483 - precision_16: 0.8450 - recall_16: 0.9084 - val_accuracy: 0.9169 - val_dice_coeff: 0.4981 - val_loss: 0.3017 - val_mean_absolute_error: 0.3564 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8466 - val_recall_16: 0.8345 - learning_rate: 1.0000e-04
# Epoch 19/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.9247 - dice_coeff: 0.6247 - loss: 0.2250 - mean_absolute_error: 0.2787 - mean_io_u_16: 0.3466 - precision_16: 0.8499 - recall_16: 0.9170
# Epoch 19: loss improved from 0.22596 to 0.22527, saving model to model_BT-Unet_5.keras
#
# Epoch 19: finished saving model to model_BT-Unet_5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 447ms/step - accuracy: 0.9255 - dice_coeff: 0.6201 - loss: 0.2253 - mean_absolute_error: 0.2781 - mean_io_u_16: 0.3483 - precision_16: 0.8457 - recall_16: 0.9229 - val_accuracy: 0.9179 - val_dice_coeff: 0.4995 - val_loss: 0.3008 - val_mean_absolute_error: 0.3548 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8488 - val_recall_16: 0.8363 - learning_rate: 1.0000e-04
# Epoch 20/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.9125 - dice_coeff: 0.5971 - loss: 0.2420 - mean_absolute_error: 0.2873 - mean_io_u_16: 0.3635 - precision_16: 0.7893 - recall_16: 0.9237
# Epoch 20: loss improved from 0.22527 to 0.22445, saving model to model_BT-Unet_5.keras
#
# Epoch 20: finished saving model to model_BT-Unet_5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 447ms/step - accuracy: 0.9246 - dice_coeff: 0.6314 - loss: 0.2245 - mean_absolute_error: 0.2785 - mean_io_u_16: 0.3483 - precision_16: 0.8438 - recall_16: 0.9221 - val_accuracy: 0.9241 - val_dice_coeff: 0.4968 - val_loss: 0.3024 - val_mean_absolute_error: 0.3554 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8710 - val_recall_16: 0.8344 - learning_rate: 1.0000e-04
# Epoch 21/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.9064 - dice_coeff: 0.5995 - loss: 0.2403 - mean_absolute_error: 0.2893 - mean_io_u_16: 0.3574 - precision_16: 0.7951 - recall_16: 0.9052
# Epoch 21: loss did not improve from 0.22445
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 430ms/step - accuracy: 0.9189 - dice_coeff: 0.6189 - loss: 0.2287 - mean_absolute_error: 0.2820 - mean_io_u_16: 0.3483 - precision_16: 0.8352 - recall_16: 0.9127 - val_accuracy: 0.9278 - val_dice_coeff: 0.4971 - val_loss: 0.3023 - val_mean_absolute_error: 0.3532 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8877 - val_recall_16: 0.8301 - learning_rate: 1.0000e-04
# Epoch 22/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9326 - dice_coeff: 0.6399 - loss: 0.2162 - mean_absolute_error: 0.2733 - mean_io_u_16: 0.3425 - precision_16: 0.8765 - recall_16: 0.9151
# Epoch 22: loss did not improve from 0.22445
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 432ms/step - accuracy: 0.9246 - dice_coeff: 0.6274 - loss: 0.2249 - mean_absolute_error: 0.2783 - mean_io_u_16: 0.3483 - precision_16: 0.8485 - recall_16: 0.9148 - val_accuracy: 0.9265 - val_dice_coeff: 0.5047 - val_loss: 0.2977 - val_mean_absolute_error: 0.3474 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8804 - val_recall_16: 0.8332 - learning_rate: 1.0000e-04
# Epoch 23/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9330 - dice_coeff: 0.6251 - loss: 0.2247 - mean_absolute_error: 0.2751 - mean_io_u_16: 0.3513 - precision_16: 0.8517 - recall_16: 0.9376
# Epoch 23: loss improved from 0.22445 to 0.22383, saving model to model_BT-Unet_5.keras
#
# Epoch 23: finished saving model to model_BT-Unet_5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 446ms/step - accuracy: 0.9289 - dice_coeff: 0.6210 - loss: 0.2238 - mean_absolute_error: 0.2765 - mean_io_u_16: 0.3483 - precision_16: 0.8584 - recall_16: 0.9167 - val_accuracy: 0.9292 - val_dice_coeff: 0.5079 - val_loss: 0.2958 - val_mean_absolute_error: 0.3439 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8892 - val_recall_16: 0.8343 - learning_rate: 1.0000e-04
# Epoch 24/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.9219 - dice_coeff: 0.6125 - loss: 0.2327 - mean_absolute_error: 0.2803 - mean_io_u_16: 0.3568 - precision_16: 0.8223 - recall_16: 0.9254
# Epoch 24: loss improved from 0.22383 to 0.22285, saving model to model_BT-Unet_5.keras
#
# Epoch 24: finished saving model to model_BT-Unet_5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 448ms/step - accuracy: 0.9262 - dice_coeff: 0.6329 - loss: 0.2229 - mean_absolute_error: 0.2759 - mean_io_u_16: 0.3483 - precision_16: 0.8461 - recall_16: 0.9251 - val_accuracy: 0.9325 - val_dice_coeff: 0.5114 - val_loss: 0.2937 - val_mean_absolute_error: 0.3411 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8930 - val_recall_16: 0.8437 - learning_rate: 1.0000e-04
# Epoch 25/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.9279 - dice_coeff: 0.6148 - loss: 0.2309 - mean_absolute_error: 0.2773 - mean_io_u_16: 0.3600 - precision_16: 0.8228 - recall_16: 0.9468
# Epoch 25: loss improved from 0.22285 to 0.22205, saving model to model_BT-Unet_5.keras
#
# Epoch 25: finished saving model to model_BT-Unet_5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 449ms/step - accuracy: 0.9291 - dice_coeff: 0.6256 - loss: 0.2220 - mean_absolute_error: 0.2752 - mean_io_u_16: 0.3483 - precision_16: 0.8548 - recall_16: 0.9232 - val_accuracy: 0.9342 - val_dice_coeff: 0.5161 - val_loss: 0.2909 - val_mean_absolute_error: 0.3357 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.9052 - val_recall_16: 0.8371 - learning_rate: 1.0000e-04
# Epoch 26/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.9335 - dice_coeff: 0.6316 - loss: 0.2211 - mean_absolute_error: 0.2724 - mean_io_u_16: 0.3511 - precision_16: 0.8520 - recall_16: 0.9398
# Epoch 26: loss improved from 0.22205 to 0.22083, saving model to model_BT-Unet_5.keras
#
# Epoch 26: finished saving model to model_BT-Unet_5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 447ms/step - accuracy: 0.9301 - dice_coeff: 0.6329 - loss: 0.2208 - mean_absolute_error: 0.2741 - mean_io_u_16: 0.3483 - precision_16: 0.8571 - recall_16: 0.9235 - val_accuracy: 0.9367 - val_dice_coeff: 0.5201 - val_loss: 0.2885 - val_mean_absolute_error: 0.3321 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.9111 - val_recall_16: 0.8409 - learning_rate: 1.0000e-05
# Epoch 27/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9237 - dice_coeff: 0.6200 - loss: 0.2282 - mean_absolute_error: 0.2788 - mean_io_u_16: 0.3542 - precision_16: 0.8348 - recall_16: 0.9206
# Epoch 27: loss did not improve from 0.22083
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 432ms/step - accuracy: 0.9257 - dice_coeff: 0.6329 - loss: 0.2228 - mean_absolute_error: 0.2763 - mean_io_u_16: 0.3483 - precision_16: 0.8491 - recall_16: 0.9183 - val_accuracy: 0.9389 - val_dice_coeff: 0.5241 - val_loss: 0.2861 - val_mean_absolute_error: 0.3281 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.9174 - val_recall_16: 0.8431 - learning_rate: 1.0000e-05
# Epoch 28/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9355 - dice_coeff: 0.6377 - loss: 0.2173 - mean_absolute_error: 0.2721 - mean_io_u_16: 0.3436 - precision_16: 0.8823 - recall_16: 0.9162
# Epoch 28: loss did not improve from 0.22083
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 428ms/step - accuracy: 0.9243 - dice_coeff: 0.6233 - loss: 0.2247 - mean_absolute_error: 0.2773 - mean_io_u_16: 0.3483 - precision_16: 0.8446 - recall_16: 0.9198 - val_accuracy: 0.9412 - val_dice_coeff: 0.5285 - val_loss: 0.2835 - val_mean_absolute_error: 0.3239 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.9235 - val_recall_16: 0.8461 - learning_rate: 1.0000e-05
# Epoch 29/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9284 - dice_coeff: 0.6371 - loss: 0.2178 - mean_absolute_error: 0.2744 - mean_io_u_16: 0.3426 - precision_16: 0.8633 - recall_16: 0.9172
# Epoch 29: loss did not improve from 0.22083
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 430ms/step - accuracy: 0.9271 - dice_coeff: 0.6310 - loss: 0.2227 - mean_absolute_error: 0.2763 - mean_io_u_16: 0.3483 - precision_16: 0.8517 - recall_16: 0.9201 - val_accuracy: 0.9432 - val_dice_coeff: 0.5330 - val_loss: 0.2807 - val_mean_absolute_error: 0.3202 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.9266 - val_recall_16: 0.8512 - learning_rate: 1.0000e-05
# Epoch 30/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.9317 - dice_coeff: 0.6273 - loss: 0.2237 - mean_absolute_error: 0.2745 - mean_io_u_16: 0.3515 - precision_16: 0.8468 - recall_16: 0.9400
# Epoch 30: loss did not improve from 0.22083
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 431ms/step - accuracy: 0.9307 - dice_coeff: 0.6330 - loss: 0.2221 - mean_absolute_error: 0.2748 - mean_io_u_16: 0.3483 - precision_16: 0.8576 - recall_16: 0.9251 - val_accuracy: 0.9444 - val_dice_coeff: 0.5386 - val_loss: 0.2774 - val_mean_absolute_error: 0.3162 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.9258 - val_recall_16: 0.8567 - learning_rate: 1.0000e-05
# Epoch 31/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9298 - dice_coeff: 0.6224 - loss: 0.2266 - mean_absolute_error: 0.2760 - mean_io_u_16: 0.3499 - precision_16: 0.8550 - recall_16: 0.9235
# Epoch 31: loss did not improve from 0.22083
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 430ms/step - accuracy: 0.9257 - dice_coeff: 0.6239 - loss: 0.2264 - mean_absolute_error: 0.2774 - mean_io_u_16: 0.3483 - precision_16: 0.8517 - recall_16: 0.9144 - val_accuracy: 0.9453 - val_dice_coeff: 0.5441 - val_loss: 0.2741 - val_mean_absolute_error: 0.3121 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.9243 - val_recall_16: 0.8624 - learning_rate: 1.0000e-05
# Epoch 32/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.9255 - dice_coeff: 0.6188 - loss: 0.2281 - mean_absolute_error: 0.2768 - mean_io_u_16: 0.3559 - precision_16: 0.8319 - recall_16: 0.9296
# Epoch 32: loss did not improve from 0.22083
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 428ms/step - accuracy: 0.9297 - dice_coeff: 0.6168 - loss: 0.2224 - mean_absolute_error: 0.2747 - mean_io_u_16: 0.3483 - precision_16: 0.8574 - recall_16: 0.9215 - val_accuracy: 0.9461 - val_dice_coeff: 0.5496 - val_loss: 0.2708 - val_mean_absolute_error: 0.3083 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.9219 - val_recall_16: 0.8681 - learning_rate: 1.0000e-05
# Epoch 33/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.9279 - dice_coeff: 0.6344 - loss: 0.2193 - mean_absolute_error: 0.2745 - mean_io_u_16: 0.3424 - precision_16: 0.8612 - recall_16: 0.9189
# Epoch 33: loss did not improve from 0.22083
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 430ms/step - accuracy: 0.9239 - dice_coeff: 0.6226 - loss: 0.2255 - mean_absolute_error: 0.2774 - mean_io_u_16: 0.3483 - precision_16: 0.8444 - recall_16: 0.9186 - val_accuracy: 0.9463 - val_dice_coeff: 0.5551 - val_loss: 0.2675 - val_mean_absolute_error: 0.3046 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.9181 - val_recall_16: 0.8733 - learning_rate: 1.0000e-05
# Epoch 34/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9319 - dice_coeff: 0.6362 - loss: 0.2177 - mean_absolute_error: 0.2725 - mean_io_u_16: 0.3442 - precision_16: 0.8693 - recall_16: 0.9200
# Epoch 34: loss did not improve from 0.22083
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 427ms/step - accuracy: 0.9319 - dice_coeff: 0.6190 - loss: 0.2212 - mean_absolute_error: 0.2730 - mean_io_u_16: 0.3483 - precision_16: 0.8562 - recall_16: 0.9320 - val_accuracy: 0.9467 - val_dice_coeff: 0.5597 - val_loss: 0.2648 - val_mean_absolute_error: 0.3011 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.9162 - val_recall_16: 0.8772 - learning_rate: 1.0000e-05
# Epoch 35/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9122 - dice_coeff: 0.6169 - loss: 0.2300 - mean_absolute_error: 0.2823 - mean_io_u_16: 0.3506 - precision_16: 0.8175 - recall_16: 0.9088
# Epoch 35: loss did not improve from 0.22083
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 431ms/step - accuracy: 0.9292 - dice_coeff: 0.6323 - loss: 0.2223 - mean_absolute_error: 0.2747 - mean_io_u_16: 0.3483 - precision_16: 0.8555 - recall_16: 0.9226 - val_accuracy: 0.9467 - val_dice_coeff: 0.5641 - val_loss: 0.2621 - val_mean_absolute_error: 0.2981 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.9120 - val_recall_16: 0.8820 - learning_rate: 1.0000e-05
# Epoch 36/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.9293 - dice_coeff: 0.6330 - loss: 0.2204 - mean_absolute_error: 0.2740 - mean_io_u_16: 0.3474 - precision_16: 0.8557 - recall_16: 0.9247
# Epoch 36: loss did not improve from 0.22083
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 429ms/step - accuracy: 0.9273 - dice_coeff: 0.6330 - loss: 0.2223 - mean_absolute_error: 0.2754 - mean_io_u_16: 0.3483 - precision_16: 0.8528 - recall_16: 0.9191 - val_accuracy: 0.9467 - val_dice_coeff: 0.5682 - val_loss: 0.2597 - val_mean_absolute_error: 0.2953 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.9087 - val_recall_16: 0.8862 - learning_rate: 1.0000e-06
# Epoch 37/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.9334 - dice_coeff: 0.6337 - loss: 0.2195 - mean_absolute_error: 0.2718 - mean_io_u_16: 0.3501 - precision_16: 0.8509 - recall_16: 0.9435
# Epoch 37: loss improved from 0.22083 to 0.22022, saving model to model_BT-Unet_5.keras
#
# Epoch 37: finished saving model to model_BT-Unet_5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 445ms/step - accuracy: 0.9293 - dice_coeff: 0.6283 - loss: 0.2202 - mean_absolute_error: 0.2740 - mean_io_u_16: 0.3483 - precision_16: 0.8541 - recall_16: 0.9250 - val_accuracy: 0.9467 - val_dice_coeff: 0.5723 - val_loss: 0.2572 - val_mean_absolute_error: 0.2925 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.9052 - val_recall_16: 0.8902 - learning_rate: 1.0000e-06
# Epoch 38/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.9280 - dice_coeff: 0.6371 - loss: 0.2167 - mean_absolute_error: 0.2740 - mean_io_u_16: 0.3411 - precision_16: 0.8667 - recall_16: 0.9142
# Epoch 38: loss did not improve from 0.22022
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 430ms/step - accuracy: 0.9289 - dice_coeff: 0.6062 - loss: 0.2240 - mean_absolute_error: 0.2758 - mean_io_u_16: 0.3483 - precision_16: 0.8555 - recall_16: 0.9213 - val_accuracy: 0.9463 - val_dice_coeff: 0.5759 - val_loss: 0.2551 - val_mean_absolute_error: 0.2902 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.9006 - val_recall_16: 0.8942 - learning_rate: 1.0000e-06
# Epoch 39/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9341 - dice_coeff: 0.6244 - loss: 0.2253 - mean_absolute_error: 0.2746 - mean_io_u_16: 0.3542 - precision_16: 0.8508 - recall_16: 0.9387
# Epoch 39: loss did not improve from 0.22022
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 432ms/step - accuracy: 0.9312 - dice_coeff: 0.6302 - loss: 0.2213 - mean_absolute_error: 0.2743 - mean_io_u_16: 0.3483 - precision_16: 0.8612 - recall_16: 0.9217 - val_accuracy: 0.9458 - val_dice_coeff: 0.5791 - val_loss: 0.2532 - val_mean_absolute_error: 0.2882 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8962 - val_recall_16: 0.8975 - learning_rate: 1.0000e-06
# Epoch 40/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9324 - dice_coeff: 0.6326 - loss: 0.2201 - mean_absolute_error: 0.2728 - mean_io_u_16: 0.3480 - precision_16: 0.8566 - recall_16: 0.9342
# Epoch 40: loss did not improve from 0.22022
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 430ms/step - accuracy: 0.9312 - dice_coeff: 0.6246 - loss: 0.2213 - mean_absolute_error: 0.2742 - mean_io_u_16: 0.3483 - precision_16: 0.8578 - recall_16: 0.9269 - val_accuracy: 0.9453 - val_dice_coeff: 0.5820 - val_loss: 0.2514 - val_mean_absolute_error: 0.2865 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8919 - val_recall_16: 0.9008 - learning_rate: 1.0000e-06
# Epoch 41/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.9205 - dice_coeff: 0.6057 - loss: 0.2361 - mean_absolute_error: 0.2822 - mean_io_u_16: 0.3591 - precision_16: 0.8180 - recall_16: 0.9232
# Epoch 41: loss did not improve from 0.22022
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 430ms/step - accuracy: 0.9230 - dice_coeff: 0.6115 - loss: 0.2268 - mean_absolute_error: 0.2787 - mean_io_u_16: 0.3483 - precision_16: 0.8415 - recall_16: 0.9195 - val_accuracy: 0.9451 - val_dice_coeff: 0.5850 - val_loss: 0.2496 - val_mean_absolute_error: 0.2844 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8892 - val_recall_16: 0.9033 - learning_rate: 1.0000e-06
# Epoch 42/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.9354 - dice_coeff: 0.6387 - loss: 0.2162 - mean_absolute_error: 0.2708 - mean_io_u_16: 0.3455 - precision_16: 0.8768 - recall_16: 0.9207
# Epoch 42: loss improved from 0.22022 to 0.21978, saving model to model_BT-Unet_5.keras
#
# Epoch 42: finished saving model to model_BT-Unet_5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 448ms/step - accuracy: 0.9321 - dice_coeff: 0.6219 - loss: 0.2198 - mean_absolute_error: 0.2727 - mean_io_u_16: 0.3483 - precision_16: 0.8598 - recall_16: 0.9277 - val_accuracy: 0.9446 - val_dice_coeff: 0.5872 - val_loss: 0.2483 - val_mean_absolute_error: 0.2829 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8861 - val_recall_16: 0.9055 - learning_rate: 1.0000e-06
# Epoch 43/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.9315 - dice_coeff: 0.6260 - loss: 0.2246 - mean_absolute_error: 0.2745 - mean_io_u_16: 0.3541 - precision_16: 0.8482 - recall_16: 0.9329
# Epoch 43: loss did not improve from 0.21978
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 431ms/step - accuracy: 0.9333 - dice_coeff: 0.6374 - loss: 0.2199 - mean_absolute_error: 0.2728 - mean_io_u_16: 0.3483 - precision_16: 0.8639 - recall_16: 0.9261 - val_accuracy: 0.9443 - val_dice_coeff: 0.5892 - val_loss: 0.2471 - val_mean_absolute_error: 0.2815 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8834 - val_recall_16: 0.9077 - learning_rate: 1.0000e-06
# Epoch 44/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.9329 - dice_coeff: 0.6353 - loss: 0.2187 - mean_absolute_error: 0.2730 - mean_io_u_16: 0.3455 - precision_16: 0.8719 - recall_16: 0.9178
# Epoch 44: loss did not improve from 0.21978
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 431ms/step - accuracy: 0.9293 - dice_coeff: 0.6264 - loss: 0.2225 - mean_absolute_error: 0.2748 - mean_io_u_16: 0.3483 - precision_16: 0.8560 - recall_16: 0.9219 - val_accuracy: 0.9440 - val_dice_coeff: 0.5911 - val_loss: 0.2460 - val_mean_absolute_error: 0.2803 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8809 - val_recall_16: 0.9096 - learning_rate: 1.0000e-06
# Epoch 45/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.9296 - dice_coeff: 0.6351 - loss: 0.2191 - mean_absolute_error: 0.2738 - mean_io_u_16: 0.3441 - precision_16: 0.8559 - recall_16: 0.9288
# Epoch 45: loss did not improve from 0.21978
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 431ms/step - accuracy: 0.9305 - dice_coeff: 0.6317 - loss: 0.2232 - mean_absolute_error: 0.2753 - mean_io_u_16: 0.3483 - precision_16: 0.8561 - recall_16: 0.9266 - val_accuracy: 0.9433 - val_dice_coeff: 0.5929 - val_loss: 0.2449 - val_mean_absolute_error: 0.2792 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8772 - val_recall_16: 0.9115 - learning_rate: 1.0000e-06
# Epoch 46/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.9300 - dice_coeff: 0.6230 - loss: 0.2255 - mean_absolute_error: 0.2748 - mean_io_u_16: 0.3535 - precision_16: 0.8398 - recall_16: 0.9417
# Epoch 46: loss did not improve from 0.21978
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 429ms/step - accuracy: 0.9249 - dice_coeff: 0.6121 - loss: 0.2247 - mean_absolute_error: 0.2764 - mean_io_u_16: 0.3483 - precision_16: 0.8468 - recall_16: 0.9187 - val_accuracy: 0.9424 - val_dice_coeff: 0.5945 - val_loss: 0.2439 - val_mean_absolute_error: 0.2785 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8727 - val_recall_16: 0.9137 - learning_rate: 1.0000e-06
# Epoch 47/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9240 - dice_coeff: 0.6241 - loss: 0.2258 - mean_absolute_error: 0.2770 - mean_io_u_16: 0.3522 - precision_16: 0.8363 - recall_16: 0.9250
# Epoch 47: loss did not improve from 0.21978
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 431ms/step - accuracy: 0.9260 - dice_coeff: 0.6323 - loss: 0.2234 - mean_absolute_error: 0.2763 - mean_io_u_16: 0.3483 - precision_16: 0.8533 - recall_16: 0.9131 - val_accuracy: 0.9418 - val_dice_coeff: 0.5958 - val_loss: 0.2431 - val_mean_absolute_error: 0.2777 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8696 - val_recall_16: 0.9154 - learning_rate: 1.0000e-06
# Epoch 48/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.9321 - dice_coeff: 0.6253 - loss: 0.2246 - mean_absolute_error: 0.2746 - mean_io_u_16: 0.3530 - precision_16: 0.8468 - recall_16: 0.9392
# Epoch 48: loss did not improve from 0.21978
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 430ms/step - accuracy: 0.9322 - dice_coeff: 0.6259 - loss: 0.2217 - mean_absolute_error: 0.2740 - mean_io_u_16: 0.3483 - precision_16: 0.8610 - recall_16: 0.9258 - val_accuracy: 0.9409 - val_dice_coeff: 0.5969 - val_loss: 0.2425 - val_mean_absolute_error: 0.2773 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8657 - val_recall_16: 0.9173 - learning_rate: 1.0000e-06
# Epoch 49/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.9268 - dice_coeff: 0.6290 - loss: 0.2229 - mean_absolute_error: 0.2749 - mean_io_u_16: 0.3487 - precision_16: 0.8504 - recall_16: 0.9210
# Epoch 49: loss did not improve from 0.21978
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 429ms/step - accuracy: 0.9258 - dice_coeff: 0.6303 - loss: 0.2247 - mean_absolute_error: 0.2761 - mean_io_u_16: 0.3483 - precision_16: 0.8467 - recall_16: 0.9223 - val_accuracy: 0.9406 - val_dice_coeff: 0.5979 - val_loss: 0.2419 - val_mean_absolute_error: 0.2766 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8640 - val_recall_16: 0.9183 - learning_rate: 1.0000e-06
# Epoch 50/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.9330 - dice_coeff: 0.6371 - loss: 0.2178 - mean_absolute_error: 0.2719 - mean_io_u_16: 0.3467 - precision_16: 0.8594 - recall_16: 0.9341
# Epoch 50: loss did not improve from 0.21978
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 433ms/step - accuracy: 0.9321 - dice_coeff: 0.6341 - loss: 0.2201 - mean_absolute_error: 0.2733 - mean_io_u_16: 0.3483 - precision_16: 0.8589 - recall_16: 0.9287 - val_accuracy: 0.9405 - val_dice_coeff: 0.5991 - val_loss: 0.2412 - val_mean_absolute_error: 0.2756 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8633 - val_recall_16: 0.9189 - learning_rate: 1.0000e-06
# Epoch 51/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.9305 - dice_coeff: 0.6361 - loss: 0.2172 - mean_absolute_error: 0.2731 - mean_io_u_16: 0.3411 - precision_16: 0.8734 - recall_16: 0.9141
# Epoch 51: loss did not improve from 0.21978
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 431ms/step - accuracy: 0.9238 - dice_coeff: 0.5986 - loss: 0.2264 - mean_absolute_error: 0.2770 - mean_io_u_16: 0.3483 - precision_16: 0.8427 - recall_16: 0.9208 - val_accuracy: 0.9401 - val_dice_coeff: 0.6001 - val_loss: 0.2406 - val_mean_absolute_error: 0.2750 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8613 - val_recall_16: 0.9199 - learning_rate: 1.0000e-06
# Epoch 52/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9283 - dice_coeff: 0.6431 - loss: 0.2140 - mean_absolute_error: 0.2729 - mean_io_u_16: 0.3356 - precision_16: 0.8764 - recall_16: 0.9099
# Epoch 52: loss did not improve from 0.21978
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 428ms/step - accuracy: 0.9238 - dice_coeff: 0.6228 - loss: 0.2251 - mean_absolute_error: 0.2771 - mean_io_u_16: 0.3483 - precision_16: 0.8438 - recall_16: 0.9190 - val_accuracy: 0.9399 - val_dice_coeff: 0.6009 - val_loss: 0.2401 - val_mean_absolute_error: 0.2744 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8601 - val_recall_16: 0.9206 - learning_rate: 1.0000e-06
# Epoch 53/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9309 - dice_coeff: 0.6213 - loss: 0.2275 - mean_absolute_error: 0.2756 - mean_io_u_16: 0.3553 - precision_16: 0.8424 - recall_16: 0.9363
# Epoch 53: loss did not improve from 0.21978
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 429ms/step - accuracy: 0.9284 - dice_coeff: 0.6327 - loss: 0.2238 - mean_absolute_error: 0.2759 - mean_io_u_16: 0.3483 - precision_16: 0.8508 - recall_16: 0.9265 - val_accuracy: 0.9396 - val_dice_coeff: 0.6014 - val_loss: 0.2398 - val_mean_absolute_error: 0.2740 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8591 - val_recall_16: 0.9212 - learning_rate: 1.0000e-06
# Epoch 54/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.9277 - dice_coeff: 0.6330 - loss: 0.2204 - mean_absolute_error: 0.2751 - mean_io_u_16: 0.3451 - precision_16: 0.8583 - recall_16: 0.9183
# Epoch 54: loss did not improve from 0.21978
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 428ms/step - accuracy: 0.9272 - dice_coeff: 0.6308 - loss: 0.2236 - mean_absolute_error: 0.2763 - mean_io_u_16: 0.3483 - precision_16: 0.8540 - recall_16: 0.9168 - val_accuracy: 0.9393 - val_dice_coeff: 0.6020 - val_loss: 0.2394 - val_mean_absolute_error: 0.2737 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8573 - val_recall_16: 0.9222 - learning_rate: 1.0000e-06
# Epoch 55/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.9383 - dice_coeff: 0.6340 - loss: 0.2199 - mean_absolute_error: 0.2715 - mean_io_u_16: 0.3507 - precision_16: 0.8656 - recall_16: 0.9401
# Epoch 55: loss did not improve from 0.21978
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 428ms/step - accuracy: 0.9322 - dice_coeff: 0.6376 - loss: 0.2209 - mean_absolute_error: 0.2741 - mean_io_u_16: 0.3483 - precision_16: 0.8618 - recall_16: 0.9248 - val_accuracy: 0.9396 - val_dice_coeff: 0.6026 - val_loss: 0.2391 - val_mean_absolute_error: 0.2730 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8584 - val_recall_16: 0.9221 - learning_rate: 1.0000e-06
# Epoch 56/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.9282 - dice_coeff: 0.6291 - loss: 0.2222 - mean_absolute_error: 0.2746 - mean_io_u_16: 0.3490 - precision_16: 0.8479 - recall_16: 0.9287
# Epoch 56: loss did not improve from 0.21978
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 429ms/step - accuracy: 0.9294 - dice_coeff: 0.6233 - loss: 0.2217 - mean_absolute_error: 0.2745 - mean_io_u_16: 0.3483 - precision_16: 0.8531 - recall_16: 0.9267 - val_accuracy: 0.9389 - val_dice_coeff: 0.6031 - val_loss: 0.2388 - val_mean_absolute_error: 0.2730 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8555 - val_recall_16: 0.9232 - learning_rate: 1.0000e-06
# Epoch 57/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.9253 - dice_coeff: 0.6271 - loss: 0.2239 - mean_absolute_error: 0.2759 - mean_io_u_16: 0.3508 - precision_16: 0.8398 - recall_16: 0.9273
# Epoch 57: loss did not improve from 0.21978
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 428ms/step - accuracy: 0.9292 - dice_coeff: 0.6359 - loss: 0.2203 - mean_absolute_error: 0.2738 - mean_io_u_16: 0.3483 - precision_16: 0.8525 - recall_16: 0.9270 - val_accuracy: 0.9385 - val_dice_coeff: 0.6036 - val_loss: 0.2385 - val_mean_absolute_error: 0.2728 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8537 - val_recall_16: 0.9239 - learning_rate: 1.0000e-06
# Epoch 58/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.9207 - dice_coeff: 0.6237 - loss: 0.2256 - mean_absolute_error: 0.2778 - mean_io_u_16: 0.3505 - precision_16: 0.8287 - recall_16: 0.9248
# Epoch 58: loss did not improve from 0.21978
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 426ms/step - accuracy: 0.9285 - dice_coeff: 0.6265 - loss: 0.2223 - mean_absolute_error: 0.2749 - mean_io_u_16: 0.3483 - precision_16: 0.8500 - recall_16: 0.9280 - val_accuracy: 0.9380 - val_dice_coeff: 0.6038 - val_loss: 0.2383 - val_mean_absolute_error: 0.2728 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8519 - val_recall_16: 0.9247 - learning_rate: 1.0000e-06
# Epoch 59/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.9352 - dice_coeff: 0.6370 - loss: 0.2177 - mean_absolute_error: 0.2713 - mean_io_u_16: 0.3455 - precision_16: 0.8694 - recall_16: 0.9301
# Epoch 59: loss did not improve from 0.21978
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - accuracy: 0.9330 - dice_coeff: 0.6301 - loss: 0.2205 - mean_absolute_error: 0.2729 - mean_io_u_16: 0.3483 - precision_16: 0.8608 - recall_16: 0.9294 - val_accuracy: 0.9378 - val_dice_coeff: 0.6042 - val_loss: 0.2381 - val_mean_absolute_error: 0.2726 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8508 - val_recall_16: 0.9251 - learning_rate: 1.0000e-06
# Epoch 60/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9322 - dice_coeff: 0.6397 - loss: 0.2156 - mean_absolute_error: 0.2712 - mean_io_u_16: 0.3437 - precision_16: 0.8701 - recall_16: 0.9219
# Epoch 60: loss did not improve from 0.21978
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - accuracy: 0.9283 - dice_coeff: 0.6178 - loss: 0.2217 - mean_absolute_error: 0.2743 - mean_io_u_16: 0.3483 - precision_16: 0.8530 - recall_16: 0.9226 - val_accuracy: 0.9374 - val_dice_coeff: 0.6045 - val_loss: 0.2379 - val_mean_absolute_error: 0.2726 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8493 - val_recall_16: 0.9257 - learning_rate: 1.0000e-06
# Epoch 61/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.9341 - dice_coeff: 0.6402 - loss: 0.2161 - mean_absolute_error: 0.2719 - mean_io_u_16: 0.3425 - precision_16: 0.8804 - recall_16: 0.9149
# Epoch 61: loss did not improve from 0.21978
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 429ms/step - accuracy: 0.9272 - dice_coeff: 0.6315 - loss: 0.2237 - mean_absolute_error: 0.2758 - mean_io_u_16: 0.3483 - precision_16: 0.8533 - recall_16: 0.9177 - val_accuracy: 0.9375 - val_dice_coeff: 0.6049 - val_loss: 0.2377 - val_mean_absolute_error: 0.2723 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8495 - val_recall_16: 0.9258 - learning_rate: 1.0000e-06
# Epoch 62/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.9301 - dice_coeff: 0.6311 - loss: 0.2214 - mean_absolute_error: 0.2737 - mean_io_u_16: 0.3482 - precision_16: 0.8544 - recall_16: 0.9276
# Epoch 62: loss did not improve from 0.21978
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 430ms/step - accuracy: 0.9271 - dice_coeff: 0.6303 - loss: 0.2226 - mean_absolute_error: 0.2755 - mean_io_u_16: 0.3483 - precision_16: 0.8520 - recall_16: 0.9195 - val_accuracy: 0.9373 - val_dice_coeff: 0.6050 - val_loss: 0.2376 - val_mean_absolute_error: 0.2723 - val_mean_io_u_16: 0.3687 - val_precision_16: 0.8489 - val_recall_16: 0.9261 - learning_rate: 1.0000e-06
# Epoch 62: early stopping

# %% [markdown]
# # Evaluate the results

# %%
preds_train = model.predict(X_train_20[:int(X_train_20.shape[0]*(1-val_split))], verbose=1)
preds_x = model.predict(X_train, verbose=1)
preds_val = model.predict(X_train_20[int(X_train_20.shape[0]*(1-val_split)):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

gt_train = Y_train_20[:int(X_train_20.shape[0]*(1-val_split))].astype(np.float32)
gt_x = Y_train.astype(np.float32)
gt_val = Y_train_20[int(X_train_20.shape[0]*(1-val_split)):].astype(np.float32)
gt_test = Y_test.astype(np.float32)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 926ms/step
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 30s 367ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 377ms/step

# %%
# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.float32)
preds_x_t = (preds_x > 0.5).astype(np.float32)
preds_val_t = (preds_val > 0.5).astype(np.float32)
preds_test_t = (preds_test > 0.5).astype(np.float32)

# %%
evalResult(gt_train, preds_train_t)
# Out:
# Accuracy= 0.9359767 Precision= 0.8765118 Recall= 0.91835064 MeanIoU= 0.8621969 DiceCoefficient= 0.8862204995420244 HD= 5.281076585026964 MyIoU= 0.6240123456790119 MAE= 0.06402334

# %%
evalResult(gt_val, preds_val_t)
# Out:
# Accuracy= 0.93730944 Precision= 0.8488686 Recall= 0.9260611 MeanIoU= 0.85608125 DiceCoefficient= 0.8757631648809482 HD= 5.24651188249466 MyIoU= 0.5617948717948718 MAE= 0.06269054

# %%
evalResult(gt_x, preds_x_t)
# Out:
# Accuracy= 0.7912331 Precision= 0.5271589 Recall= 0.86117405 MeanIoU= 0.61289567 DiceCoefficient= 0.6626404342726345 HD= 7.668749121834625 MyIoU= 0.32199750291219703 MAE= 0.20876694

# %%
evalResult(gt_test, preds_test_t)
# Out:
# Accuracy= 0.7779741 Precision= 0.5845453 Recall= 0.8626167 MeanIoU= 0.618329 DiceCoefficient= 0.6917761235344569 HD= 8.439988138597164 MyIoU= 0.2500339226051725 MAE= 0.22202589

# %% [markdown]
# # Output

# %%
print(preds_train_t.shape[0])  # tells you the max valid index + 1
# Out:
# 90

# %%
x=0
xx = [85,10,15]
for i in range(3):
    plt.figure(figsize=(10,10))
    #ix = random.randint(0, len(preds_train))
    ix = xx[i]
    #print(ix)
    #ix = 58
    plt.subplot(3,3,x+1)
    imshow(X_train[:int(X_train.shape[0]*(1-val_split))][ix].astype('uint8'))
    #plt.title('Image')

    plt.subplot(3,3,x+2)
    imshow(np.squeeze(Y_train[:int(Y_train.shape[0]*(1-val_split))][ix]))
    #plt.title('Mask')

    plt.subplot(3,3,x+3)
    imshow(np.squeeze(preds_train_t[ix]))
    #plt.title('Predicted Mask')
    #plt.show()
    
    plt.show()
    evalResult(Y_train[:int(Y_train.shape[0]*(1-val_split))][ix], preds_train_t[ix])
    x = x+3
# Out:
# Accuracy= 0.965271 Precision= 0.6630451 Recall= 0.9973136 MeanIoU= 0.8123005 DiceCoefficient= 0.8550392358447425 HD= 3.3166247903554 MyIoU= 0.16406249999999994 MAE= 0.034729004
# Accuracy= 0.99176025 Precision= 0.98275775 Recall= 0.98921144 MeanIoU= 0.98036855 DiceCoefficient= 0.977131572100916 HD= 3.872983346207417 MyIoU= 0.64765625 MAE= 0.008239746
# Accuracy= 0.94062805 Precision= 0.81191283 Recall= 0.99958265 MeanIoU= 0.8659275 DiceCoefficient= 0.8708664436053368 HD= 4.47213595499958 MyIoU= 0.38203124999999977 MAE= 0.05937195

# %%
x=0
xx = [16,10,15]
for i in range(3):
    plt.figure(figsize=(10,10))
    #ix = random.randint(0, len(preds_train))
    ix = xx[i]
    #print(ix)
    #ix = 58
    plt.subplot(3,3,x+1)
    imshow(X_test[ix].astype('uint8'))
    #plt.title('Image')

    plt.subplot(3,3,x+2)
    imshow(np.squeeze(Y_test[ix]))
    #plt.title('Mask')

    plt.subplot(3,3,x+3)
    imshow(np.squeeze(preds_test_t[ix]))
    #plt.title('Predicted Mask')
    #plt.show()
    
    plt.show()
    evalResult(Y_test[ix], preds_test_t[ix])
    x = x+3
# Out:
# Accuracy= 0.9842682 Precision= 0.7099859 Recall= 1.0 MeanIoU= 0.846812 DiceCoefficient= 0.8617437069260632 HD= 4.123105625617661 MyIoU= 0.15078125 MAE= 0.015731812
# Accuracy= 0.15522766 Precision= 0.045811 Recall= 1.0 MeanIoU= 0.08266408 DiceCoefficient= 0.079670235825688 HD= 13.892443989449804 MyIoU= 0.0 MAE= 0.84477234
# Accuracy= 0.98143005 Precision= 0.89115715 Recall= 0.98029333 MeanIoU= 0.92705745 DiceCoefficient= 0.9269698042262462 HD= 3.7416573867739413 MyIoU= 0.42304687500000016 MAE= 0.018569946

# %%
import tensorflow as tf
from tensorflow.keras.metrics import *
from tensorflow.keras.layers import *
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.applications import *
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras.callbacks import *
from tensorflow.keras import backend as K
from hausdorff import hausdorff_distance
from tensorflow.keras.regularizers import l2

import os
import random
import numpy as np
from tqdm import tqdm
from skimage.io import imread,imshow
from skimage.morphology import label
from skimage.transform import resize
import matplotlib.pyplot as plt
import datetime

TRAIN_FLG = True

# %% [markdown]
# # Dataset

# %%
import os, shutil, random
from pathlib import Path

SRC = Path("BUSIS")           # your Kaggle download folder
DST = Path("datasets/BUSIS")  # where the notebook looks
TRAIN_RATIO = 0.8

for split in ["train", "test"]:
    (DST / split / "org").mkdir(parents=True, exist_ok=True)
    (DST / split / "gt").mkdir(parents=True, exist_ok=True)

# Collect all image/mask pairs across all categories
pairs = []
for category in ["Benign", "Malignant", "Normal"]:
    cat_dir = SRC / category
    for f in cat_dir.iterdir():
        if "_mask" not in f.name and f.suffix in [".png", ".bmp"]:
            mask = cat_dir / (f.stem + "_mask" + f.suffix)
            if mask.exists():
                pairs.append((f, mask))

random.seed(42)
random.shuffle(pairs)
split_idx = int(len(pairs) * TRAIN_RATIO)
train_pairs = pairs[:split_idx]
test_pairs  = pairs[split_idx:]

def copy_pair(pairs, split):
    for i, (img, mask) in enumerate(pairs):
        # e.g. img_0001.png and img_0001_GT.png
        new_stem = f"img_{i+1:04d}"
        new_img  = new_stem + img.suffix
        new_mask = new_stem + "_GT" + img.suffix

        shutil.copy(img,  DST / split / "org" / new_img)
        shutil.copy(mask, DST / split / "gt"  / new_mask)

copy_pair(train_pairs, "train")
copy_pair(test_pairs,  "test")

print(f"Train: {len(train_pairs)}, Test: {len(test_pairs)}")
# Out:
# Train: 624, Test: 156

# %%
TRAIN_PATH="datasets/BUSIS/train/"
TEST_PATH="datasets/BUSIS/test/"

# %%
train_ids=next(os.walk(TRAIN_PATH+'org/'))[2][:]
test_ids=next(os.walk(TEST_PATH+'org/'))[2][:]
print(len(train_ids))
# Out:
# 624

# %%
input_height = IMG_HEIGHT = 256
input_width = IMG_WIDTH = 256
IMG_CHANNELS = 3

# %%
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.float32)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.float32)
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.float32)
Y_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.float32)

print('Resizing training images and masks')
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):   
    path = TRAIN_PATH + 'org/' + id_
    img = imread(path)[:,:,:IMG_CHANNELS]  
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img #/ 255. #Fill empty X_train with values from img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=bool)
    mask_path = TRAIN_PATH + 'gt/' + id_[:-4] + '_GT.png' # changed this from bmp to png to match the new naming convention
    mask = imread(mask_path)
    mask = np.expand_dims(mask, axis=-1)
    mask = resize(mask, (input_width, input_height, 1), mode='constant', preserve_range=True) # changed this line added 1 to the target shape to maintain the channel dimension
    mask = mask/255
    Y_train[n][mask[:,:,0] > 0.] = 1. # Chamged this line to squeeze the mask before comparison

print('Resizing test images and masks')
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):   
    path = TEST_PATH + 'org/' + id_
    img = imread(path)[:,:,:IMG_CHANNELS]   
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img #/ 255. #Fill empty X_train with values from img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=bool)
    mask_path = TEST_PATH + 'gt/' + id_[:-4] + '_GT.png' # changed this from bmp to png to match the new naming convention
    mask = imread(mask_path)
    mask = np.expand_dims(mask, axis=-1)
    mask = resize(mask, (input_width, input_height, 1), mode='constant', preserve_range=True) # changed this line added 1 to the target shape to maintain the channel dimension
    mask = mask/255
    Y_test[n][mask[:,:,0] > 0.] = 1. # Changes this line to squeeze the mask before comparison
# Out:
# Resizing training images and masks
# 100%|██████████| 624/624 [00:16<00:00, 37.10it/s]
# Resizing test images and masks
# 100%|██████████| 156/156 [00:04<00:00, 35.39it/s]

# %%
print(X_train.shape, Y_test.shape)
# Out:
# (624, 256, 256, 3) (156, 256, 256, 1)

# %%
ix=0
imshow(X_train[ix].astype('int'))
plt.show()
imshow(np.squeeze(Y_train[ix].astype('int')))
plt.show()

# %%
plt.figure(figsize=(30,30))
x, y = 5, 4
count=1
for i in range(y):
    for j in range(x):
        plt.subplot(y*2, x, i*2*x+j+1)
        pos = i+j
        plt.imshow(X_train[pos].astype('int'))
        plt.title('Image {}'.format(count))
        plt.axis('off')
        plt.subplot(y*2, x, (i*2+1)*x+j+1)
        plt.imshow(np.squeeze(Y_train[pos].astype('int')))
        plt.title('Mask {}'.format(count))
        plt.axis('off')
        count = count + 1
plt.show()

# %% [markdown]
# # Model

# %%
def expend_as(tensor, rep):
     return Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3),
                          arguments={'repnum': rep})(tensor)

def double_conv_layer(x, filter_size, size, dropout, batch_norm=False):
    axis = 3
    conv = SeparableConv2D(size, (filter_size, filter_size), padding='same')(x)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = SeparableConv2D(size, (filter_size, filter_size), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    if dropout > 0:
        conv = Dropout(dropout)(conv)

    shortcut = Conv2D(size, kernel_size=(1, 1), padding='same')(x)
    if batch_norm is True:
        shortcut = BatchNormalization(axis=axis)(shortcut)

    res_path = add([shortcut, conv])
    return res_path

def encoder(inputs):
    num_filters = [16, 32, 64, 128]
    skip_connections = []
    x = inputs

    for i, f in enumerate(num_filters):
        a = double_conv_layer(x, 3, f, 0.1, True)
        skip_connections.append(a)
        x = MaxPooling2D(pool_size=(2, 2))(a)
    
    return x, skip_connections

def bottleneck(inputs):
    x = inputs
    f = 256
    
    x3 = double_conv_layer(x, 3, f, 0.1, True)
    
    return x3

def decoder(inputs, skip_connections):
    num_filters = [128, 64, 32, 16]
    skip_connections.reverse()
    x = inputs
    batch_norm = True
    
    for i, f in enumerate(num_filters):
        
        x_up = UpSampling2D(size=(2, 2), data_format="channels_last")(x)
        x_att = concatenate([x_up, skip_connections[i]], axis=-1)
        
        x = double_conv_layer(x_att, 3, f, 0.1, True)
    return x

def output(inputs):
    x = Conv2D(1, kernel_size=(1,1))(inputs)
    x = BatchNormalization()(x)
    x = Activation('sigmoid')(x)
    
    return x

# %% [markdown]
# # Pre-training

# %% [markdown]
# ## Data Augmentaiton

# %%
def random_resize_crop(image, scale=[0.75, 1.0], crop_size=128):
    if crop_size == 32:
        image_shape = 48
        image = tf.image.resize(image, (image_shape, image_shape))
    else:
        image_shape = 96
        image = tf.image.resize(image, (image_shape, image_shape))
    size = tf.random.uniform(
        shape=(1,),
        minval=scale[0] * image_shape,
        maxval=scale[1] * image_shape,
        dtype=tf.float32,
    )
    size = tf.cast(size, tf.int32)[0]
    crop = tf.image.random_crop(image, (size, size, 3))
    crop_resize = tf.image.resize(crop, (crop_size, crop_size))
    return crop_resize

def flip_random_crop(image):
    image = tf.image.random_flip_left_right(image)
    image = random_resize_crop(image, crop_size=CROP_TO)
    return image


@tf.function
def float_parameter(level, maxval):
    return tf.cast(level * maxval / 10.0, tf.float32)


@tf.function
def sample_level(n):
    return tf.random.uniform(shape=[1], minval=0.1, maxval=n, dtype=tf.float32)

def rotation(image):
    augmented_image = tf.image.rot90(image)
    return augmented_image

@tf.function
def solarize(image, level=6):
    threshold = float_parameter(sample_level(level), 1)
    return tf.where(image < threshold, image, 255 - image)

def color_jitter(x, strength=0.5):
    x = tf.image.random_brightness(x, max_delta=0.8 * strength)
    x = tf.image.random_contrast(
        x, lower=1 - 0.8 * strength, upper=1 + 0.8 * strength
    )
    x = tf.image.random_saturation(
        x, lower=1 - 0.8 * strength, upper=1 + 0.8 * strength
    )
    x = tf.image.random_hue(x, max_delta=0.2 * strength)
    x = tf.clip_by_value(x, 0, 255)
    return x


def color_drop(x):
    x = tf.image.rgb_to_grayscale(x)
    x = tf.tile(x, [1, 1, 3])
    return x


def random_apply(func, x, p):
    if tf.random.uniform([], minval=0, maxval=1) < p:
        return func(x)
    else:
        return x


def custom_augment(image):
    image = tf.cast(image, tf.float32)
    image = flip_random_crop(image)
    image = random_apply(rotation, image, p=0.5)
    #image = random_apply(color_jitter, image, p=0.9)
    #image = random_apply(color_drop, image, p=0.3)
    #image = random_apply(solarize, image, p=0.3)
    return image

# %%
AUTO = tf.data.AUTOTUNE
CROP_TO = IMG_HEIGHT
SEED = 42
BATCH_SIZE = 4
ssl_ds_one = tf.data.Dataset.from_tensor_slices(X_train)
ssl_ds_one = (
    ssl_ds_one.shuffle(1024, seed=SEED)
    .map(custom_augment, num_parallel_calls=AUTO)
    .batch(BATCH_SIZE)
    .prefetch(AUTO)
)

ssl_ds_two = tf.data.Dataset.from_tensor_slices(X_train)
ssl_ds_two = (
    ssl_ds_two.shuffle(1024, seed=SEED)
    .map(custom_augment, num_parallel_calls=AUTO)
    .batch(BATCH_SIZE)
    .prefetch(AUTO)
)

# We then zip both of these datasets.
ssl_ds = tf.data.Dataset.zip((ssl_ds_one, ssl_ds_two))

# %%
sample_images_one = next(iter(ssl_ds_one))
plt.figure(figsize=(10, 10))
for n in range(2):
    ax = plt.subplot(5, 5, n + 1)
    plt.imshow(sample_images_one[n].numpy().astype("int"))
    #print(sample_images_one[n].numpy().shape)
    plt.axis("off")
plt.show()

# %%
sample_images_two = next(iter(ssl_ds_two))
plt.figure(figsize=(10, 10))
for n in range(2):
    ax = plt.subplot(5, 5, n + 1)
    plt.imshow(sample_images_two[n].numpy().astype("int"))
    plt.axis("off")
plt.show()

# %% [markdown]
# # Barlow Twins

# %%
def off_diagonal(x):
    n = tf.shape(x)[0]
    flattened = tf.reshape(x, [-1])[:-1]
    off_diagonals = tf.reshape(flattened, (n-1, n+1))[:, 1:]
    return tf.reshape(off_diagonals, [-1])


def normalize_repr(z):
    z_norm = (z - tf.reduce_mean(z, axis=0)) / tf.math.reduce_std(z, axis=0)
    return z_norm


def compute_loss(z_a, z_b, lambd):
    # Get batch size and representation dimension.
    batch_size = tf.cast(tf.shape(z_a)[0], z_a.dtype)
    repr_dim = tf.shape(z_a)[1]

    # Normalize the representations along the batch dimension.
    z_a_norm = normalize_repr(z_a)
    z_b_norm = normalize_repr(z_b)

    # Cross-correlation matrix.
    c = tf.matmul(z_a_norm, z_b_norm, transpose_a=True) / batch_size

    # Loss.
    on_diag = tf.linalg.diag_part(c) + (-1)
    on_diag = tf.reduce_sum(tf.pow(on_diag, 2))
    off_diag = off_diagonal(c)
    off_diag = tf.reduce_sum(tf.pow(off_diag, 2))
    loss = on_diag + (lambd * off_diag)
    return loss

# %%
class BarlowTwins(tf.keras.Model):
    def __init__(self, encoder, lambd=5e-3):
        super(BarlowTwins, self).__init__()
        self.encoder = encoder
        self.lambd = lambd
        self.loss_tracker = tf.keras.metrics.Mean(name="loss")

    @property
    def metrics(self):
        return [self.loss_tracker]

    def train_step(self, data):
        # Unpack the data.
        ds_one, ds_two = data

        # Forward pass through the encoder and predictor.
        with tf.GradientTape() as tape:
            z_a, z_b = self.encoder(ds_one, training=True), self.encoder(ds_two, training=True)
            loss = compute_loss(z_a, z_b, self.lambd) 

        # Compute gradients and update the parameters.
        gradients = tape.gradient(loss, self.encoder.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.encoder.trainable_variables))

        # Monitor loss.
        self.loss_tracker.update_state(loss)
        return {"loss": self.loss_tracker.result()}

# %%
class WarmUpCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    """
    Implements an LR scheduler that warms up the learning rate for some training steps
    (usually at the beginning of the training) and then decays it
    with CosineDecay (see https://arxiv.org/abs/1608.03983)
    """

    def __init__(
        self, learning_rate_base, total_steps, warmup_learning_rate, warmup_steps
    ):
        super(WarmUpCosine, self).__init__()

        self.learning_rate_base = learning_rate_base
        self.total_steps = total_steps
        self.warmup_learning_rate = warmup_learning_rate
        self.warmup_steps = warmup_steps
        self.pi = tf.constant(np.pi)

    def __call__(self, step):
        if self.total_steps < self.warmup_steps:
            raise ValueError("Total_steps must be larger or equal to warmup_steps.")
        learning_rate = (
            0.5
            * self.learning_rate_base
            * (
                1
                + tf.cos(
                    self.pi
                    * (tf.cast(step, tf.float32) - self.warmup_steps)
                    / float(self.total_steps - self.warmup_steps)
                )
            )
        )

        if self.warmup_steps > 0:
            if self.learning_rate_base < self.warmup_learning_rate:
                raise ValueError(
                    "Learning_rate_base must be larger or equal to "
                    "warmup_learning_rate."
                )
            slope = (
                self.learning_rate_base - self.warmup_learning_rate
            ) / self.warmup_steps
            warmup_rate = slope * tf.cast(step, tf.float32) + self.warmup_learning_rate
            learning_rate = tf.where(
                step < self.warmup_steps, warmup_rate, learning_rate
            )
        return tf.where(
            step > self.total_steps, 0.0, learning_rate, name="learning_rate"
        )

# %%
PROJECT_DIM = IMG_HEIGHT//2
BATCH_SIZE = 8
EPOCHS = 100
WEIGHT_DECAY = 5e-4
TRAIN_FLG = 0 # 0 - No Training, 1 - Training
val_split = 0.3

STEPS_PER_EPOCH = len(X_train) // BATCH_SIZE
TOTAL_STEPS = STEPS_PER_EPOCH * EPOCHS
WARMUP_EPOCHS = int(EPOCHS * 0.1)
WARMUP_STEPS = int(WARMUP_EPOCHS * STEPS_PER_EPOCH)

lr_decayed_fn = WarmUpCosine(
    learning_rate_base=1e-3,
    total_steps=EPOCHS * STEPS_PER_EPOCH,
    warmup_learning_rate=0.0,
    warmup_steps=WARMUP_STEPS
)

# %%
# Visualize the LR schedule
plt.plot(lr_decayed_fn(tf.range(EPOCHS*STEPS_PER_EPOCH, dtype=tf.float32)))
plt.ylabel("Learning Rate")
plt.xlabel("Train Step")
plt.show()

# %%
def projection_head(x, hidden_dim=128):
    """Constructs the projection head."""
    for i in range(2):
        x = Dense(
            hidden_dim,
            name=f"projection_layer_{i}",
            kernel_regularizer=l2(WEIGHT_DECAY),
        )(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
    outputs = Dense(hidden_dim, name="projection_output")(x)
    return outputs

def build_encoder(shape, hidden_dim=128):
    inputs = Input(shape)
    s = layers.Rescaling(1.0 / 255)(inputs) # Removed Experimental.something because it is not available in the latest TensorFlow version, replaced with Rescaling layer
    #s = inputs
    x, skip_1 = encoder(s)
    
    x = bottleneck(x)
    
    # Projections
    trunk_output = GlobalAvgPool2D()(x)
    projection_outputs = projection_head(trunk_output, hidden_dim=hidden_dim)

    model = Model(inputs, projection_outputs)
    return model, skip_1

# %%
unet_enc, skip_connetions = build_encoder((IMG_WIDTH, IMG_HEIGHT, IMG_CHANNELS), hidden_dim=PROJECT_DIM)
unet_enc.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_4         │ (None, 256, 256,  │          0 │ input_layer_6[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_48 │ (None, 256, 256,  │         91 │ rescaling_4[0][0] │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_51       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_49 │ (None, 256, 256,  │        416 │ activation_51[0]… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 256, 256,  │         64 │ rescaling_4[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_52       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_24          │ (None, 256, 256,  │          0 │ activation_52[0]… │
# │ (Dropout)           │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_24 (Add)        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ dropout_24[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_16    │ (None, 128, 128,  │          0 │ add_24[0][0]      │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_50 │ (None, 128, 128,  │        688 │ max_pooling2d_16… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_53       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_51 │ (None, 128, 128,  │      1,344 │ activation_53[0]… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 128, 128,  │        544 │ max_pooling2d_16… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_54       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 128, 128,  │          0 │ activation_54[0]… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_25 (Add)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ dropout_25[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_17    │ (None, 64, 64,    │          0 │ add_25[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_52 │ (None, 64, 64,    │      2,400 │ max_pooling2d_17… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_55       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_53 │ (None, 64, 64,    │      4,736 │ activation_55[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 64, 64,    │      2,112 │ max_pooling2d_17… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_56       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_26          │ (None, 64, 64,    │          0 │ activation_56[0]… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_26 (Add)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ dropout_26[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_18    │ (None, 32, 32,    │          0 │ add_26[0][0]      │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_54 │ (None, 32, 32,    │      8,896 │ max_pooling2d_18… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_57       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_55 │ (None, 32, 32,    │     17,664 │ activation_57[0]… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 32, 32,    │      8,320 │ max_pooling2d_18… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_58       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_27          │ (None, 32, 32,    │          0 │ activation_58[0]… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_27 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ dropout_27[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_19    │ (None, 16, 16,    │          0 │ add_27[0][0]      │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_56 │ (None, 16, 16,    │     34,176 │ max_pooling2d_19… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_59       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_57 │ (None, 16, 16,    │     68,096 │ activation_59[0]… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 16, 16,    │     33,024 │ max_pooling2d_19… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_60       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_28          │ (None, 16, 16,    │          0 │ activation_60[0]… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_28 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ dropout_28[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ add_28[0][0]      │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ projection_layer_0  │ (None, 128)       │     32,896 │ global_average_p… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ projection_layer… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_61       │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ projection_layer_1  │ (None, 128)       │     16,512 │ activation_61[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ projection_layer… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_62       │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ projection_output   │ (None, 128)       │     16,512 │ activation_62[0]… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 255,467 (997.92 KB)
#  Trainable params: 251,979 (984.29 KB)
#  Non-trainable params: 3,488 (13.62 KB)

# %% [markdown]
# # Training BT

# %%
barlow_twins.encoder.save("barlow_twins_unet.keras")
plt.plot(history.history["loss"])
plt.grid()
plt.title("Barlow Twin Loss")
plt.show()

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=lr_decayed_fn, momentum=0.9)
barlow_twins = BarlowTwins(unet_enc)
barlow_twins.compile(optimizer=optimizer)
if TRAIN_FLG:
    print("Training")
    barlow_twins.encoder.get_weights()[0]
    history = barlow_twins.fit(ssl_ds, epochs=EPOCHS)
    barlow_twins.encoder.save("barlow_twins_unet.keras")
    plt.plot(history.history["loss"])
    plt.grid()
    plt.title("Barlow Twin Loss")
    plt.show()
elif not TRAIN_FLG:
    print("Loading training weights")
    barlow_twins.encoder.load_weights("barlow_twins_unet")
# Out:
# Training
# Epoch 1/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 28s 149ms/step - loss: 54.3651
# Epoch 2/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 152ms/step - loss: 40.5251
# Epoch 3/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 152ms/step - loss: 45.6681
# Epoch 4/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 157ms/step - loss: 41.2629
# Epoch 5/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 158ms/step - loss: 47.8137
# Epoch 6/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 159ms/step - loss: 42.6451
# Epoch 7/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 158ms/step - loss: 43.1143
# Epoch 8/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 158ms/step - loss: 46.3381
# Epoch 9/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 157ms/step - loss: 43.6957
# Epoch 10/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 159ms/step - loss: 42.0345
# Epoch 11/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 162ms/step - loss: 41.5201
# Epoch 12/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 159ms/step - loss: 41.0362
# Epoch 13/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 159ms/step - loss: 42.7756
# Epoch 14/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 159ms/step - loss: 42.0989
# Epoch 15/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 160ms/step - loss: 43.1821
# Epoch 16/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 157ms/step - loss: 44.4965
# Epoch 17/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 158ms/step - loss: 39.6332
# Epoch 18/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 158ms/step - loss: 41.6099
# Epoch 19/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 157ms/step - loss: 42.2963
# Epoch 20/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 158ms/step - loss: 39.5532
# Epoch 21/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 158ms/step - loss: 41.3158
# Epoch 22/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 158ms/step - loss: 39.5825
# Epoch 23/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 158ms/step - loss: 44.0900
# Epoch 24/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 158ms/step - loss: 43.2607
# Epoch 25/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 158ms/step - loss: 44.5572
# Epoch 26/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 158ms/step - loss: 42.7811
# Epoch 27/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 158ms/step - loss: 40.1362
# Epoch 28/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 159ms/step - loss: 40.6818
# Epoch 29/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 159ms/step - loss: 41.0838
# Epoch 30/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 159ms/step - loss: 40.1970
# Epoch 31/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 158ms/step - loss: 42.3895
# Epoch 32/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 158ms/step - loss: 43.6470
# Epoch 33/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 158ms/step - loss: 42.1252
# Epoch 34/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 159ms/step - loss: 39.1419
# Epoch 35/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 157ms/step - loss: 40.2625
# Epoch 36/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 158ms/step - loss: 38.9694
# Epoch 37/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 157ms/step - loss: 41.3487
# Epoch 38/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 158ms/step - loss: 40.2767
# Epoch 39/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 159ms/step - loss: 38.2844
# Epoch 40/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 159ms/step - loss: 37.4255
# Epoch 41/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 159ms/step - loss: 40.4202
# Epoch 42/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 157ms/step - loss: 39.3758
# Epoch 43/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 158ms/step - loss: 41.6907
# Epoch 44/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 159ms/step - loss: 38.8211
# Epoch 45/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 159ms/step - loss: 39.1346
# Epoch 46/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 159ms/step - loss: 38.5853
# Epoch 47/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 160ms/step - loss: 37.6950
# Epoch 48/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 160ms/step - loss: 38.4699
# Epoch 49/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 160ms/step - loss: 39.3153
# Epoch 50/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 157ms/step - loss: 38.8983
# Epoch 51/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 156ms/step - loss: 40.4287
# Epoch 52/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 156ms/step - loss: 38.6125
# Epoch 53/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 38.1250
# Epoch 54/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 39.3786
# Epoch 55/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 40.6923
# Epoch 56/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 154ms/step - loss: 39.6457
# Epoch 57/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 37.8065
# Epoch 58/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 38.0377
# Epoch 59/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 38.5289
# Epoch 60/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 37.3998
# Epoch 61/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 41.2540
# Epoch 62/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 154ms/step - loss: 36.0984
# Epoch 63/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 38.1688
# Epoch 64/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 154ms/step - loss: 37.5540
# Epoch 65/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 37.1168
# Epoch 66/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 154ms/step - loss: 37.3726
# Epoch 67/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 37.9880
# Epoch 68/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 154ms/step - loss: 38.4258
# Epoch 69/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 154ms/step - loss: 40.2653
# Epoch 70/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 38.7742
# Epoch 71/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 37.2148
# Epoch 72/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 157ms/step - loss: 39.2541
# Epoch 73/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 156ms/step - loss: 38.7158
# Epoch 74/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 37.0251
# Epoch 75/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 156ms/step - loss: 36.0047
# Epoch 76/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 36.0836
# Epoch 77/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 37.4432
# Epoch 78/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 156ms/step - loss: 36.7781
# Epoch 79/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 156ms/step - loss: 38.0587
# Epoch 80/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 156ms/step - loss: 39.4561
# Epoch 81/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 156ms/step - loss: 40.0392
# Epoch 82/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 156ms/step - loss: 37.5214
# Epoch 83/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 156ms/step - loss: 37.0800
# Epoch 84/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 156ms/step - loss: 39.0625
# Epoch 85/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 25s 157ms/step - loss: 38.0520
# Epoch 86/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 156ms/step - loss: 38.4224
# Epoch 87/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 156ms/step - loss: 39.6171
# Epoch 88/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 156ms/step - loss: 37.0455
# Epoch 89/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 38.2315
# Epoch 90/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 35.9647
# Epoch 91/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 156ms/step - loss: 37.8669
# Epoch 92/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 156ms/step - loss: 37.9398
# Epoch 93/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 156ms/step - loss: 39.1071
# Epoch 94/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 40.5297
# Epoch 95/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 36.4685
# Epoch 96/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 156ms/step - loss: 37.6219
# Epoch 97/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 37.9196
# Epoch 98/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 156ms/step - loss: 41.0027
# Epoch 99/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 36.4104
# Epoch 100/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 38.2286
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[111], line 8
#       6 barlow_twins.encoder.get_weights()[0]
#       7 history = barlow_twins.fit(ssl_ds, epochs=EPOCHS)
# ----> 8 barlow_twins.encoder.save("barlow_twins_unet")
#       9 plt.plot(history.history["loss"])
#      10 plt.grid()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\saving\saving_api.py:114, in save_model(model, filepath, overwrite, zipped, **kwargs)
#     110 if str(filepath).endswith((".h5", ".hdf5")):
#     111     return legacy_h5_format.save_model_to_hdf5(
#     112         model, filepath, overwrite, include_optimizer
#     113     )
# --> 114 raise ValueError(
#     115     "Invalid filepath extension for saving. "
#     116     "Please add either a `.keras` extension for the native Keras "
#     117     f"format (recommended) or a `.h5` extension. "
#     118     "Use `model.export(filepath)` if you want to export a SavedModel "
#     119     "for use with TFLite/TFServing/etc. "
#     120     f"Received: filepath={filepath}."
#     121 )
#
# ValueError: Invalid filepath extension for saving. Please add either a `.keras` extension for the native Keras format (recommended) or a `.h5` extension. Use `model.export(filepath)` if you want to export a SavedModel for use with TFLite/TFServing/etc. Received: filepath=barlow_twins_unet.

# %%
backbone = tf.keras.Model(
    barlow_twins.encoder.input, barlow_twins.encoder.layers[-9].output
)
backbone.layers
# Out:
# [<InputLayer name=input_layer_6, built=True>,
#  <Rescaling name=rescaling_4, built=True>,
#  <SeparableConv2D name=separable_conv2d_48, built=True>,
#  <BatchNormalization name=batch_normalization_75, built=True>,
#  <Activation name=activation_51, built=True>,
#  <SeparableConv2D name=separable_conv2d_49, built=True>,
#  <BatchNormalization name=batch_normalization_76, built=True>,
#  <Conv2D name=conv2d_25, built=True>,
#  <Activation name=activation_52, built=True>,
#  <BatchNormalization name=batch_normalization_77, built=True>,
#  <Dropout name=dropout_24, built=True>,
#  <Add name=add_24, built=True>,
#  <MaxPooling2D name=max_pooling2d_16, built=True>,
#  <SeparableConv2D name=separable_conv2d_50, built=True>,
#  <BatchNormalization name=batch_normalization_78, built=True>,
#  <Activation name=activation_53, built=True>,
#  <SeparableConv2D name=separable_conv2d_51, built=True>,
#  <BatchNormalization name=batch_normalization_79, built=True>,
#  <Conv2D name=conv2d_26, built=True>,
#  <Activation name=activation_54, built=True>,
#  <BatchNormalization name=batch_normalization_80, built=True>,
#  <Dropout name=dropout_25, built=True>,
#  <Add name=add_25, built=True>,
#  <MaxPooling2D name=max_pooling2d_17, built=True>,
#  <SeparableConv2D name=separable_conv2d_52, built=True>,
#  <BatchNormalization name=batch_normalization_81, built=True>,
#  <Activation name=activation_55, built=True>,
#  <SeparableConv2D name=separable_conv2d_53, built=True>,
#  <BatchNormalization name=batch_normalization_82, built=True>,
#  <Conv2D name=conv2d_27, built=True>,
#  <Activation name=activation_56, built=True>,
#  <BatchNormalization name=batch_normalization_83, built=True>,
#  <Dropout name=dropout_26, built=True>,
#  <Add name=add_26, built=True>,
#  <MaxPooling2D name=max_pooling2d_18, built=True>,
#  <SeparableConv2D name=separable_conv2d_54, built=True>,
#  <BatchNormalization name=batch_normalization_84, built=True>,
#  <Activation name=activation_57, built=True>,
#  <SeparableConv2D name=separable_conv2d_55, built=True>,
#  <BatchNormalization name=batch_normalization_85, built=True>,
#  <Conv2D name=conv2d_28, built=True>,
#  <Activation name=activation_58, built=True>,
#  <BatchNormalization name=batch_normalization_86, built=True>,
#  <Dropout name=dropout_27, built=True>,
#  <Add name=add_27, built=True>,
#  <MaxPooling2D name=max_pooling2d_19, built=True>,
#  <SeparableConv2D name=separable_conv2d_56, built=True>,
#  <BatchNormalization name=batch_normalization_87, built=True>,
#  <Activation name=activation_59, built=True>,
#  <SeparableConv2D name=separable_conv2d_57, built=True>,
#  <BatchNormalization name=batch_normalization_88, built=True>,
#  <Conv2D name=conv2d_29, built=True>,
#  <Activation name=activation_60, built=True>,
#  <BatchNormalization name=batch_normalization_89, built=True>,
#  <Dropout name=dropout_28, built=True>,
#  <Add name=add_28, built=True>]

# %%
backbone.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_4         │ (None, 256, 256,  │          0 │ input_layer_6[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_48 │ (None, 256, 256,  │         91 │ rescaling_4[0][0] │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_51       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_49 │ (None, 256, 256,  │        416 │ activation_51[0]… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 256, 256,  │         64 │ rescaling_4[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_52       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_24          │ (None, 256, 256,  │          0 │ activation_52[0]… │
# │ (Dropout)           │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_24 (Add)        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ dropout_24[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_16    │ (None, 128, 128,  │          0 │ add_24[0][0]      │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_50 │ (None, 128, 128,  │        688 │ max_pooling2d_16… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_53       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_51 │ (None, 128, 128,  │      1,344 │ activation_53[0]… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 128, 128,  │        544 │ max_pooling2d_16… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_54       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 128, 128,  │          0 │ activation_54[0]… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_25 (Add)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ dropout_25[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_17    │ (None, 64, 64,    │          0 │ add_25[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_52 │ (None, 64, 64,    │      2,400 │ max_pooling2d_17… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_55       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_53 │ (None, 64, 64,    │      4,736 │ activation_55[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 64, 64,    │      2,112 │ max_pooling2d_17… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_56       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_26          │ (None, 64, 64,    │          0 │ activation_56[0]… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_26 (Add)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ dropout_26[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_18    │ (None, 32, 32,    │          0 │ add_26[0][0]      │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_54 │ (None, 32, 32,    │      8,896 │ max_pooling2d_18… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_57       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_55 │ (None, 32, 32,    │     17,664 │ activation_57[0]… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 32, 32,    │      8,320 │ max_pooling2d_18… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_58       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_27          │ (None, 32, 32,    │          0 │ activation_58[0]… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_27 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ dropout_27[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_19    │ (None, 16, 16,    │          0 │ add_27[0][0]      │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_56 │ (None, 16, 16,    │     34,176 │ max_pooling2d_19… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_59       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_57 │ (None, 16, 16,    │     68,096 │ activation_59[0]… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 16, 16,    │     33,024 │ max_pooling2d_19… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_60       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_28          │ (None, 16, 16,    │          0 │ activation_60[0]… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_28 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ dropout_28[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 188,523 (736.42 KB)
#  Trainable params: 185,547 (724.79 KB)
#  Non-trainable params: 2,976 (11.62 KB)

# %%
new_skip_connections = [backbone.get_layer(index=11).output, 
                        backbone.get_layer(index=22).output, 
                        backbone.get_layer(index=33).output, 
                        backbone.get_layer(index=44).output]

# %%
new_skip_connections
# Out:
# [<KerasTensor shape=(None, 256, 256, 16), dtype=float32, sparse=False, ragged=False, name=keras_tensor_524>,
#  <KerasTensor shape=(None, 128, 128, 32), dtype=float32, sparse=False, ragged=False, name=keras_tensor_535>,
#  <KerasTensor shape=(None, 64, 64, 64), dtype=float32, sparse=False, ragged=False, name=keras_tensor_546>,
#  <KerasTensor shape=(None, 32, 32, 128), dtype=float32, sparse=False, ragged=False, name=keras_tensor_557>]

# %%
backbone.output
# Out:
# <KerasTensor shape=(None, 16, 16, 256), dtype=float32, sparse=False, ragged=False, name=keras_tensor_568>

# %% [markdown]
# # Complete model

# %%
backbone.trainable=True
x = backbone.output
#x = bottleneck(x)
x = decoder(x, new_skip_connections)
outputs = output(x)
model = Model(barlow_twins.encoder.input, outputs)

# %%
model.summary()
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_4         │ (None, 256, 256,  │          0 │ input_layer_6[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_48 │ (None, 256, 256,  │         91 │ rescaling_4[0][0] │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_51       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_49 │ (None, 256, 256,  │        416 │ activation_51[0]… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 256, 256,  │         64 │ rescaling_4[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_52       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_24          │ (None, 256, 256,  │          0 │ activation_52[0]… │
# │ (Dropout)           │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_24 (Add)        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ dropout_24[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_16    │ (None, 128, 128,  │          0 │ add_24[0][0]      │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_50 │ (None, 128, 128,  │        688 │ max_pooling2d_16… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_53       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_51 │ (None, 128, 128,  │      1,344 │ activation_53[0]… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 128, 128,  │        544 │ max_pooling2d_16… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_54       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 128, 128,  │          0 │ activation_54[0]… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_25 (Add)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ dropout_25[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_17    │ (None, 64, 64,    │          0 │ add_25[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_52 │ (None, 64, 64,    │      2,400 │ max_pooling2d_17… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_55       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_53 │ (None, 64, 64,    │      4,736 │ activation_55[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 64, 64,    │      2,112 │ max_pooling2d_17… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_56       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_26          │ (None, 64, 64,    │          0 │ activation_56[0]… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_26 (Add)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ dropout_26[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_18    │ (None, 32, 32,    │          0 │ add_26[0][0]      │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_54 │ (None, 32, 32,    │      8,896 │ max_pooling2d_18… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_57       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_55 │ (None, 32, 32,    │     17,664 │ activation_57[0]… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 32, 32,    │      8,320 │ max_pooling2d_18… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_58       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_27          │ (None, 32, 32,    │          0 │ activation_58[0]… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_27 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ dropout_27[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_19    │ (None, 16, 16,    │          0 │ add_27[0][0]      │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_56 │ (None, 16, 16,    │     34,176 │ max_pooling2d_19… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_59       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_57 │ (None, 16, 16,    │     68,096 │ activation_59[0]… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 16, 16,    │     33,024 │ max_pooling2d_19… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_60       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_28          │ (None, 16, 16,    │          0 │ activation_60[0]… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_28 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ dropout_28[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (None, 32, 32,    │          0 │ add_28[0][0]      │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 32, 32,    │          0 │ up_sampling2d_4[… │
# │ (Concatenate)       │ 384)              │            │ add_27[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_58 │ (None, 32, 32,    │     52,736 │ concatenate_4[0]… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_63       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_59 │ (None, 32, 32,    │     17,664 │ activation_63[0]… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 32, 32,    │     49,280 │ concatenate_4[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_64       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_29          │ (None, 32, 32,    │          0 │ activation_64[0]… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_29 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ dropout_29[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_5     │ (None, 64, 64,    │          0 │ add_29[0][0]      │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 64, 64,    │          0 │ up_sampling2d_5[… │
# │ (Concatenate)       │ 192)              │            │ add_26[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_60 │ (None, 64, 64,    │     14,080 │ concatenate_5[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_65       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_61 │ (None, 64, 64,    │      4,736 │ activation_65[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 64, 64,    │     12,352 │ concatenate_5[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_66       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_30          │ (None, 64, 64,    │          0 │ activation_66[0]… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_30 (Add)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ dropout_30[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_6     │ (None, 128, 128,  │          0 │ add_30[0][0]      │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 128, 128,  │          0 │ up_sampling2d_6[… │
# │ (Concatenate)       │ 96)               │            │ add_25[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_62 │ (None, 128, 128,  │      3,968 │ concatenate_6[0]… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_67       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_63 │ (None, 128, 128,  │      1,344 │ activation_67[0]… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 128, 128,  │      3,104 │ concatenate_6[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_68       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_31          │ (None, 128, 128,  │          0 │ activation_68[0]… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_31 (Add)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ dropout_31[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_7     │ (None, 256, 256,  │          0 │ add_31[0][0]      │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 256, 256,  │          0 │ up_sampling2d_7[… │
# │ (Concatenate)       │ 48)               │            │ add_24[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_64 │ (None, 256, 256,  │      1,216 │ concatenate_7[0]… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_69       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_65 │ (None, 256, 256,  │        416 │ activation_69[0]… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 256, 256,  │        784 │ concatenate_7[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_70       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_32          │ (None, 256, 256,  │          0 │ activation_70[0]… │
# │ (Dropout)           │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_32 (Add)        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ dropout_32[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 256, 256,  │         17 │ add_32[0][0]      │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │          4 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_71       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 353,104 (1.35 MB)
#  Trainable params: 348,686 (1.33 MB)
#  Non-trainable params: 4,418 (17.26 KB)

# %% [markdown]
# # Metrics

# %%
def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = label(y_true_in > 0.5)
    y_pred = label(y_pred_in > 0.5)
    
    true_objects = len(np.unique(labels))
    pred_objects = len(np.unique(y_pred))

    intersection = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))[0]

    # Compute areas (needed for finding the union between all objects)
    area_true = np.histogram(labels, bins = true_objects)[0]
    area_pred = np.histogram(y_pred, bins = pred_objects)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection

    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union
    #print('IOU {}'.format(iou))
    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
    
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    value = 0.
    for batch in range(batch_size):
        value = value + iou_metric(y_true_in[batch], y_pred_in[batch])
    return value/batch_size

def my_iou_metric(label, pred):
    metric_value = tf.py_function(iou_metric_batch, [label, pred], tf.float32)
    return metric_value

def my_iou_metric_loss(label, pred):
    loss = 1-tf.py_function(iou_metric_batch, [label, pred], tf.float32)
    #loss = -tf.map_fn(my_iou_metric_loss(label, pred), tf.range(tf.shape(pred)[0]))
    loss.set_shape((None,))

    return loss

def dice_coeff(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score

def haud_dist(y_true, y_pred):
    y_true = np.squeeze(y_true)
    y_pred = np.squeeze(y_pred)
    
    return hausdorff_distance(y_true,y_pred)

def haud_dist_batch(y_true, y_pred):
    if len(y_true.shape)==2:
        return haud_dist(y_true, y_pred)
    else:
        batch_size = y_true.shape[0]
    hd = 0.
    for batch in range(batch_size):
        hd = hd + haud_dist(y_true[batch], y_pred[batch])
    return hd/batch_size

def my_haud_dist(label, pred):
    metric_value = tf.py_function(haud_dist_batch, [label, pred], tf.float32)
    return metric_value

def evalResult(gt,pred,target_size=(256,256),flag_multi_class = False,num_class = 2):
    gt = np.squeeze(gt)
    pred = np.squeeze(pred)
    
    acc = Accuracy()
    acc.update_state(np.squeeze(gt), np.squeeze(pred))
    r_acc = acc.result().numpy()
    
    pr = Precision()
    pr.update_state(np.squeeze(gt), np.squeeze(pred))
    r_pr = pr.result().numpy()
    
    rc = Recall()
    rc.update_state(np.squeeze(gt), np.squeeze(pred))
    r_rc = rc.result().numpy()
    
    mi = MeanIoU(num_class)
    mi.update_state(np.squeeze(gt), np.squeeze(pred))
    r_mi = mi.result().numpy()
    
    dc = 0.
    for img in range(gt.shape[0]):
        dc = dc + dice_coeff(gt[img], pred[img]).numpy()
    dc = dc / gt.shape[0]
    
    hd = haud_dist_batch(gt,pred)
    
    miou = iou_metric_batch(gt,pred)
    
    mae = MeanAbsoluteError()
    r_mae = mae(np.squeeze(gt), np.squeeze(pred)).numpy()

    print("Accuracy=",r_acc, "Precision=",r_pr, "Recall=",r_rc, "MeanIoU=",r_mi, "DiceCoefficient=",dc, "HD=",hd, "MyIoU=",miou, "MAE=",r_mae)

# %% [markdown]
# # Loss

# %%
def focal_loss(target_tensor, prediction_tensor, weights=None, alpha=0.25, gamma=2):
    sigmoid_p = tf.nn.sigmoid(prediction_tensor)
    zeros = array_ops.zeros_like(sigmoid_p, dtype=sigmoid_p.dtype)
    
    # For poitive prediction, only need consider front part loss, back part is 0;
    # target_tensor > zeros <=> z=1, so poitive coefficient = z - p.
    pos_p_sub = array_ops.where(target_tensor > zeros, target_tensor - sigmoid_p, zeros)
    
    # For negative prediction, only need consider back part loss, front part is 0;
    # target_tensor > zeros <=> z=1, so negative coefficient = 0.
    neg_p_sub = array_ops.where(target_tensor > zeros, zeros, sigmoid_p)
    per_entry_cross_ent = - alpha * (pos_p_sub ** gamma) * tf.math.log(tf.clip_by_value(sigmoid_p, 1e-8, 1.0))                           - (1 - alpha) * (neg_p_sub ** gamma) * tf.math.log(tf.clip_by_value(1.0 - sigmoid_p, 1e-8, 1.0))
    return tf.reduce_sum(per_entry_cross_ent)

def mean_iou_loss(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.compat.v1.to_int32(y_pred > t)
        score, up_opt = tf.compat.v1.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return -tf.math.log(K.mean(K.stack(prec), axis=0))

def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss

def bce_dice_loss(y_true, y_pred):
    loss = 0.4*categorical_crossentropy(y_true, y_pred) + 0.6*dice_loss(y_true, y_pred)
    return loss

def bce_dice_loss2(y_true, y_pred):
    fl = focal_loss(y_true, y_pred, gamma=5)
    loss = 0.2*categorical_crossentropy(y_true, y_pred) + 0.3*dice_loss(y_true, y_pred) + 0.5*fl
    return loss

# %% [markdown]
# # Callbacks

# %%
log_path = "logs/"
keyname = "BT-Unet"
cur_date = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tb_log_dir = log_path + "fit/" + keyname + '_' + cur_date 
tensorboard_callback = TensorBoard(log_dir=tb_log_dir, histogram_freq=0)
model_checkpoint = ModelCheckpoint('model_'+keyname+'.keras', monitor='loss',verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor='loss', verbose=1, patience=20)
csv_logger = CSVLogger(log_path + keyname + '_' + cur_date + '.log', separator=',', append=False)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10)

# %% [markdown]
# # Training

# %%
model.compile(
    loss=bce_dice_loss,
    optimizer=Adam(),
    metrics=['accuracy', Precision(), MeanIoU(num_classes=2), Recall(), dice_coeff, MeanAbsoluteError()]
   )
X_train_20 = X_train[:int(X_train.shape[0]*0.2)]
Y_train_20 = Y_train[:int(Y_train.shape[0]*0.2)]
if TRAIN_FLG:
    print("Training")
    callbacks = [
        model_checkpoint,
        reduce_lr,
        csv_logger,
        tensorboard_callback,
        early_stopping
    ]
    results = model.fit(X_train_20, Y_train_20, validation_split=val_split, batch_size=8, epochs=200, callbacks=callbacks)
elif not TRAIN_FLG:
    print("Loading training weights")
    model.load_weights('model_'+keyname+'.hdf5')
# Out:
# Training
# Epoch 1/200
# C:\Users\ujai264\AppData\Local\Temp\ipykernel_21772\3548703083.py:31: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 256, 256, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   loss = 0.4*categorical_crossentropy(y_true, y_pred) + 0.6*dice_loss(y_true, y_pred)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.5628 - dice_coeff: 0.1348 - loss: 0.5191 - mean_absolute_error: 0.4855 - mean_io_u_2: 0.4648 - precision_3: 0.0884 - recall_3: 0.5630
# Epoch 1: loss improved from None to 0.51106, saving model to model_BT-Unet.keras
#
# Epoch 1: finished saving model to model_BT-Unet.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 15s 550ms/step - accuracy: 0.5950 - dice_coeff: 0.1474 - loss: 0.5111 - mean_absolute_error: 0.4754 - mean_io_u_2: 0.4654 - precision_3: 0.1068 - recall_3: 0.6589 - val_accuracy: 0.6680 - val_dice_coeff: 0.1913 - val_loss: 0.4847 - val_mean_absolute_error: 0.3670 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.1271 - val_recall_3: 0.5564 - learning_rate: 0.0010
# Epoch 2/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.6327 - dice_coeff: 0.1803 - loss: 0.4918 - mean_absolute_error: 0.4604 - mean_io_u_2: 0.4601 - precision_3: 0.1470 - recall_3: 0.7551
# Epoch 2: loss improved from 0.51106 to 0.50195, saving model to model_BT-Unet.keras
#
# Epoch 2: finished saving model to model_BT-Unet.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 461ms/step - accuracy: 0.6482 - dice_coeff: 0.1634 - loss: 0.5019 - mean_absolute_error: 0.4596 - mean_io_u_2: 0.4654 - precision_3: 0.1364 - recall_3: 0.7652 - val_accuracy: 0.7973 - val_dice_coeff: 0.2050 - val_loss: 0.4765 - val_mean_absolute_error: 0.2856 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.1776 - val_recall_3: 0.4420 - learning_rate: 0.0010
# Epoch 3/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.7195 - dice_coeff: 0.1833 - loss: 0.4900 - mean_absolute_error: 0.4471 - mean_io_u_2: 0.4634 - precision_3: 0.1754 - recall_3: 0.7630
# Epoch 3: loss improved from 0.50195 to 0.49666, saving model to model_BT-Unet.keras
#
# Epoch 3: finished saving model to model_BT-Unet.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 461ms/step - accuracy: 0.7070 - dice_coeff: 0.1716 - loss: 0.4967 - mean_absolute_error: 0.4499 - mean_io_u_2: 0.4654 - precision_3: 0.1595 - recall_3: 0.7572 - val_accuracy: 0.7891 - val_dice_coeff: 0.1817 - val_loss: 0.4920 - val_mean_absolute_error: 0.3214 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.1664 - val_recall_3: 0.4267 - learning_rate: 0.0010
# Epoch 4/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.6813 - dice_coeff: 0.1763 - loss: 0.4942 - mean_absolute_error: 0.4487 - mean_io_u_2: 0.4647 - precision_3: 0.1554 - recall_3: 0.7926
# Epoch 4: loss improved from 0.49666 to 0.49639, saving model to model_BT-Unet.keras
#
# Epoch 4: finished saving model to model_BT-Unet.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 465ms/step - accuracy: 0.6840 - dice_coeff: 0.1719 - loss: 0.4964 - mean_absolute_error: 0.4488 - mean_io_u_2: 0.4654 - precision_3: 0.1509 - recall_3: 0.7701 - val_accuracy: 0.7959 - val_dice_coeff: 0.1827 - val_loss: 0.4912 - val_mean_absolute_error: 0.3375 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.1760 - val_recall_3: 0.4407 - learning_rate: 0.0010
# Epoch 5/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.6613 - dice_coeff: 0.1537 - loss: 0.5077 - mean_absolute_error: 0.4512 - mean_io_u_2: 0.4693 - precision_3: 0.1269 - recall_3: 0.7638
# Epoch 5: loss improved from 0.49639 to 0.49586, saving model to model_BT-Unet.keras
#
# Epoch 5: finished saving model to model_BT-Unet.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 477ms/step - accuracy: 0.6818 - dice_coeff: 0.1718 - loss: 0.4959 - mean_absolute_error: 0.4448 - mean_io_u_2: 0.4654 - precision_3: 0.1507 - recall_3: 0.7762 - val_accuracy: 0.8119 - val_dice_coeff: 0.1872 - val_loss: 0.4878 - val_mean_absolute_error: 0.3306 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.1889 - val_recall_3: 0.4301 - learning_rate: 0.0010
# Epoch 6/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.7338 - dice_coeff: 0.1654 - loss: 0.5008 - mean_absolute_error: 0.4391 - mean_io_u_2: 0.4698 - precision_3: 0.1602 - recall_3: 0.8077
# Epoch 6: loss improved from 0.49586 to 0.49099, saving model to model_BT-Unet.keras
#
# Epoch 6: finished saving model to model_BT-Unet.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 477ms/step - accuracy: 0.7234 - dice_coeff: 0.1828 - loss: 0.4910 - mean_absolute_error: 0.4375 - mean_io_u_2: 0.4654 - precision_3: 0.1719 - recall_3: 0.7844 - val_accuracy: 0.8243 - val_dice_coeff: 0.1736 - val_loss: 0.4964 - val_mean_absolute_error: 0.3532 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.1948 - val_recall_3: 0.4016 - learning_rate: 0.0010
# Epoch 7/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.7383 - dice_coeff: 0.2142 - loss: 0.4714 - mean_absolute_error: 0.4241 - mean_io_u_2: 0.4609 - precision_3: 0.2150 - recall_3: 0.8814
# Epoch 7: loss improved from 0.49099 to 0.48909, saving model to model_BT-Unet.keras
#
# Epoch 7: finished saving model to model_BT-Unet.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 475ms/step - accuracy: 0.7200 - dice_coeff: 0.1840 - loss: 0.4891 - mean_absolute_error: 0.4330 - mean_io_u_2: 0.4654 - precision_3: 0.1755 - recall_3: 0.8236 - val_accuracy: 0.8555 - val_dice_coeff: 0.1658 - val_loss: 0.5012 - val_mean_absolute_error: 0.3489 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.2189 - val_recall_3: 0.3338 - learning_rate: 0.0010
# Epoch 8/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.7292 - dice_coeff: 0.1809 - loss: 0.4915 - mean_absolute_error: 0.4307 - mean_io_u_2: 0.4681 - precision_3: 0.1690 - recall_3: 0.8261
# Epoch 8: loss improved from 0.48909 to 0.48518, saving model to model_BT-Unet.keras
#
# Epoch 8: finished saving model to model_BT-Unet.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 476ms/step - accuracy: 0.7304 - dice_coeff: 0.1914 - loss: 0.4852 - mean_absolute_error: 0.4290 - mean_io_u_2: 0.4654 - precision_3: 0.1817 - recall_3: 0.8264 - val_accuracy: 0.8750 - val_dice_coeff: 0.1599 - val_loss: 0.5048 - val_mean_absolute_error: 0.3591 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.2481 - val_recall_3: 0.2987 - learning_rate: 0.0010
# Epoch 9/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.7482 - dice_coeff: 0.2042 - loss: 0.4775 - mean_absolute_error: 0.4226 - mean_io_u_2: 0.4638 - precision_3: 0.2003 - recall_3: 0.8255
# Epoch 9: loss did not improve from 0.48518
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 465ms/step - accuracy: 0.7406 - dice_coeff: 0.1916 - loss: 0.4855 - mean_absolute_error: 0.4260 - mean_io_u_2: 0.4654 - precision_3: 0.1842 - recall_3: 0.8009 - val_accuracy: 0.8235 - val_dice_coeff: 0.1650 - val_loss: 0.5012 - val_mean_absolute_error: 0.3827 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.2005 - val_recall_3: 0.4244 - learning_rate: 0.0010
# Epoch 10/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.7284 - dice_coeff: 0.1963 - loss: 0.4822 - mean_absolute_error: 0.4248 - mean_io_u_2: 0.4638 - precision_3: 0.1844 - recall_3: 0.8048
# Epoch 10: loss improved from 0.48518 to 0.48326, saving model to model_BT-Unet.keras
#
# Epoch 10: finished saving model to model_BT-Unet.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 478ms/step - accuracy: 0.7408 - dice_coeff: 0.1932 - loss: 0.4833 - mean_absolute_error: 0.4220 - mean_io_u_2: 0.4654 - precision_3: 0.1883 - recall_3: 0.8292 - val_accuracy: 0.8695 - val_dice_coeff: 0.1616 - val_loss: 0.5036 - val_mean_absolute_error: 0.3743 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.2492 - val_recall_3: 0.3365 - learning_rate: 0.0010
# Epoch 11/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 0.7537 - dice_coeff: 0.1861 - loss: 0.4883 - mean_absolute_error: 0.4223 - mean_io_u_2: 0.4662 - precision_3: 0.1846 - recall_3: 0.7653
# Epoch 11: loss did not improve from 0.48326
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 471ms/step - accuracy: 0.7685 - dice_coeff: 0.1912 - loss: 0.4845 - mean_absolute_error: 0.4186 - mean_io_u_2: 0.4654 - precision_3: 0.2006 - recall_3: 0.7851 - val_accuracy: 0.8269 - val_dice_coeff: 0.1628 - val_loss: 0.5027 - val_mean_absolute_error: 0.3847 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.2102 - val_recall_3: 0.4440 - learning_rate: 0.0010
# Epoch 12/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.7599 - dice_coeff: 0.1740 - loss: 0.4956 - mean_absolute_error: 0.4172 - mean_io_u_2: 0.4709 - precision_3: 0.1736 - recall_3: 0.8348
# Epoch 12: loss improved from 0.48326 to 0.48257, saving model to model_BT-Unet.keras
#
# Epoch 12: finished saving model to model_BT-Unet.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 477ms/step - accuracy: 0.7649 - dice_coeff: 0.1963 - loss: 0.4826 - mean_absolute_error: 0.4142 - mean_io_u_2: 0.4654 - precision_3: 0.1996 - recall_3: 0.7960 - val_accuracy: 0.8713 - val_dice_coeff: 0.1591 - val_loss: 0.5050 - val_mean_absolute_error: 0.3767 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.2551 - val_recall_3: 0.3403 - learning_rate: 0.0010
# Epoch 13/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.7476 - dice_coeff: 0.1996 - loss: 0.4803 - mean_absolute_error: 0.4141 - mean_io_u_2: 0.4642 - precision_3: 0.1949 - recall_3: 0.8104
# Epoch 13: loss improved from 0.48257 to 0.47955, saving model to model_BT-Unet.keras
#
# Epoch 13: finished saving model to model_BT-Unet.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 476ms/step - accuracy: 0.7568 - dice_coeff: 0.2013 - loss: 0.4795 - mean_absolute_error: 0.4114 - mean_io_u_2: 0.4654 - precision_3: 0.2016 - recall_3: 0.8486 - val_accuracy: 0.8788 - val_dice_coeff: 0.1568 - val_loss: 0.5064 - val_mean_absolute_error: 0.3770 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.2672 - val_recall_3: 0.3199 - learning_rate: 1.0000e-04
# Epoch 14/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.7693 - dice_coeff: 0.2078 - loss: 0.4753 - mean_absolute_error: 0.4092 - mean_io_u_2: 0.4646 - precision_3: 0.2122 - recall_3: 0.8333
# Epoch 14: loss improved from 0.47955 to 0.47637, saving model to model_BT-Unet.keras
#
# Epoch 14: finished saving model to model_BT-Unet.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 478ms/step - accuracy: 0.7713 - dice_coeff: 0.2054 - loss: 0.4764 - mean_absolute_error: 0.4083 - mean_io_u_2: 0.4654 - precision_3: 0.2137 - recall_3: 0.8596 - val_accuracy: 0.8817 - val_dice_coeff: 0.1557 - val_loss: 0.5070 - val_mean_absolute_error: 0.3769 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.2723 - val_recall_3: 0.3108 - learning_rate: 1.0000e-04
# Epoch 15/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.7753 - dice_coeff: 0.2150 - loss: 0.4711 - mean_absolute_error: 0.4065 - mean_io_u_2: 0.4636 - precision_3: 0.2233 - recall_3: 0.8445
# Epoch 15: loss improved from 0.47637 to 0.47630, saving model to model_BT-Unet.keras
#
# Epoch 15: finished saving model to model_BT-Unet.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 479ms/step - accuracy: 0.7729 - dice_coeff: 0.2080 - loss: 0.4763 - mean_absolute_error: 0.4077 - mean_io_u_2: 0.4654 - precision_3: 0.2137 - recall_3: 0.8512 - val_accuracy: 0.8840 - val_dice_coeff: 0.1544 - val_loss: 0.5078 - val_mean_absolute_error: 0.3790 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.2769 - val_recall_3: 0.3048 - learning_rate: 1.0000e-04
# Epoch 16/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.7718 - dice_coeff: 0.2012 - loss: 0.4794 - mean_absolute_error: 0.4091 - mean_io_u_2: 0.4663 - precision_3: 0.2055 - recall_3: 0.8320
# Epoch 16: loss did not improve from 0.47630
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 465ms/step - accuracy: 0.7741 - dice_coeff: 0.2042 - loss: 0.4786 - mean_absolute_error: 0.4086 - mean_io_u_2: 0.4654 - precision_3: 0.2116 - recall_3: 0.8305 - val_accuracy: 0.8871 - val_dice_coeff: 0.1532 - val_loss: 0.5085 - val_mean_absolute_error: 0.3793 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.2832 - val_recall_3: 0.2941 - learning_rate: 1.0000e-04
# Epoch 17/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.7940 - dice_coeff: 0.2227 - loss: 0.4666 - mean_absolute_error: 0.4023 - mean_io_u_2: 0.4626 - precision_3: 0.2432 - recall_3: 0.8292
# Epoch 17: loss did not improve from 0.47630
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 476ms/step - accuracy: 0.7831 - dice_coeff: 0.2054 - loss: 0.4787 - mean_absolute_error: 0.4075 - mean_io_u_2: 0.4654 - precision_3: 0.2183 - recall_3: 0.8265 - val_accuracy: 0.8963 - val_dice_coeff: 0.1513 - val_loss: 0.5097 - val_mean_absolute_error: 0.3782 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.3063 - val_recall_3: 0.2627 - learning_rate: 1.0000e-04
# Epoch 18/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.7925 - dice_coeff: 0.2076 - loss: 0.4756 - mean_absolute_error: 0.4029 - mean_io_u_2: 0.4666 - precision_3: 0.2286 - recall_3: 0.8807
# Epoch 18: loss improved from 0.47630 to 0.47602, saving model to model_BT-Unet.keras
#
# Epoch 18: finished saving model to model_BT-Unet.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 501ms/step - accuracy: 0.7835 - dice_coeff: 0.2088 - loss: 0.4760 - mean_absolute_error: 0.4057 - mean_io_u_2: 0.4654 - precision_3: 0.2224 - recall_3: 0.8526 - val_accuracy: 0.9022 - val_dice_coeff: 0.1501 - val_loss: 0.5104 - val_mean_absolute_error: 0.3788 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.3285 - val_recall_3: 0.2457 - learning_rate: 1.0000e-04
# Epoch 19/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.7789 - dice_coeff: 0.1812 - loss: 0.4914 - mean_absolute_error: 0.4082 - mean_io_u_2: 0.4709 - precision_3: 0.1944 - recall_3: 0.8956
# Epoch 19: loss did not improve from 0.47602
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 476ms/step - accuracy: 0.7867 - dice_coeff: 0.2080 - loss: 0.4763 - mean_absolute_error: 0.4046 - mean_io_u_2: 0.4654 - precision_3: 0.2249 - recall_3: 0.8504 - val_accuracy: 0.9021 - val_dice_coeff: 0.1502 - val_loss: 0.5104 - val_mean_absolute_error: 0.3778 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.3280 - val_recall_3: 0.2457 - learning_rate: 1.0000e-04
# Epoch 20/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.7965 - dice_coeff: 0.2221 - loss: 0.4666 - mean_absolute_error: 0.3999 - mean_io_u_2: 0.4616 - precision_3: 0.2567 - recall_3: 0.8697
# Epoch 20: loss did not improve from 0.47602
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 483ms/step - accuracy: 0.7893 - dice_coeff: 0.2019 - loss: 0.4773 - mean_absolute_error: 0.4049 - mean_io_u_2: 0.4654 - precision_3: 0.2268 - recall_3: 0.8483 - val_accuracy: 0.9034 - val_dice_coeff: 0.1495 - val_loss: 0.5108 - val_mean_absolute_error: 0.3774 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.3324 - val_recall_3: 0.2398 - learning_rate: 1.0000e-04
# Epoch 21/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.8020 - dice_coeff: 0.2048 - loss: 0.4772 - mean_absolute_error: 0.4017 - mean_io_u_2: 0.4679 - precision_3: 0.2293 - recall_3: 0.8825
# Epoch 21: loss improved from 0.47602 to 0.47325, saving model to model_BT-Unet.keras
#
# Epoch 21: finished saving model to model_BT-Unet.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 500ms/step - accuracy: 0.7954 - dice_coeff: 0.2131 - loss: 0.4732 - mean_absolute_error: 0.4024 - mean_io_u_2: 0.4654 - precision_3: 0.2336 - recall_3: 0.8568 - val_accuracy: 0.9076 - val_dice_coeff: 0.1488 - val_loss: 0.5112 - val_mean_absolute_error: 0.3767 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.3529 - val_recall_3: 0.2242 - learning_rate: 1.0000e-04
# Epoch 22/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.7908 - dice_coeff: 0.1843 - loss: 0.4896 - mean_absolute_error: 0.4072 - mean_io_u_2: 0.4704 - precision_3: 0.2010 - recall_3: 0.8564
# Epoch 22: loss did not improve from 0.47325
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 481ms/step - accuracy: 0.7898 - dice_coeff: 0.2053 - loss: 0.4784 - mean_absolute_error: 0.4044 - mean_io_u_2: 0.4654 - precision_3: 0.2254 - recall_3: 0.8356 - val_accuracy: 0.9133 - val_dice_coeff: 0.1477 - val_loss: 0.5119 - val_mean_absolute_error: 0.3751 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.3891 - val_recall_3: 0.1994 - learning_rate: 1.0000e-04
# Epoch 23/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.7834 - dice_coeff: 0.1822 - loss: 0.4909 - mean_absolute_error: 0.4093 - mean_io_u_2: 0.4704 - precision_3: 0.1946 - recall_3: 0.8444
# Epoch 23: loss did not improve from 0.47325
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 480ms/step - accuracy: 0.7926 - dice_coeff: 0.2079 - loss: 0.4773 - mean_absolute_error: 0.4038 - mean_io_u_2: 0.4654 - precision_3: 0.2297 - recall_3: 0.8480 - val_accuracy: 0.9136 - val_dice_coeff: 0.1479 - val_loss: 0.5118 - val_mean_absolute_error: 0.3746 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.3923 - val_recall_3: 0.2015 - learning_rate: 1.0000e-05
# Epoch 24/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.7886 - dice_coeff: 0.2120 - loss: 0.4728 - mean_absolute_error: 0.4027 - mean_io_u_2: 0.4627 - precision_3: 0.2389 - recall_3: 0.8146
# Epoch 24: loss did not improve from 0.47325
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 479ms/step - accuracy: 0.7942 - dice_coeff: 0.2075 - loss: 0.4755 - mean_absolute_error: 0.4018 - mean_io_u_2: 0.4654 - precision_3: 0.2326 - recall_3: 0.8580 - val_accuracy: 0.9139 - val_dice_coeff: 0.1482 - val_loss: 0.5116 - val_mean_absolute_error: 0.3739 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.3964 - val_recall_3: 0.2030 - learning_rate: 1.0000e-05
# Epoch 25/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.7865 - dice_coeff: 0.1961 - loss: 0.4822 - mean_absolute_error: 0.4071 - mean_io_u_2: 0.4674 - precision_3: 0.2116 - recall_3: 0.8264
# Epoch 25: loss did not improve from 0.47325
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 481ms/step - accuracy: 0.7952 - dice_coeff: 0.2077 - loss: 0.4736 - mean_absolute_error: 0.4018 - mean_io_u_2: 0.4654 - precision_3: 0.2337 - recall_3: 0.8592 - val_accuracy: 0.9142 - val_dice_coeff: 0.1485 - val_loss: 0.5114 - val_mean_absolute_error: 0.3735 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.3997 - val_recall_3: 0.2054 - learning_rate: 1.0000e-05
# Epoch 26/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.7903 - dice_coeff: 0.2247 - loss: 0.4651 - mean_absolute_error: 0.4015 - mean_io_u_2: 0.4611 - precision_3: 0.2432 - recall_3: 0.8114
# Epoch 26: loss did not improve from 0.47325
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 484ms/step - accuracy: 0.7921 - dice_coeff: 0.2079 - loss: 0.4749 - mean_absolute_error: 0.4038 - mean_io_u_2: 0.4654 - precision_3: 0.2263 - recall_3: 0.8281 - val_accuracy: 0.9146 - val_dice_coeff: 0.1488 - val_loss: 0.5112 - val_mean_absolute_error: 0.3730 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.4046 - val_recall_3: 0.2063 - learning_rate: 1.0000e-05
# Epoch 27/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.7992 - dice_coeff: 0.2210 - loss: 0.4673 - mean_absolute_error: 0.3999 - mean_io_u_2: 0.4628 - precision_3: 0.2472 - recall_3: 0.8289
# Epoch 27: loss did not improve from 0.47325
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 485ms/step - accuracy: 0.7958 - dice_coeff: 0.2072 - loss: 0.4746 - mean_absolute_error: 0.4025 - mean_io_u_2: 0.4654 - precision_3: 0.2328 - recall_3: 0.8495 - val_accuracy: 0.9150 - val_dice_coeff: 0.1492 - val_loss: 0.5110 - val_mean_absolute_error: 0.3725 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.4096 - val_recall_3: 0.2086 - learning_rate: 1.0000e-05
# Epoch 28/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.7866 - dice_coeff: 0.1634 - loss: 0.5020 - mean_absolute_error: 0.4097 - mean_io_u_2: 0.4735 - precision_3: 0.1831 - recall_3: 0.8740
# Epoch 28: loss did not improve from 0.47325
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 479ms/step - accuracy: 0.7973 - dice_coeff: 0.2083 - loss: 0.4751 - mean_absolute_error: 0.4014 - mean_io_u_2: 0.4654 - precision_3: 0.2359 - recall_3: 0.8605 - val_accuracy: 0.9152 - val_dice_coeff: 0.1498 - val_loss: 0.5106 - val_mean_absolute_error: 0.3721 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.4134 - val_recall_3: 0.2149 - learning_rate: 1.0000e-05
# Epoch 29/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.7999 - dice_coeff: 0.2332 - loss: 0.4599 - mean_absolute_error: 0.3973 - mean_io_u_2: 0.4615 - precision_3: 0.2606 - recall_3: 0.8690
# Epoch 29: loss did not improve from 0.47325
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 479ms/step - accuracy: 0.7912 - dice_coeff: 0.2059 - loss: 0.4747 - mean_absolute_error: 0.4033 - mean_io_u_2: 0.4654 - precision_3: 0.2271 - recall_3: 0.8391 - val_accuracy: 0.9152 - val_dice_coeff: 0.1506 - val_loss: 0.5101 - val_mean_absolute_error: 0.3717 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.4164 - val_recall_3: 0.2247 - learning_rate: 1.0000e-05
# Epoch 30/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.7995 - dice_coeff: 0.2126 - loss: 0.4724 - mean_absolute_error: 0.4016 - mean_io_u_2: 0.4653 - precision_3: 0.2363 - recall_3: 0.8463
# Epoch 30: loss improved from 0.47325 to 0.47136, saving model to model_BT-Unet.keras
#
# Epoch 30: finished saving model to model_BT-Unet.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 500ms/step - accuracy: 0.7997 - dice_coeff: 0.2134 - loss: 0.4714 - mean_absolute_error: 0.4008 - mean_io_u_2: 0.4654 - precision_3: 0.2374 - recall_3: 0.8558 - val_accuracy: 0.9156 - val_dice_coeff: 0.1513 - val_loss: 0.5097 - val_mean_absolute_error: 0.3713 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.4224 - val_recall_3: 0.2308 - learning_rate: 1.0000e-05
# Epoch 31/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.7946 - dice_coeff: 0.2242 - loss: 0.4654 - mean_absolute_error: 0.3996 - mean_io_u_2: 0.4596 - precision_3: 0.2589 - recall_3: 0.8354
# Epoch 31: loss did not improve from 0.47136
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 483ms/step - accuracy: 0.7906 - dice_coeff: 0.2005 - loss: 0.4792 - mean_absolute_error: 0.4042 - mean_io_u_2: 0.4654 - precision_3: 0.2269 - recall_3: 0.8412 - val_accuracy: 0.9159 - val_dice_coeff: 0.1523 - val_loss: 0.5091 - val_mean_absolute_error: 0.3706 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.4278 - val_recall_3: 0.2399 - learning_rate: 1.0000e-05
# Epoch 32/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.8073 - dice_coeff: 0.2375 - loss: 0.4575 - mean_absolute_error: 0.3956 - mean_io_u_2: 0.4604 - precision_3: 0.2762 - recall_3: 0.8694
# Epoch 32: loss did not improve from 0.47136
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 480ms/step - accuracy: 0.7947 - dice_coeff: 0.2119 - loss: 0.4726 - mean_absolute_error: 0.4019 - mean_io_u_2: 0.4654 - precision_3: 0.2338 - recall_3: 0.8631 - val_accuracy: 0.9155 - val_dice_coeff: 0.1535 - val_loss: 0.5083 - val_mean_absolute_error: 0.3703 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.4270 - val_recall_3: 0.2527 - learning_rate: 1.0000e-05
# Epoch 33/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.7913 - dice_coeff: 0.1820 - loss: 0.4908 - mean_absolute_error: 0.4059 - mean_io_u_2: 0.4718 - precision_3: 0.1996 - recall_3: 0.9063
# Epoch 33: loss did not improve from 0.47136
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 481ms/step - accuracy: 0.7950 - dice_coeff: 0.2080 - loss: 0.4753 - mean_absolute_error: 0.4026 - mean_io_u_2: 0.4654 - precision_3: 0.2324 - recall_3: 0.8518 - val_accuracy: 0.9153 - val_dice_coeff: 0.1547 - val_loss: 0.5076 - val_mean_absolute_error: 0.3698 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.4279 - val_recall_3: 0.2633 - learning_rate: 1.0000e-06
# Epoch 34/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.8044 - dice_coeff: 0.2228 - loss: 0.4663 - mean_absolute_error: 0.3997 - mean_io_u_2: 0.4608 - precision_3: 0.2637 - recall_3: 0.8362
# Epoch 34: loss did not improve from 0.47136
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 480ms/step - accuracy: 0.7965 - dice_coeff: 0.2039 - loss: 0.4773 - mean_absolute_error: 0.4035 - mean_io_u_2: 0.4654 - precision_3: 0.2316 - recall_3: 0.8369 - val_accuracy: 0.9148 - val_dice_coeff: 0.1560 - val_loss: 0.5068 - val_mean_absolute_error: 0.3695 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.4262 - val_recall_3: 0.2756 - learning_rate: 1.0000e-06
# Epoch 35/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 0.7989 - dice_coeff: 0.2172 - loss: 0.4699 - mean_absolute_error: 0.3992 - mean_io_u_2: 0.4595 - precision_3: 0.2652 - recall_3: 0.8565
# Epoch 35: loss did not improve from 0.47136
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 491ms/step - accuracy: 0.7911 - dice_coeff: 0.1986 - loss: 0.4835 - mean_absolute_error: 0.4053 - mean_io_u_2: 0.4654 - precision_3: 0.2265 - recall_3: 0.8356 - val_accuracy: 0.9138 - val_dice_coeff: 0.1576 - val_loss: 0.5058 - val_mean_absolute_error: 0.3692 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.4217 - val_recall_3: 0.2895 - learning_rate: 1.0000e-06
# Epoch 36/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.7944 - dice_coeff: 0.2113 - loss: 0.4733 - mean_absolute_error: 0.4023 - mean_io_u_2: 0.4653 - precision_3: 0.2325 - recall_3: 0.8530
# Epoch 36: loss did not improve from 0.47136
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 480ms/step - accuracy: 0.7984 - dice_coeff: 0.2137 - loss: 0.4724 - mean_absolute_error: 0.4012 - mean_io_u_2: 0.4654 - precision_3: 0.2367 - recall_3: 0.8597 - val_accuracy: 0.9129 - val_dice_coeff: 0.1592 - val_loss: 0.5048 - val_mean_absolute_error: 0.3688 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.4181 - val_recall_3: 0.3031 - learning_rate: 1.0000e-06
# Epoch 37/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - accuracy: 0.8046 - dice_coeff: 0.2163 - loss: 0.4702 - mean_absolute_error: 0.3988 - mean_io_u_2: 0.4656 - precision_3: 0.2449 - recall_3: 0.8868
# Epoch 37: loss did not improve from 0.47136
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 484ms/step - accuracy: 0.7964 - dice_coeff: 0.2102 - loss: 0.4732 - mean_absolute_error: 0.4019 - mean_io_u_2: 0.4654 - precision_3: 0.2327 - recall_3: 0.8443 - val_accuracy: 0.9111 - val_dice_coeff: 0.1610 - val_loss: 0.5037 - val_mean_absolute_error: 0.3688 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.4093 - val_recall_3: 0.3200 - learning_rate: 1.0000e-06
# Epoch 38/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.7995 - dice_coeff: 0.2340 - loss: 0.4595 - mean_absolute_error: 0.3977 - mean_io_u_2: 0.4606 - precision_3: 0.2627 - recall_3: 0.8542
# Epoch 38: loss did not improve from 0.47136
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 480ms/step - accuracy: 0.7955 - dice_coeff: 0.2104 - loss: 0.4728 - mean_absolute_error: 0.4018 - mean_io_u_2: 0.4654 - precision_3: 0.2330 - recall_3: 0.8523 - val_accuracy: 0.9093 - val_dice_coeff: 0.1629 - val_loss: 0.5026 - val_mean_absolute_error: 0.3688 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.4012 - val_recall_3: 0.3372 - learning_rate: 1.0000e-06
# Epoch 39/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.7853 - dice_coeff: 0.1813 - loss: 0.4913 - mean_absolute_error: 0.4083 - mean_io_u_2: 0.4710 - precision_3: 0.1918 - recall_3: 0.8392
# Epoch 39: loss did not improve from 0.47136
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 480ms/step - accuracy: 0.7964 - dice_coeff: 0.2143 - loss: 0.4729 - mean_absolute_error: 0.4016 - mean_io_u_2: 0.4654 - precision_3: 0.2345 - recall_3: 0.8571 - val_accuracy: 0.9074 - val_dice_coeff: 0.1649 - val_loss: 0.5014 - val_mean_absolute_error: 0.3688 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.3942 - val_recall_3: 0.3538 - learning_rate: 1.0000e-06
# Epoch 40/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.7950 - dice_coeff: 0.2049 - loss: 0.4771 - mean_absolute_error: 0.4026 - mean_io_u_2: 0.4669 - precision_3: 0.2234 - recall_3: 0.8453
# Epoch 40: loss did not improve from 0.47136
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 475ms/step - accuracy: 0.7955 - dice_coeff: 0.2108 - loss: 0.4737 - mean_absolute_error: 0.4022 - mean_io_u_2: 0.4654 - precision_3: 0.2329 - recall_3: 0.8517 - val_accuracy: 0.9048 - val_dice_coeff: 0.1670 - val_loss: 0.5001 - val_mean_absolute_error: 0.3690 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.3846 - val_recall_3: 0.3711 - learning_rate: 1.0000e-06
# Epoch 41/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.7918 - dice_coeff: 0.2082 - loss: 0.4753 - mean_absolute_error: 0.4033 - mean_io_u_2: 0.4659 - precision_3: 0.2286 - recall_3: 0.8645
# Epoch 41: loss did not improve from 0.47136
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 483ms/step - accuracy: 0.7946 - dice_coeff: 0.2097 - loss: 0.4767 - mean_absolute_error: 0.4032 - mean_io_u_2: 0.4654 - precision_3: 0.2312 - recall_3: 0.8461 - val_accuracy: 0.9019 - val_dice_coeff: 0.1693 - val_loss: 0.4987 - val_mean_absolute_error: 0.3695 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.3748 - val_recall_3: 0.3907 - learning_rate: 1.0000e-06
# Epoch 42/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.8040 - dice_coeff: 0.2286 - loss: 0.4630 - mean_absolute_error: 0.3970 - mean_io_u_2: 0.4611 - precision_3: 0.2661 - recall_3: 0.8708
# Epoch 42: loss did not improve from 0.47136
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 479ms/step - accuracy: 0.7989 - dice_coeff: 0.2127 - loss: 0.4734 - mean_absolute_error: 0.4010 - mean_io_u_2: 0.4654 - precision_3: 0.2380 - recall_3: 0.8652 - val_accuracy: 0.8992 - val_dice_coeff: 0.1715 - val_loss: 0.4974 - val_mean_absolute_error: 0.3699 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.3670 - val_recall_3: 0.4072 - learning_rate: 1.0000e-06
# Epoch 43/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.7831 - dice_coeff: 0.2068 - loss: 0.4759 - mean_absolute_error: 0.4045 - mean_io_u_2: 0.4639 - precision_3: 0.2261 - recall_3: 0.8368
# Epoch 43: loss did not improve from 0.47136
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 477ms/step - accuracy: 0.7928 - dice_coeff: 0.2075 - loss: 0.4756 - mean_absolute_error: 0.4027 - mean_io_u_2: 0.4654 - precision_3: 0.2298 - recall_3: 0.8475 - val_accuracy: 0.8952 - val_dice_coeff: 0.1738 - val_loss: 0.4960 - val_mean_absolute_error: 0.3707 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.3567 - val_recall_3: 0.4313 - learning_rate: 1.0000e-07
# Epoch 44/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.8075 - dice_coeff: 0.2290 - loss: 0.4626 - mean_absolute_error: 0.3980 - mean_io_u_2: 0.4597 - precision_3: 0.2740 - recall_3: 0.8321
# Epoch 44: loss did not improve from 0.47136
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 480ms/step - accuracy: 0.7956 - dice_coeff: 0.2035 - loss: 0.4781 - mean_absolute_error: 0.4035 - mean_io_u_2: 0.4654 - precision_3: 0.2310 - recall_3: 0.8379 - val_accuracy: 0.8913 - val_dice_coeff: 0.1761 - val_loss: 0.4946 - val_mean_absolute_error: 0.3715 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.3475 - val_recall_3: 0.4525 - learning_rate: 1.0000e-07
# Epoch 45/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.8022 - dice_coeff: 0.1969 - loss: 0.4821 - mean_absolute_error: 0.4026 - mean_io_u_2: 0.4686 - precision_3: 0.2290 - recall_3: 0.9081
# Epoch 45: loss did not improve from 0.47136
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 479ms/step - accuracy: 0.7974 - dice_coeff: 0.2097 - loss: 0.4761 - mean_absolute_error: 0.4027 - mean_io_u_2: 0.4654 - precision_3: 0.2352 - recall_3: 0.8552 - val_accuracy: 0.8875 - val_dice_coeff: 0.1782 - val_loss: 0.4934 - val_mean_absolute_error: 0.3724 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.3390 - val_recall_3: 0.4693 - learning_rate: 1.0000e-07
# Epoch 46/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.8002 - dice_coeff: 0.2186 - loss: 0.4689 - mean_absolute_error: 0.4002 - mean_io_u_2: 0.4632 - precision_3: 0.2483 - recall_3: 0.8458
# Epoch 46: loss did not improve from 0.47136
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 480ms/step - accuracy: 0.7936 - dice_coeff: 0.2084 - loss: 0.4761 - mean_absolute_error: 0.4034 - mean_io_u_2: 0.4654 - precision_3: 0.2300 - recall_3: 0.8442 - val_accuracy: 0.8831 - val_dice_coeff: 0.1803 - val_loss: 0.4921 - val_mean_absolute_error: 0.3732 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.3299 - val_recall_3: 0.4870 - learning_rate: 1.0000e-07
# Epoch 47/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.7810 - dice_coeff: 0.1797 - loss: 0.4922 - mean_absolute_error: 0.4102 - mean_io_u_2: 0.4697 - precision_3: 0.1905 - recall_3: 0.7950
# Epoch 47: loss did not improve from 0.47136
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 478ms/step - accuracy: 0.7926 - dice_coeff: 0.2095 - loss: 0.4747 - mean_absolute_error: 0.4030 - mean_io_u_2: 0.4654 - precision_3: 0.2286 - recall_3: 0.8407 - val_accuracy: 0.8785 - val_dice_coeff: 0.1823 - val_loss: 0.4909 - val_mean_absolute_error: 0.3744 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.3212 - val_recall_3: 0.5046 - learning_rate: 1.0000e-07
# Epoch 48/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.7919 - dice_coeff: 0.1960 - loss: 0.4827 - mean_absolute_error: 0.4046 - mean_io_u_2: 0.4680 - precision_3: 0.2151 - recall_3: 0.8512
# Epoch 48: loss did not improve from 0.47136
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 477ms/step - accuracy: 0.7983 - dice_coeff: 0.2127 - loss: 0.4751 - mean_absolute_error: 0.4016 - mean_io_u_2: 0.4654 - precision_3: 0.2368 - recall_3: 0.8610 - val_accuracy: 0.8742 - val_dice_coeff: 0.1841 - val_loss: 0.4898 - val_mean_absolute_error: 0.3756 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.3135 - val_recall_3: 0.5183 - learning_rate: 1.0000e-07
# Epoch 49/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.7892 - dice_coeff: 0.1696 - loss: 0.4984 - mean_absolute_error: 0.4089 - mean_io_u_2: 0.4733 - precision_3: 0.1879 - recall_3: 0.8808
# Epoch 49: loss did not improve from 0.47136
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 478ms/step - accuracy: 0.8000 - dice_coeff: 0.2129 - loss: 0.4742 - mean_absolute_error: 0.4011 - mean_io_u_2: 0.4654 - precision_3: 0.2384 - recall_3: 0.8605 - val_accuracy: 0.8697 - val_dice_coeff: 0.1858 - val_loss: 0.4888 - val_mean_absolute_error: 0.3771 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.3062 - val_recall_3: 0.5324 - learning_rate: 1.0000e-07
# Epoch 50/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - accuracy: 0.8147 - dice_coeff: 0.2487 - loss: 0.4506 - mean_absolute_error: 0.3917 - mean_io_u_2: 0.4592 - precision_3: 0.2924 - recall_3: 0.8928
# Epoch 50: loss did not improve from 0.47136
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 482ms/step - accuracy: 0.7969 - dice_coeff: 0.2056 - loss: 0.4746 - mean_absolute_error: 0.4017 - mean_io_u_2: 0.4654 - precision_3: 0.2345 - recall_3: 0.8537 - val_accuracy: 0.8652 - val_dice_coeff: 0.1875 - val_loss: 0.4878 - val_mean_absolute_error: 0.3785 - val_mean_io_u_2: 0.4611 - val_precision_3: 0.2994 - val_recall_3: 0.5467 - learning_rate: 1.0000e-07
# Epoch 50: early stopping

# %% [markdown]
# # Evaluate the results

# %%
preds_train = model.predict(X_train_20[:int(X_train_20.shape[0]*(1-val_split))], verbose=1)
preds_x = model.predict(X_train, verbose=1)
preds_val = model.predict(X_train_20[int(X_train_20.shape[0]*(1-val_split)):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

gt_train = Y_train_20[:int(X_train_20.shape[0]*(1-val_split))].astype(np.float32)
gt_x = Y_train.astype(np.float32)
gt_val = Y_train_20[int(X_train_20.shape[0]*(1-val_split)):].astype(np.float32)
gt_test = Y_test.astype(np.float32)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 601ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 376ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 436ms/step

# %%
# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.float32)
preds_x_t = (preds_x > 0.5).astype(np.float32)
preds_val_t = (preds_val > 0.5).astype(np.float32)
preds_test_t = (preds_test > 0.5).astype(np.float32)

# %%
evalResult(gt_train, preds_train_t)
# Out:
# Accuracy= 0.90051657 Precision= 0.3797932 Recall= 0.6903416 MeanIoU= 0.61001664 DiceCoefficient= 0.3900849260368654 HD= 8.90450702418499 MyIoU= 0.027766865202740718 MAE= 0.0994834

# %%
evalResult(gt_val, preds_val_t)
# Out:
# Accuracy= 0.865177 Precision= 0.29940683 Recall= 0.54668266 MeanIoU= 0.5495217 DiceCoefficient= 0.31039472953355135 HD= 9.671706340803935 MyIoU= 0.011991050997057861 MAE= 0.13482304

# %%
evalResult(gt_x, preds_x_t)
# Out:
# Accuracy= 0.8859074 Precision= 0.37082624 Recall= 0.6185913 MeanIoU= 0.59090304 DiceCoefficient= 0.36657962955518997 HD= 9.196840104105974 MyIoU= 0.021867741720948304 MAE= 0.1140926

# %%
evalResult(gt_test, preds_test_t)
# Out:
# Accuracy= 0.88352036 Precision= 0.31291446 Recall= 0.6193535 MeanIoU= 0.57046354 DiceCoefficient= 0.30604823221853084 HD= 9.396837205797897 MyIoU= 0.020830909465777887 MAE= 0.11647963

# %% [markdown]
# # Output

# %%
print(preds_train_t.shape[0])  # tells you the max valid index + 1
# Out:
# 86

# %%
x=0
xx = [85,10,15]
for i in range(3):
    plt.figure(figsize=(10,10))
    #ix = random.randint(0, len(preds_train))
    ix = xx[i]
    #print(ix)
    #ix = 58
    plt.subplot(3,3,x+1)
    imshow(X_train[:int(X_train.shape[0]*(1-val_split))][ix].astype('uint8'))
    #plt.title('Image')

    plt.subplot(3,3,x+2)
    imshow(np.squeeze(Y_train[:int(Y_train.shape[0]*(1-val_split))][ix]))
    #plt.title('Mask')

    plt.subplot(3,3,x+3)
    imshow(np.squeeze(preds_train_t[ix]))
    #plt.title('Predicted Mask')
    #plt.show()
    
    plt.show()
    evalResult(Y_train[:int(Y_train.shape[0]*(1-val_split))][ix], preds_train_t[ix])
    x = x+3
# Out:
# Accuracy= 0.9371948 Precision= 0.33401638 Recall= 0.24652147 MeanIoU= 0.5508424 DiceCoefficient= 0.710797932020796 HD= 7.14142842854285 MyIoU= 0.009244791666666667 MAE= 0.062805176
# Accuracy= 0.9143982 Precision= 0.51517886 Recall= 0.5898142 MeanIoU= 0.64448047 DiceCoefficient= 0.462503685746924 HD= 7.416198487095663 MyIoU= 0.07431640625000001 MAE= 0.08560181
# Accuracy= 0.9472656 Precision= 0.63426894 Recall= 0.3695387 MeanIoU= 0.6253232 DiceCoefficient= 0.8058065817931492 HD= 8.831760866327848 MyIoU= 0.004622395833333333 MAE= 0.052734375

# %%
x=0
xx = [16,10,15]
for i in range(3):
    plt.figure(figsize=(10,10))
    #ix = random.randint(0, len(preds_train))
    ix = xx[i]
    #print(ix)
    #ix = 58
    plt.subplot(3,3,x+1)
    imshow(X_test[ix].astype('uint8'))
    #plt.title('Image')

    plt.subplot(3,3,x+2)
    imshow(np.squeeze(Y_test[ix]))
    #plt.title('Mask')

    plt.subplot(3,3,x+3)
    imshow(np.squeeze(preds_test_t[ix]))
    #plt.title('Predicted Mask')
    #plt.show()
    
    plt.show()
    evalResult(Y_test[ix], preds_test_t[ix])
    x = x+3
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:149: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
# Accuracy= 0.8277588 Precision= 0.02888429 Recall= 0.9305556 MeanIoU= 0.427848 DiceCoefficient= 0.42322769739985233 HD= 12.288205727444508 MyIoU= 0.04667968749999999 MAE= 0.17224121
# Accuracy= 0.95584106 Precision= 0.5382416 Recall= 0.7026439 MeanIoU= 0.696325 DiceCoefficient= 0.6282579917751718 HD= 6.6332495807108 MyIoU= 0.06490885416666667 MAE= 0.044158936
# Accuracy= 0.8002167 Precision= 0.06358175 Recall= 1.0 MeanIoU= 0.43052554 DiceCoefficient= 0.44760249101273075 HD= 13.638181696985855 MyIoU= 0.004101562499999999 MAE= 0.19978333

# %%
import tensorflow as tf
from tensorflow.keras.metrics import *
from tensorflow.keras.layers import *
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.applications import *
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras.callbacks import *
from tensorflow.keras import backend as K
from hausdorff import hausdorff_distance
# import lr_scheduler
from tensorflow.keras.regularizers import l2

import os
import random
import numpy as np
from tqdm import tqdm
from skimage.io import imread,imshow
from skimage.morphology import label
from skimage.transform import resize
import matplotlib.pyplot as plt
import datetime

# %% [markdown]
# # Dataset

# %%
TRAIN_PATH="../datasets/BUSIS/train/"
TEST_PATH="../datasets/BUSIS/test/"

# %%
train_ids=next(os.walk(TRAIN_PATH+'org/'))[2][:]
test_ids=next(os.walk(TEST_PATH+'org/'))[2][:]
print(len(train_ids))
# Out:
# 624

# %%
input_height = IMG_HEIGHT = 256
input_width = IMG_WIDTH = 256
IMG_CHANNELS = 3

# %%
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.float32)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.float32)
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.float32)
Y_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.float32)

print('Resizing training images and masks')
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):   
    path = TRAIN_PATH + 'org/' + id_
    img = imread(path)[:,:,:IMG_CHANNELS]  
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img #/ 255. #Fill empty X_train with values from img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=bool)
    mask_path = TRAIN_PATH + 'gt/' + id_[:-4] + '_GT.png' # changed this from bmp to png to match the new naming convention
    mask = imread(mask_path)
    mask = np.expand_dims(mask, axis=-1)
    mask = resize(mask, (input_width, input_height, 1), mode='constant', preserve_range=True) # changed this line added 1 to the target shape to maintain the channel dimension
    mask = mask/255
    Y_train[n][mask[:,:,0] > 0.] = 1. # Chamged this line to squeeze the mask before comparison

print('Resizing test images and masks')
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):   
    path = TEST_PATH + 'org/' + id_
    img = imread(path)[:,:,:IMG_CHANNELS]   
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img #/ 255. #Fill empty X_train with values from img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=bool)
    mask_path = TEST_PATH + 'gt/' + id_[:-4] + '_GT.png' # changed this from bmp to png to match the new naming convention
    mask = imread(mask_path)
    mask = np.expand_dims(mask, axis=-1)
    mask = resize(mask, (input_width, input_height, 1), mode='constant', preserve_range=True) # changed this line added 1 to the target shape to maintain the channel dimension
    mask = mask/255
    Y_test[n][mask[:,:,0] > 0.] = 1. # Changes this line to squeeze the mask before comparison
# Out:
# Resizing training images and masks
# 100%|██████████| 624/624 [00:16<00:00, 37.49it/s]
# Resizing test images and masks
# 100%|██████████| 156/156 [00:04<00:00, 34.72it/s]

# %%
X_train = np.load('../datasets/BUSIS/X_train.npy')
Y_train = np.load('../datasets/BUSIS/Y_train.npy')
X_test  = np.load('../datasets/BUSIS/X_test.npy')
Y_test  = np.load('../datasets/BUSIS/Y_test.npy')
print(X_train.shape, Y_test.shape)
# Out:
# (624, 256, 256, 3) (156, 256, 256, 1)

# %%
ix=0
imshow(X_train[ix].astype('int'))
plt.show()
imshow(np.squeeze(Y_train[ix].astype('int')))
plt.show()

# %%
plt.figure(figsize=(30,30))
x, y = 5, 4
count=1
for i in range(y):
    for j in range(x):
        plt.subplot(y*2, x, i*2*x+j+1)
        pos = i+j
        plt.imshow(X_train[pos].astype('int'))
        plt.title('Image {}'.format(count))
        plt.axis('off')
        plt.subplot(y*2, x, (i*2+1)*x+j+1)
        plt.imshow(np.squeeze(Y_train[pos].astype('int')))
        plt.title('Mask {}'.format(count))
        plt.axis('off')
        count = count + 1
plt.show()

# %% [markdown]
# # Model

# %%
def expend_as(tensor, rep):
     return Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3),
                          arguments={'repnum': rep})(tensor)

def double_conv_layer(x, filter_size, size, dropout, batch_norm=False):
    axis = 3
    conv = SeparableConv2D(size, (filter_size, filter_size), padding='same')(x)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = SeparableConv2D(size, (filter_size, filter_size), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    if dropout > 0:
        conv = Dropout(dropout)(conv)

    shortcut = Conv2D(size, kernel_size=(1, 1), padding='same')(x)
    if batch_norm is True:
        shortcut = BatchNormalization(axis=axis)(shortcut)

    res_path = add([shortcut, conv])
    return res_path

def encoder(inputs):
    num_filters = [16, 32, 64, 128]
    skip_connections = []
    x = inputs

    for i, f in enumerate(num_filters):
        a = double_conv_layer(x, 3, f, 0.1, True)
        skip_connections.append(a)
        x = MaxPooling2D(pool_size=(2, 2))(a)
    
    return x, skip_connections

def bottleneck(inputs):
    x = inputs
    f = 256
    
    x3 = double_conv_layer(x, 3, f, 0.1, True)
    
    return x3

def decoder(inputs, skip_connections):
    num_filters = [128, 64, 32, 16]
    skip_connections.reverse()
    x = inputs
    batch_norm = True
    
    for i, f in enumerate(num_filters):
        
        x_up = UpSampling2D(size=(2, 2), data_format="channels_last")(x)
        x_att = concatenate([x_up, skip_connections[i]], axis=-1)
        
        x = double_conv_layer(x_att, 3, f, 0.1, True)
    return x

def output(inputs):
    x = Conv2D(1, kernel_size=(1,1))(inputs)
    x = BatchNormalization()(x)
    x = Activation('sigmoid')(x)
    
    return x

# %% [markdown]
# # Complete model

# %%
inputs = Input((IMG_WIDTH, IMG_HEIGHT, IMG_CHANNELS))
s = layers.Rescaling(1.0 / 255)(inputs)
#s = inputs
x, skip_1 = encoder(s)
x = bottleneck(x)
x = decoder(x, skip_1)
outputs = output(x)
model = Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_1         │ (None, 256, 256,  │          0 │ input_layer_1[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_18 │ (None, 256, 256,  │         91 │ rescaling_1[0][0] │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_19 │ (None, 256, 256,  │        416 │ activation_19[0]… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 256, 256,  │         64 │ rescaling_1[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 256, 256,  │          0 │ activation_20[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 128, 128,  │          0 │ add_9[0][0]       │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_20 │ (None, 128, 128,  │        688 │ max_pooling2d_4[… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_21 │ (None, 128, 128,  │      1,344 │ activation_21[0]… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 128, 128,  │        544 │ max_pooling2d_4[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 128, 128,  │          0 │ activation_22[0]… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 64, 64,    │          0 │ add_10[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_22 │ (None, 64, 64,    │      2,400 │ max_pooling2d_5[… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_23 │ (None, 64, 64,    │      4,736 │ activation_23[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │      2,112 │ max_pooling2d_5[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 64, 64,    │          0 │ activation_24[0]… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ dropout_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 32, 32,    │          0 │ add_11[0][0]      │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_24 │ (None, 32, 32,    │      8,896 │ max_pooling2d_6[… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_25 │ (None, 32, 32,    │     17,664 │ activation_25[0]… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │      8,320 │ max_pooling2d_6[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 32, 32,    │          0 │ activation_26[0]… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ dropout_12[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 16, 16,    │          0 │ add_12[0][0]      │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_26 │ (None, 16, 16,    │     34,176 │ max_pooling2d_7[… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_27 │ (None, 16, 16,    │     68,096 │ activation_27[0]… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 16, 16,    │     33,024 │ max_pooling2d_7[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 16, 16,    │          0 │ activation_28[0]… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (None, 32, 32,    │          0 │ add_13[0][0]      │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 32, 32,    │          0 │ up_sampling2d_4[… │
# │ (Concatenate)       │ 384)              │            │ add_12[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_28 │ (None, 32, 32,    │     52,736 │ concatenate_4[0]… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_29 │ (None, 32, 32,    │     17,664 │ activation_29[0]… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 32, 32,    │     49,280 │ concatenate_4[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 32, 32,    │          0 │ activation_30[0]… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ dropout_14[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_5     │ (None, 64, 64,    │          0 │ add_14[0][0]      │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 64, 64,    │          0 │ up_sampling2d_5[… │
# │ (Concatenate)       │ 192)              │            │ add_11[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_30 │ (None, 64, 64,    │     14,080 │ concatenate_5[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_31 │ (None, 64, 64,    │      4,736 │ activation_31[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 64, 64,    │     12,352 │ concatenate_5[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 64, 64,    │          0 │ activation_32[0]… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ dropout_15[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_6     │ (None, 128, 128,  │          0 │ add_15[0][0]      │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 128, 128,  │          0 │ up_sampling2d_6[… │
# │ (Concatenate)       │ 96)               │            │ add_10[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_32 │ (None, 128, 128,  │      3,968 │ concatenate_6[0]… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_33 │ (None, 128, 128,  │      1,344 │ activation_33[0]… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 128, 128,  │      3,104 │ concatenate_6[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 128, 128,  │          0 │ activation_34[0]… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ dropout_16[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_7     │ (None, 256, 256,  │          0 │ add_16[0][0]      │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 256, 256,  │          0 │ up_sampling2d_7[… │
# │ (Concatenate)       │ 48)               │            │ add_9[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_34 │ (None, 256, 256,  │      1,216 │ concatenate_7[0]… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_35 │ (None, 256, 256,  │        416 │ activation_35[0]… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │        784 │ concatenate_7[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_36       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 256, 256,  │          0 │ activation_36[0]… │
# │ (Dropout)           │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ dropout_17[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 256, 256,  │         17 │ add_17[0][0]      │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │          4 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 353,104 (1.35 MB)
#  Trainable params: 348,686 (1.33 MB)
#  Non-trainable params: 4,418 (17.26 KB)

# %% [markdown]
# # Metrics

# %%
def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = label(y_true_in > 0.5)
    y_pred = label(y_pred_in > 0.5)
    
    true_objects = len(np.unique(labels))
    pred_objects = len(np.unique(y_pred))

    intersection = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))[0]

    # Compute areas (needed for finding the union between all objects)
    area_true = np.histogram(labels, bins = true_objects)[0]
    area_pred = np.histogram(y_pred, bins = pred_objects)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection

    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union
    #print('IOU {}'.format(iou))
    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
    
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    value = 0.
    for batch in range(batch_size):
        value = value + iou_metric(y_true_in[batch], y_pred_in[batch])
    return value/batch_size

def my_iou_metric(label, pred):
    metric_value = tf.py_function(iou_metric_batch, [label, pred], tf.float32)
    return metric_value

def my_iou_metric_loss(label, pred):
    loss = 1-tf.py_function(iou_metric_batch, [label, pred], tf.float32)
    #loss = -tf.map_fn(my_iou_metric_loss(label, pred), tf.range(tf.shape(pred)[0]))
    loss.set_shape((None,))

    return loss

def dice_coeff(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score

def haud_dist(y_true, y_pred):
    y_true = np.squeeze(y_true)
    y_pred = np.squeeze(y_pred)
    
    return hausdorff_distance(y_true,y_pred)

def haud_dist_batch(y_true, y_pred):
    if len(y_true.shape)==2:
        return haud_dist(y_true, y_pred)
    else:
        batch_size = y_true.shape[0]
    hd = 0.
    for batch in range(batch_size):
        hd = hd + haud_dist(y_true[batch], y_pred[batch])
    return hd/batch_size

def my_haud_dist(label, pred):
    metric_value = tf.py_function(haud_dist_batch, [label, pred], tf.float32)
    return metric_value

def evalResult(gt,pred,target_size=(256,256),flag_multi_class = False,num_class = 2):
    gt = np.squeeze(gt)
    pred = np.squeeze(pred)
    
    acc = Accuracy()
    acc.update_state(np.squeeze(gt), np.squeeze(pred))
    r_acc = acc.result().numpy()
    
    pr = Precision()
    pr.update_state(np.squeeze(gt), np.squeeze(pred))
    r_pr = pr.result().numpy()
    
    rc = Recall()
    rc.update_state(np.squeeze(gt), np.squeeze(pred))
    r_rc = rc.result().numpy()
    
    mi = MeanIoU(num_class)
    mi.update_state(np.squeeze(gt), np.squeeze(pred))
    r_mi = mi.result().numpy()
    
    dc = 0.
    for img in range(gt.shape[0]):
        dc = dc + dice_coeff(gt[img], pred[img]).numpy()
    dc = dc / gt.shape[0]
    
    hd = haud_dist_batch(gt,pred)
    
    miou = iou_metric_batch(gt,pred)
    
    mae = MeanAbsoluteError()
    r_mae = mae(np.squeeze(gt), np.squeeze(pred)).numpy()

    print("Accuracy=",r_acc, "Precision=",r_pr, "Recall=",r_rc, "MeanIoU=",r_mi, "DiceCoefficient=",dc, "HD=",hd, "MyIoU=",miou, "MAE=",r_mae)

# %% [markdown]
# # Loss

# %%
def focal_loss(target_tensor, prediction_tensor, weights=None, alpha=0.25, gamma=2):
    sigmoid_p = tf.nn.sigmoid(prediction_tensor)
    zeros = array_ops.zeros_like(sigmoid_p, dtype=sigmoid_p.dtype)
    
    # For poitive prediction, only need consider front part loss, back part is 0;
    # target_tensor > zeros <=> z=1, so poitive coefficient = z - p.
    pos_p_sub = array_ops.where(target_tensor > zeros, target_tensor - sigmoid_p, zeros)
    
    # For negative prediction, only need consider back part loss, front part is 0;
    # target_tensor > zeros <=> z=1, so negative coefficient = 0.
    neg_p_sub = array_ops.where(target_tensor > zeros, zeros, sigmoid_p)
    per_entry_cross_ent = - alpha * (pos_p_sub ** gamma) * tf.math.log(tf.clip_by_value(sigmoid_p, 1e-8, 1.0))                           - (1 - alpha) * (neg_p_sub ** gamma) * tf.math.log(tf.clip_by_value(1.0 - sigmoid_p, 1e-8, 1.0))
    return tf.reduce_sum(per_entry_cross_ent)

def mean_iou_loss(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.compat.v1.to_int32(y_pred > t)
        score, up_opt = tf.compat.v1.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return -tf.math.log(K.mean(K.stack(prec), axis=0))

def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss

def bce_dice_loss(y_true, y_pred):
    loss = 0.4*categorical_crossentropy(y_true, y_pred) + 0.6*dice_loss(y_true, y_pred)
    return loss

def bce_dice_loss2(y_true, y_pred):
    fl = focal_loss(y_true, y_pred, gamma=5)
    loss = 0.2*categorical_crossentropy(y_true, y_pred) + 0.3*dice_loss(y_true, y_pred) + 0.5*fl
    return loss

# %% [markdown]
# # Callbacks

# %%
log_path = "logs/"
keyname = "Unet-without-BT-50"
cur_date = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tb_log_dir = log_path + "fit/" + keyname + '_' + cur_date 
tensorboard_callback = TensorBoard(log_dir=tb_log_dir, histogram_freq=0)
model_checkpoint = ModelCheckpoint('model_'+keyname+'.keras', monitor='loss',verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor='loss', verbose=1, patience=20)
csv_logger = CSVLogger(log_path + keyname + '_' + cur_date + '.log', separator=',', append=False)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10)

# %% [markdown]
# # Training

# %%
TRAIN_FLG = 1 # 0 - No Training, 1 - Training
val_split = 0.3
model.compile(
    loss=bce_dice_loss,
    optimizer=Adam(),
    metrics=['accuracy', Precision(), MeanIoU(num_classes=2), Recall(), dice_coeff, MeanAbsoluteError()]
   )
if TRAIN_FLG:
    print("Training")
    callbacks = [
        model_checkpoint,
        reduce_lr,
        csv_logger,
        tensorboard_callback,
        early_stopping
    ]
    X_train_20 = X_train[:int(X_train.shape[0]*0.05)]
    Y_train_20 = Y_train[:int(Y_train.shape[0]*0.05)]
    results = model.fit(X_train_20, Y_train_20, validation_split=val_split, batch_size=8, epochs=200, callbacks=callbacks)
elif not TRAIN_FLG:
    print("Loading training weights")
    model.load_weights('model_'+keyname+'.keras')
# Out:
# Training
# Epoch 1/200
# C:\Users\ujai264\AppData\Local\Temp\ipykernel_17308\3548703083.py:31: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 256, 256, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   loss = 0.4*categorical_crossentropy(y_true, y_pred) + 0.6*dice_loss(y_true, y_pred)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.5559 - dice_coeff: 0.0871 - loss: 0.5469 - mean_absolute_error: 0.4858 - mean_io_u_11: 0.4787 - precision_11: 0.0530 - recall_11: 0.5557
# Epoch 1: loss improved from None to 0.54847, saving model to model_Unet-without-BT-50.keras
#
# Epoch 1: finished saving model to model_Unet-without-BT-50.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 11s 883ms/step - accuracy: 0.5748 - dice_coeff: 0.0816 - loss: 0.5485 - mean_absolute_error: 0.4833 - mean_io_u_11: 0.4797 - precision_11: 0.0523 - recall_11: 0.5527 - val_accuracy: 0.8626 - val_dice_coeff: 0.2233 - val_loss: 0.4729 - val_mean_absolute_error: 0.4459 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.5242 - val_recall_11: 0.0256 - learning_rate: 0.0010
# Epoch 2/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.6603 - dice_coeff: 0.1067 - loss: 0.5368 - mean_absolute_error: 0.4672 - mean_io_u_11: 0.4798 - precision_11: 0.0919 - recall_11: 0.8301
# Epoch 2: loss improved from 0.54847 to 0.53704, saving model to model_Unet-without-BT-50.keras
#
# Epoch 2: finished saving model to model_Unet-without-BT-50.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 489ms/step - accuracy: 0.6433 - dice_coeff: 0.1088 - loss: 0.5370 - mean_absolute_error: 0.4684 - mean_io_u_11: 0.4797 - precision_11: 0.0858 - recall_11: 0.8064 - val_accuracy: 0.8637 - val_dice_coeff: 0.2185 - val_loss: 0.4747 - val_mean_absolute_error: 0.4239 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.8352 - val_recall_11: 0.0127 - learning_rate: 0.0010
# Epoch 3/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.6149 - dice_coeff: 0.1102 - loss: 0.5333 - mean_absolute_error: 0.4652 - mean_io_u_11: 0.4812 - precision_11: 0.0836 - recall_11: 0.9250
# Epoch 3: loss improved from 0.53704 to 0.52756, saving model to model_Unet-without-BT-50.keras
#
# Epoch 3: finished saving model to model_Unet-without-BT-50.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 484ms/step - accuracy: 0.6151 - dice_coeff: 0.1178 - loss: 0.5276 - mean_absolute_error: 0.4634 - mean_io_u_11: 0.4797 - precision_11: 0.0904 - recall_11: 0.9353 - val_accuracy: 0.8633 - val_dice_coeff: 0.2187 - val_loss: 0.4757 - val_mean_absolute_error: 0.4231 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.8156 - val_recall_11: 0.0096 - learning_rate: 0.0010
# Epoch 4/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.6322 - dice_coeff: 0.1235 - loss: 0.5260 - mean_absolute_error: 0.4605 - mean_io_u_11: 0.4799 - precision_11: 0.0917 - recall_11: 0.9141
# Epoch 4: loss improved from 0.52756 to 0.52298, saving model to model_Unet-without-BT-50.keras
#
# Epoch 4: finished saving model to model_Unet-without-BT-50.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 485ms/step - accuracy: 0.6499 - dice_coeff: 0.1290 - loss: 0.5230 - mean_absolute_error: 0.4568 - mean_io_u_11: 0.4797 - precision_11: 0.0986 - recall_11: 0.9362 - val_accuracy: 0.8625 - val_dice_coeff: 0.2082 - val_loss: 0.4805 - val_mean_absolute_error: 0.3785 - val_mean_io_u_11: 0.4312 - val_precision_11: 1.0000 - val_recall_11: 0.0016 - learning_rate: 0.0010
# Epoch 5/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.6996 - dice_coeff: 0.1313 - loss: 0.5222 - mean_absolute_error: 0.4486 - mean_io_u_11: 0.4812 - precision_11: 0.1083 - recall_11: 0.9660
# Epoch 5: loss improved from 0.52298 to 0.51862, saving model to model_Unet-without-BT-50.keras
#
# Epoch 5: finished saving model to model_Unet-without-BT-50.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 481ms/step - accuracy: 0.7059 - dice_coeff: 0.1406 - loss: 0.5186 - mean_absolute_error: 0.4480 - mean_io_u_11: 0.4797 - precision_11: 0.1171 - recall_11: 0.9539 - val_accuracy: 0.8623 - val_dice_coeff: 0.2036 - val_loss: 0.4826 - val_mean_absolute_error: 0.3626 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 0.0010
# Epoch 6/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.7279 - dice_coeff: 0.1408 - loss: 0.5160 - mean_absolute_error: 0.4442 - mean_io_u_11: 0.4798 - precision_11: 0.1271 - recall_11: 0.9767
# Epoch 6: loss improved from 0.51862 to 0.51576, saving model to model_Unet-without-BT-50.keras
#
# Epoch 6: finished saving model to model_Unet-without-BT-50.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 495ms/step - accuracy: 0.7311 - dice_coeff: 0.1428 - loss: 0.5158 - mean_absolute_error: 0.4439 - mean_io_u_11: 0.4797 - precision_11: 0.1284 - recall_11: 0.9710 - val_accuracy: 0.8623 - val_dice_coeff: 0.2006 - val_loss: 0.4845 - val_mean_absolute_error: 0.3528 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 0.0010
# Epoch 7/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.7591 - dice_coeff: 0.1244 - loss: 0.5267 - mean_absolute_error: 0.4456 - mean_io_u_11: 0.4827 - precision_11: 0.1230 - recall_11: 0.9683
# Epoch 7: loss did not improve from 0.51576
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 398ms/step - accuracy: 0.7746 - dice_coeff: 0.1458 - loss: 0.5166 - mean_absolute_error: 0.4417 - mean_io_u_11: 0.4797 - precision_11: 0.1483 - recall_11: 0.9588 - val_accuracy: 0.8623 - val_dice_coeff: 0.1984 - val_loss: 0.4863 - val_mean_absolute_error: 0.3462 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 0.0010
# Epoch 8/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.8068 - dice_coeff: 0.1427 - loss: 0.5136 - mean_absolute_error: 0.4372 - mean_io_u_11: 0.4799 - precision_11: 0.1702 - recall_11: 0.9781
# Epoch 8: loss improved from 0.51576 to 0.51538, saving model to model_Unet-without-BT-50.keras
#
# Epoch 8: finished saving model to model_Unet-without-BT-50.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 495ms/step - accuracy: 0.8091 - dice_coeff: 0.1368 - loss: 0.5154 - mean_absolute_error: 0.4388 - mean_io_u_11: 0.4797 - precision_11: 0.1702 - recall_11: 0.9545 - val_accuracy: 0.8623 - val_dice_coeff: 0.2060 - val_loss: 0.4834 - val_mean_absolute_error: 0.3711 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 0.0010
# Epoch 9/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.8337 - dice_coeff: 0.1692 - loss: 0.4984 - mean_absolute_error: 0.4283 - mean_io_u_11: 0.4760 - precision_11: 0.2256 - recall_11: 0.9910
# Epoch 9: loss improved from 0.51538 to 0.51380, saving model to model_Unet-without-BT-50.keras
#
# Epoch 9: finished saving model to model_Unet-without-BT-50.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 474ms/step - accuracy: 0.8205 - dice_coeff: 0.1430 - loss: 0.5138 - mean_absolute_error: 0.4359 - mean_io_u_11: 0.4797 - precision_11: 0.1825 - recall_11: 0.9832 - val_accuracy: 0.8623 - val_dice_coeff: 0.2088 - val_loss: 0.4816 - val_mean_absolute_error: 0.3822 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 0.0010
# Epoch 10/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.8109 - dice_coeff: 0.1216 - loss: 0.5274 - mean_absolute_error: 0.4415 - mean_io_u_11: 0.4830 - precision_11: 0.1524 - recall_11: 0.9814
# Epoch 10: loss improved from 0.51380 to 0.51362, saving model to model_Unet-without-BT-50.keras
#
# Epoch 10: finished saving model to model_Unet-without-BT-50.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 496ms/step - accuracy: 0.8289 - dice_coeff: 0.1458 - loss: 0.5136 - mean_absolute_error: 0.4349 - mean_io_u_11: 0.4797 - precision_11: 0.1894 - recall_11: 0.9801 - val_accuracy: 0.8623 - val_dice_coeff: 0.2041 - val_loss: 0.4846 - val_mean_absolute_error: 0.3650 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 0.0010
# Epoch 11/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.8428 - dice_coeff: 0.1683 - loss: 0.4977 - mean_absolute_error: 0.4275 - mean_io_u_11: 0.4755 - precision_11: 0.2376 - recall_11: 0.9835
# Epoch 11: loss improved from 0.51362 to 0.51280, saving model to model_Unet-without-BT-50.keras
#
# Epoch 11: finished saving model to model_Unet-without-BT-50.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 475ms/step - accuracy: 0.8275 - dice_coeff: 0.1389 - loss: 0.5128 - mean_absolute_error: 0.4336 - mean_io_u_11: 0.4797 - precision_11: 0.1891 - recall_11: 0.9873 - val_accuracy: 0.8623 - val_dice_coeff: 0.2065 - val_loss: 0.4842 - val_mean_absolute_error: 0.3735 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 0.0010
# Epoch 12/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.8402 - dice_coeff: 0.1548 - loss: 0.5060 - mean_absolute_error: 0.4293 - mean_io_u_11: 0.4785 - precision_11: 0.2103 - recall_11: 0.9863
# Epoch 12: loss improved from 0.51280 to 0.51047, saving model to model_Unet-without-BT-50.keras
#
# Epoch 12: finished saving model to model_Unet-without-BT-50.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 487ms/step - accuracy: 0.8345 - dice_coeff: 0.1434 - loss: 0.5105 - mean_absolute_error: 0.4312 - mean_io_u_11: 0.4797 - precision_11: 0.1955 - recall_11: 0.9872 - val_accuracy: 0.8623 - val_dice_coeff: 0.2078 - val_loss: 0.4835 - val_mean_absolute_error: 0.3786 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 13/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.8417 - dice_coeff: 0.1429 - loss: 0.5150 - mean_absolute_error: 0.4317 - mean_io_u_11: 0.4814 - precision_11: 0.1899 - recall_11: 0.9941
# Epoch 13: loss improved from 0.51047 to 0.50870, saving model to model_Unet-without-BT-50.keras
#
# Epoch 13: finished saving model to model_Unet-without-BT-50.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 492ms/step - accuracy: 0.8418 - dice_coeff: 0.1558 - loss: 0.5087 - mean_absolute_error: 0.4293 - mean_io_u_11: 0.4797 - precision_11: 0.2037 - recall_11: 0.9948 - val_accuracy: 0.8623 - val_dice_coeff: 0.2094 - val_loss: 0.4826 - val_mean_absolute_error: 0.3849 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 14/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.8395 - dice_coeff: 0.1582 - loss: 0.5039 - mean_absolute_error: 0.4277 - mean_io_u_11: 0.4784 - precision_11: 0.2111 - recall_11: 0.9903
# Epoch 14: loss did not improve from 0.50870
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 433ms/step - accuracy: 0.8409 - dice_coeff: 0.1462 - loss: 0.5088 - mean_absolute_error: 0.4293 - mean_io_u_11: 0.4797 - precision_11: 0.2024 - recall_11: 0.9915 - val_accuracy: 0.8623 - val_dice_coeff: 0.2112 - val_loss: 0.4816 - val_mean_absolute_error: 0.3922 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 15/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.8567 - dice_coeff: 0.1545 - loss: 0.5073 - mean_absolute_error: 0.4283 - mean_io_u_11: 0.4794 - precision_11: 0.2224 - recall_11: 0.9936
# Epoch 15: loss improved from 0.50870 to 0.50805, saving model to model_Unet-without-BT-50.keras
#
# Epoch 15: finished saving model to model_Unet-without-BT-50.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 493ms/step - accuracy: 0.8519 - dice_coeff: 0.1534 - loss: 0.5080 - mean_absolute_error: 0.4285 - mean_io_u_11: 0.4797 - precision_11: 0.2144 - recall_11: 0.9936 - val_accuracy: 0.8623 - val_dice_coeff: 0.2126 - val_loss: 0.4809 - val_mean_absolute_error: 0.3981 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 16/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.8711 - dice_coeff: 0.1776 - loss: 0.4915 - mean_absolute_error: 0.4205 - mean_io_u_11: 0.4754 - precision_11: 0.2796 - recall_11: 0.9957
# Epoch 16: loss did not improve from 0.50805
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 415ms/step - accuracy: 0.8504 - dice_coeff: 0.1414 - loss: 0.5092 - mean_absolute_error: 0.4289 - mean_io_u_11: 0.4797 - precision_11: 0.2128 - recall_11: 0.9946 - val_accuracy: 0.8623 - val_dice_coeff: 0.2138 - val_loss: 0.4803 - val_mean_absolute_error: 0.4029 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 17/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.8595 - dice_coeff: 0.1516 - loss: 0.5097 - mean_absolute_error: 0.4288 - mean_io_u_11: 0.4802 - precision_11: 0.2192 - recall_11: 0.9952
# Epoch 17: loss did not improve from 0.50805
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 416ms/step - accuracy: 0.8536 - dice_coeff: 0.1554 - loss: 0.5088 - mean_absolute_error: 0.4293 - mean_io_u_11: 0.4797 - precision_11: 0.2161 - recall_11: 0.9915 - val_accuracy: 0.8623 - val_dice_coeff: 0.2145 - val_loss: 0.4798 - val_mean_absolute_error: 0.4061 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 18/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.8801 - dice_coeff: 0.1696 - loss: 0.4960 - mean_absolute_error: 0.4223 - mean_io_u_11: 0.4766 - precision_11: 0.2807 - recall_11: 0.9948
# Epoch 18: loss did not improve from 0.50805
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 433ms/step - accuracy: 0.8682 - dice_coeff: 0.1406 - loss: 0.5090 - mean_absolute_error: 0.4283 - mean_io_u_11: 0.4797 - precision_11: 0.2348 - recall_11: 0.9944 - val_accuracy: 0.8623 - val_dice_coeff: 0.2150 - val_loss: 0.4796 - val_mean_absolute_error: 0.4086 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 19/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.8608 - dice_coeff: 0.1342 - loss: 0.5216 - mean_absolute_error: 0.4341 - mean_io_u_11: 0.4829 - precision_11: 0.1970 - recall_11: 0.9934
# Epoch 19: loss did not improve from 0.50805
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 419ms/step - accuracy: 0.8725 - dice_coeff: 0.1619 - loss: 0.5093 - mean_absolute_error: 0.4285 - mean_io_u_11: 0.4797 - precision_11: 0.2407 - recall_11: 0.9935 - val_accuracy: 0.8623 - val_dice_coeff: 0.2153 - val_loss: 0.4794 - val_mean_absolute_error: 0.4100 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 20/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.8828 - dice_coeff: 0.1607 - loss: 0.5046 - mean_absolute_error: 0.4255 - mean_io_u_11: 0.4790 - precision_11: 0.2667 - recall_11: 0.9972
# Epoch 20: loss did not improve from 0.50805
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 412ms/step - accuracy: 0.8731 - dice_coeff: 0.1577 - loss: 0.5084 - mean_absolute_error: 0.4277 - mean_io_u_11: 0.4797 - precision_11: 0.2418 - recall_11: 0.9955 - val_accuracy: 0.8623 - val_dice_coeff: 0.2154 - val_loss: 0.4794 - val_mean_absolute_error: 0.4104 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 21/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.8594 - dice_coeff: 0.1360 - loss: 0.5213 - mean_absolute_error: 0.4334 - mean_io_u_11: 0.4828 - precision_11: 0.1961 - recall_11: 0.9907
# Epoch 21: loss did not improve from 0.50805
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 417ms/step - accuracy: 0.8704 - dice_coeff: 0.1639 - loss: 0.5104 - mean_absolute_error: 0.4287 - mean_io_u_11: 0.4797 - precision_11: 0.2377 - recall_11: 0.9926 - val_accuracy: 0.8623 - val_dice_coeff: 0.2156 - val_loss: 0.4793 - val_mean_absolute_error: 0.4113 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 22/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.8836 - dice_coeff: 0.1689 - loss: 0.4984 - mean_absolute_error: 0.4229 - mean_io_u_11: 0.4773 - precision_11: 0.2818 - recall_11: 0.9935
# Epoch 22: loss improved from 0.50805 to 0.50780, saving model to model_Unet-without-BT-50.keras
#
# Epoch 22: finished saving model to model_Unet-without-BT-50.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step - accuracy: 0.8768 - dice_coeff: 0.1526 - loss: 0.5078 - mean_absolute_error: 0.4271 - mean_io_u_11: 0.4797 - precision_11: 0.2473 - recall_11: 0.9953 - val_accuracy: 0.8623 - val_dice_coeff: 0.2159 - val_loss: 0.4792 - val_mean_absolute_error: 0.4128 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 23/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8688 - dice_coeff: 0.1445 - loss: 0.5117 - mean_absolute_error: 0.4293 - mean_io_u_11: 0.4804 - precision_11: 0.2310 - recall_11: 0.9960
# Epoch 23: loss did not improve from 0.50780
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 414ms/step - accuracy: 0.8727 - dice_coeff: 0.1431 - loss: 0.5094 - mean_absolute_error: 0.4282 - mean_io_u_11: 0.4797 - precision_11: 0.2412 - recall_11: 0.9944 - val_accuracy: 0.8623 - val_dice_coeff: 0.2162 - val_loss: 0.4790 - val_mean_absolute_error: 0.4139 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 24/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.8775 - dice_coeff: 0.1539 - loss: 0.5081 - mean_absolute_error: 0.4273 - mean_io_u_11: 0.4799 - precision_11: 0.2469 - recall_11: 0.9963
# Epoch 24: loss improved from 0.50780 to 0.50761, saving model to model_Unet-without-BT-50.keras
#
# Epoch 24: finished saving model to model_Unet-without-BT-50.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 496ms/step - accuracy: 0.8765 - dice_coeff: 0.1562 - loss: 0.5076 - mean_absolute_error: 0.4272 - mean_io_u_11: 0.4797 - precision_11: 0.2466 - recall_11: 0.9938 - val_accuracy: 0.8623 - val_dice_coeff: 0.2164 - val_loss: 0.4789 - val_mean_absolute_error: 0.4150 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 25/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8880 - dice_coeff: 0.1691 - loss: 0.4977 - mean_absolute_error: 0.4226 - mean_io_u_11: 0.4771 - precision_11: 0.2901 - recall_11: 0.9969
# Epoch 25: loss did not improve from 0.50761
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 413ms/step - accuracy: 0.8808 - dice_coeff: 0.1494 - loss: 0.5079 - mean_absolute_error: 0.4270 - mean_io_u_11: 0.4797 - precision_11: 0.2536 - recall_11: 0.9962 - val_accuracy: 0.8623 - val_dice_coeff: 0.2166 - val_loss: 0.4788 - val_mean_absolute_error: 0.4159 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 26/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.8804 - dice_coeff: 0.1543 - loss: 0.5075 - mean_absolute_error: 0.4267 - mean_io_u_11: 0.4798 - precision_11: 0.2519 - recall_11: 0.9972
# Epoch 26: loss improved from 0.50761 to 0.50685, saving model to model_Unet-without-BT-50.keras
#
# Epoch 26: finished saving model to model_Unet-without-BT-50.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step - accuracy: 0.8797 - dice_coeff: 0.1556 - loss: 0.5069 - mean_absolute_error: 0.4263 - mean_io_u_11: 0.4797 - precision_11: 0.2519 - recall_11: 0.9965 - val_accuracy: 0.8623 - val_dice_coeff: 0.2168 - val_loss: 0.4787 - val_mean_absolute_error: 0.4169 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 27/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.8853 - dice_coeff: 0.1602 - loss: 0.5034 - mean_absolute_error: 0.4253 - mean_io_u_11: 0.4786 - precision_11: 0.2714 - recall_11: 0.9951
# Epoch 27: loss did not improve from 0.50685
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 412ms/step - accuracy: 0.8754 - dice_coeff: 0.1510 - loss: 0.5081 - mean_absolute_error: 0.4277 - mean_io_u_11: 0.4797 - precision_11: 0.2451 - recall_11: 0.9939 - val_accuracy: 0.8623 - val_dice_coeff: 0.2170 - val_loss: 0.4787 - val_mean_absolute_error: 0.4176 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 28/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.8624 - dice_coeff: 0.1345 - loss: 0.5191 - mean_absolute_error: 0.4326 - mean_io_u_11: 0.4822 - precision_11: 0.2084 - recall_11: 0.9966
# Epoch 28: loss did not improve from 0.50685
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 418ms/step - accuracy: 0.8744 - dice_coeff: 0.1515 - loss: 0.5084 - mean_absolute_error: 0.4273 - mean_io_u_11: 0.4797 - precision_11: 0.2437 - recall_11: 0.9951 - val_accuracy: 0.8623 - val_dice_coeff: 0.2171 - val_loss: 0.4786 - val_mean_absolute_error: 0.4184 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 29/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8547 - dice_coeff: 0.1276 - loss: 0.5255 - mean_absolute_error: 0.4355 - mean_io_u_11: 0.4838 - precision_11: 0.1844 - recall_11: 0.9923
# Epoch 29: loss did not improve from 0.50685
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 412ms/step - accuracy: 0.8728 - dice_coeff: 0.1624 - loss: 0.5088 - mean_absolute_error: 0.4276 - mean_io_u_11: 0.4797 - precision_11: 0.2415 - recall_11: 0.9952 - val_accuracy: 0.8623 - val_dice_coeff: 0.2172 - val_loss: 0.4785 - val_mean_absolute_error: 0.4190 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 30/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.8801 - dice_coeff: 0.1485 - loss: 0.5105 - mean_absolute_error: 0.4278 - mean_io_u_11: 0.4805 - precision_11: 0.2463 - recall_11: 0.9981
# Epoch 30: loss did not improve from 0.50685
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 431ms/step - accuracy: 0.8837 - dice_coeff: 0.1525 - loss: 0.5072 - mean_absolute_error: 0.4263 - mean_io_u_11: 0.4797 - precision_11: 0.2583 - recall_11: 0.9964 - val_accuracy: 0.8623 - val_dice_coeff: 0.2174 - val_loss: 0.4784 - val_mean_absolute_error: 0.4198 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 31/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.8841 - dice_coeff: 0.1554 - loss: 0.5070 - mean_absolute_error: 0.4262 - mean_io_u_11: 0.4798 - precision_11: 0.2585 - recall_11: 0.9975
# Epoch 31: loss improved from 0.50685 to 0.50670, saving model to model_Unet-without-BT-50.keras
#
# Epoch 31: finished saving model to model_Unet-without-BT-50.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step - accuracy: 0.8868 - dice_coeff: 0.1566 - loss: 0.5067 - mean_absolute_error: 0.4260 - mean_io_u_11: 0.4797 - precision_11: 0.2637 - recall_11: 0.9969 - val_accuracy: 0.8623 - val_dice_coeff: 0.2176 - val_loss: 0.4784 - val_mean_absolute_error: 0.4205 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 32/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.8690 - dice_coeff: 0.1448 - loss: 0.5149 - mean_absolute_error: 0.4302 - mean_io_u_11: 0.4816 - precision_11: 0.2203 - recall_11: 0.9970
# Epoch 32: loss did not improve from 0.50670
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 434ms/step - accuracy: 0.8817 - dice_coeff: 0.1631 - loss: 0.5076 - mean_absolute_error: 0.4266 - mean_io_u_11: 0.4797 - precision_11: 0.2550 - recall_11: 0.9963 - val_accuracy: 0.8623 - val_dice_coeff: 0.2177 - val_loss: 0.4783 - val_mean_absolute_error: 0.4211 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-06
# Epoch 33/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.8831 - dice_coeff: 0.1525 - loss: 0.5077 - mean_absolute_error: 0.4265 - mean_io_u_11: 0.4799 - precision_11: 0.2563 - recall_11: 0.9967
# Epoch 33: loss did not improve from 0.50670
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 448ms/step - accuracy: 0.8849 - dice_coeff: 0.1508 - loss: 0.5072 - mean_absolute_error: 0.4264 - mean_io_u_11: 0.4797 - precision_11: 0.2604 - recall_11: 0.9960 - val_accuracy: 0.8623 - val_dice_coeff: 0.2178 - val_loss: 0.4782 - val_mean_absolute_error: 0.4218 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-06
# Epoch 34/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.8665 - dice_coeff: 0.1408 - loss: 0.5180 - mean_absolute_error: 0.4315 - mean_io_u_11: 0.4822 - precision_11: 0.2108 - recall_11: 0.9950
# Epoch 34: loss did not improve from 0.50670
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 450ms/step - accuracy: 0.8735 - dice_coeff: 0.1637 - loss: 0.5092 - mean_absolute_error: 0.4277 - mean_io_u_11: 0.4797 - precision_11: 0.2424 - recall_11: 0.9950 - val_accuracy: 0.8623 - val_dice_coeff: 0.2179 - val_loss: 0.4782 - val_mean_absolute_error: 0.4223 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-06
# Epoch 35/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.8774 - dice_coeff: 0.1401 - loss: 0.5158 - mean_absolute_error: 0.4304 - mean_io_u_11: 0.4816 - precision_11: 0.2304 - recall_11: 0.9932
# Epoch 35: loss did not improve from 0.50670
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 427ms/step - accuracy: 0.8814 - dice_coeff: 0.1530 - loss: 0.5078 - mean_absolute_error: 0.4267 - mean_io_u_11: 0.4797 - precision_11: 0.2545 - recall_11: 0.9954 - val_accuracy: 0.8623 - val_dice_coeff: 0.2180 - val_loss: 0.4781 - val_mean_absolute_error: 0.4228 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-06
# Epoch 36/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8596 - dice_coeff: 0.1321 - loss: 0.5215 - mean_absolute_error: 0.4332 - mean_io_u_11: 0.4830 - precision_11: 0.1992 - recall_11: 0.9983
# Epoch 36: loss did not improve from 0.50670
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 421ms/step - accuracy: 0.8770 - dice_coeff: 0.1572 - loss: 0.5080 - mean_absolute_error: 0.4270 - mean_io_u_11: 0.4797 - precision_11: 0.2476 - recall_11: 0.9960 - val_accuracy: 0.8623 - val_dice_coeff: 0.2181 - val_loss: 0.4781 - val_mean_absolute_error: 0.4232 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-06
# Epoch 37/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.8829 - dice_coeff: 0.1546 - loss: 0.5081 - mean_absolute_error: 0.4265 - mean_io_u_11: 0.4800 - precision_11: 0.2545 - recall_11: 0.9970
# Epoch 37: loss did not improve from 0.50670
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 426ms/step - accuracy: 0.8822 - dice_coeff: 0.1591 - loss: 0.5071 - mean_absolute_error: 0.4262 - mean_io_u_11: 0.4797 - precision_11: 0.2561 - recall_11: 0.9969 - val_accuracy: 0.8623 - val_dice_coeff: 0.2182 - val_loss: 0.4780 - val_mean_absolute_error: 0.4237 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-06
# Epoch 38/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.8679 - dice_coeff: 0.1519 - loss: 0.5098 - mean_absolute_error: 0.4287 - mean_io_u_11: 0.4800 - precision_11: 0.2309 - recall_11: 0.9912
# Epoch 38: loss did not improve from 0.50670
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 445ms/step - accuracy: 0.8704 - dice_coeff: 0.1583 - loss: 0.5079 - mean_absolute_error: 0.4275 - mean_io_u_11: 0.4797 - precision_11: 0.2379 - recall_11: 0.9944 - val_accuracy: 0.8623 - val_dice_coeff: 0.2183 - val_loss: 0.4780 - val_mean_absolute_error: 0.4239 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-06
# Epoch 39/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.8851 - dice_coeff: 0.1636 - loss: 0.5019 - mean_absolute_error: 0.4242 - mean_io_u_11: 0.4783 - precision_11: 0.2766 - recall_11: 0.9963
# Epoch 39: loss did not improve from 0.50670
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 435ms/step - accuracy: 0.8760 - dice_coeff: 0.1542 - loss: 0.5075 - mean_absolute_error: 0.4268 - mean_io_u_11: 0.4797 - precision_11: 0.2461 - recall_11: 0.9955 - val_accuracy: 0.8623 - val_dice_coeff: 0.2183 - val_loss: 0.4780 - val_mean_absolute_error: 0.4241 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-06
# Epoch 40/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.8872 - dice_coeff: 0.1533 - loss: 0.5072 - mean_absolute_error: 0.4264 - mean_io_u_11: 0.4797 - precision_11: 0.2642 - recall_11: 0.9977
# Epoch 40: loss did not improve from 0.50670
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 436ms/step - accuracy: 0.8809 - dice_coeff: 0.1504 - loss: 0.5073 - mean_absolute_error: 0.4266 - mean_io_u_11: 0.4797 - precision_11: 0.2539 - recall_11: 0.9966 - val_accuracy: 0.8623 - val_dice_coeff: 0.2184 - val_loss: 0.4780 - val_mean_absolute_error: 0.4245 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-06
# Epoch 41/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.8681 - dice_coeff: 0.1362 - loss: 0.5164 - mean_absolute_error: 0.4311 - mean_io_u_11: 0.4813 - precision_11: 0.2233 - recall_11: 0.9965
# Epoch 41: loss did not improve from 0.50670
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 433ms/step - accuracy: 0.8717 - dice_coeff: 0.1402 - loss: 0.5102 - mean_absolute_error: 0.4282 - mean_io_u_11: 0.4797 - precision_11: 0.2401 - recall_11: 0.9971 - val_accuracy: 0.8623 - val_dice_coeff: 0.2185 - val_loss: 0.4779 - val_mean_absolute_error: 0.4247 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-06
# Epoch 42/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.8787 - dice_coeff: 0.1484 - loss: 0.5100 - mean_absolute_error: 0.4279 - mean_io_u_11: 0.4803 - precision_11: 0.2454 - recall_11: 0.9974
# Epoch 42: loss did not improve from 0.50670
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 440ms/step - accuracy: 0.8764 - dice_coeff: 0.1487 - loss: 0.5078 - mean_absolute_error: 0.4269 - mean_io_u_11: 0.4797 - precision_11: 0.2468 - recall_11: 0.9961 - val_accuracy: 0.8623 - val_dice_coeff: 0.2185 - val_loss: 0.4779 - val_mean_absolute_error: 0.4250 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 43/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.8779 - dice_coeff: 0.1521 - loss: 0.5070 - mean_absolute_error: 0.4263 - mean_io_u_11: 0.4796 - precision_11: 0.2508 - recall_11: 0.9968
# Epoch 43: loss did not improve from 0.50670
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 431ms/step - accuracy: 0.8776 - dice_coeff: 0.1451 - loss: 0.5079 - mean_absolute_error: 0.4268 - mean_io_u_11: 0.4797 - precision_11: 0.2485 - recall_11: 0.9956 - val_accuracy: 0.8623 - val_dice_coeff: 0.2186 - val_loss: 0.4779 - val_mean_absolute_error: 0.4253 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 44/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.8785 - dice_coeff: 0.1499 - loss: 0.5107 - mean_absolute_error: 0.4280 - mean_io_u_11: 0.4806 - precision_11: 0.2413 - recall_11: 0.9976
# Epoch 44: loss did not improve from 0.50670
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 435ms/step - accuracy: 0.8760 - dice_coeff: 0.1580 - loss: 0.5072 - mean_absolute_error: 0.4265 - mean_io_u_11: 0.4797 - precision_11: 0.2462 - recall_11: 0.9956 - val_accuracy: 0.8623 - val_dice_coeff: 0.2186 - val_loss: 0.4779 - val_mean_absolute_error: 0.4255 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 45/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.8729 - dice_coeff: 0.1512 - loss: 0.5105 - mean_absolute_error: 0.4282 - mean_io_u_11: 0.4805 - precision_11: 0.2347 - recall_11: 0.9952
# Epoch 45: loss did not improve from 0.50670
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 432ms/step - accuracy: 0.8778 - dice_coeff: 0.1599 - loss: 0.5077 - mean_absolute_error: 0.4269 - mean_io_u_11: 0.4797 - precision_11: 0.2489 - recall_11: 0.9947 - val_accuracy: 0.8623 - val_dice_coeff: 0.2187 - val_loss: 0.4778 - val_mean_absolute_error: 0.4259 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 46/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.8884 - dice_coeff: 0.1583 - loss: 0.5047 - mean_absolute_error: 0.4249 - mean_io_u_11: 0.4792 - precision_11: 0.2710 - recall_11: 0.9973
# Epoch 46: loss improved from 0.50670 to 0.50668, saving model to model_Unet-without-BT-50.keras
#
# Epoch 46: finished saving model to model_Unet-without-BT-50.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 550ms/step - accuracy: 0.8843 - dice_coeff: 0.1539 - loss: 0.5067 - mean_absolute_error: 0.4260 - mean_io_u_11: 0.4797 - precision_11: 0.2595 - recall_11: 0.9977 - val_accuracy: 0.8623 - val_dice_coeff: 0.2188 - val_loss: 0.4778 - val_mean_absolute_error: 0.4261 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 47/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.8665 - dice_coeff: 0.1444 - loss: 0.5134 - mean_absolute_error: 0.4297 - mean_io_u_11: 0.4811 - precision_11: 0.2217 - recall_11: 0.9966
# Epoch 47: loss did not improve from 0.50668
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 437ms/step - accuracy: 0.8754 - dice_coeff: 0.1543 - loss: 0.5076 - mean_absolute_error: 0.4269 - mean_io_u_11: 0.4797 - precision_11: 0.2453 - recall_11: 0.9956 - val_accuracy: 0.8623 - val_dice_coeff: 0.2188 - val_loss: 0.4778 - val_mean_absolute_error: 0.4263 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 48/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.8799 - dice_coeff: 0.1444 - loss: 0.5135 - mean_absolute_error: 0.4292 - mean_io_u_11: 0.4813 - precision_11: 0.2374 - recall_11: 0.9973
# Epoch 48: loss did not improve from 0.50668
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 429ms/step - accuracy: 0.8782 - dice_coeff: 0.1554 - loss: 0.5072 - mean_absolute_error: 0.4265 - mean_io_u_11: 0.4797 - precision_11: 0.2496 - recall_11: 0.9965 - val_accuracy: 0.8623 - val_dice_coeff: 0.2189 - val_loss: 0.4778 - val_mean_absolute_error: 0.4265 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 49/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.8859 - dice_coeff: 0.1595 - loss: 0.5035 - mean_absolute_error: 0.4246 - mean_io_u_11: 0.4789 - precision_11: 0.2702 - recall_11: 0.9967
# Epoch 49: loss did not improve from 0.50668
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 419ms/step - accuracy: 0.8783 - dice_coeff: 0.1511 - loss: 0.5070 - mean_absolute_error: 0.4263 - mean_io_u_11: 0.4797 - precision_11: 0.2498 - recall_11: 0.9961 - val_accuracy: 0.8623 - val_dice_coeff: 0.2189 - val_loss: 0.4778 - val_mean_absolute_error: 0.4267 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 50/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.8719 - dice_coeff: 0.1445 - loss: 0.5137 - mean_absolute_error: 0.4297 - mean_io_u_11: 0.4812 - precision_11: 0.2264 - recall_11: 0.9949
# Epoch 50: loss did not improve from 0.50668
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 432ms/step - accuracy: 0.8758 - dice_coeff: 0.1564 - loss: 0.5075 - mean_absolute_error: 0.4269 - mean_io_u_11: 0.4797 - precision_11: 0.2459 - recall_11: 0.9966 - val_accuracy: 0.8623 - val_dice_coeff: 0.2189 - val_loss: 0.4777 - val_mean_absolute_error: 0.4268 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 51/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.8924 - dice_coeff: 0.1689 - loss: 0.4968 - mean_absolute_error: 0.4215 - mean_io_u_11: 0.4772 - precision_11: 0.2992 - recall_11: 0.9957
# Epoch 51: loss did not improve from 0.50668
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 424ms/step - accuracy: 0.8780 - dice_coeff: 0.1447 - loss: 0.5077 - mean_absolute_error: 0.4269 - mean_io_u_11: 0.4797 - precision_11: 0.2492 - recall_11: 0.9952 - val_accuracy: 0.8623 - val_dice_coeff: 0.2190 - val_loss: 0.4777 - val_mean_absolute_error: 0.4270 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 52/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.8612 - dice_coeff: 0.1268 - loss: 0.5262 - mean_absolute_error: 0.4356 - mean_io_u_11: 0.4841 - precision_11: 0.1888 - recall_11: 0.9981
# Epoch 52: loss did not improve from 0.50668
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 440ms/step - accuracy: 0.8783 - dice_coeff: 0.1633 - loss: 0.5088 - mean_absolute_error: 0.4275 - mean_io_u_11: 0.4797 - precision_11: 0.2495 - recall_11: 0.9946 - val_accuracy: 0.8623 - val_dice_coeff: 0.2190 - val_loss: 0.4777 - val_mean_absolute_error: 0.4273 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-08
# Epoch 53/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.8870 - dice_coeff: 0.1781 - loss: 0.4907 - mean_absolute_error: 0.4195 - mean_io_u_11: 0.4751 - precision_11: 0.3055 - recall_11: 0.9919
# Epoch 53: loss did not improve from 0.50668
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 433ms/step - accuracy: 0.8749 - dice_coeff: 0.1387 - loss: 0.5093 - mean_absolute_error: 0.4277 - mean_io_u_11: 0.4797 - precision_11: 0.2443 - recall_11: 0.9936 - val_accuracy: 0.8623 - val_dice_coeff: 0.2191 - val_loss: 0.4777 - val_mean_absolute_error: 0.4274 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-08
# Epoch 54/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.8673 - dice_coeff: 0.1420 - loss: 0.5161 - mean_absolute_error: 0.4307 - mean_io_u_11: 0.4818 - precision_11: 0.2159 - recall_11: 0.9978
# Epoch 54: loss did not improve from 0.50668
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 441ms/step - accuracy: 0.8793 - dice_coeff: 0.1606 - loss: 0.5075 - mean_absolute_error: 0.4266 - mean_io_u_11: 0.4797 - precision_11: 0.2512 - recall_11: 0.9958 - val_accuracy: 0.8623 - val_dice_coeff: 0.2191 - val_loss: 0.4777 - val_mean_absolute_error: 0.4276 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-08
# Epoch 55/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.8930 - dice_coeff: 0.1831 - loss: 0.4882 - mean_absolute_error: 0.4180 - mean_io_u_11: 0.4744 - precision_11: 0.3286 - recall_11: 0.9937
# Epoch 55: loss did not improve from 0.50668
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 435ms/step - accuracy: 0.8722 - dice_coeff: 0.1415 - loss: 0.5093 - mean_absolute_error: 0.4279 - mean_io_u_11: 0.4797 - precision_11: 0.2406 - recall_11: 0.9949 - val_accuracy: 0.8623 - val_dice_coeff: 0.2192 - val_loss: 0.4777 - val_mean_absolute_error: 0.4278 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-08
# Epoch 56/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.8698 - dice_coeff: 0.1385 - loss: 0.5159 - mean_absolute_error: 0.4308 - mean_io_u_11: 0.4814 - precision_11: 0.2233 - recall_11: 0.9962
# Epoch 56: loss did not improve from 0.50668
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 438ms/step - accuracy: 0.8756 - dice_coeff: 0.1469 - loss: 0.5089 - mean_absolute_error: 0.4276 - mean_io_u_11: 0.4797 - precision_11: 0.2455 - recall_11: 0.9947 - val_accuracy: 0.8623 - val_dice_coeff: 0.2192 - val_loss: 0.4777 - val_mean_absolute_error: 0.4279 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-08
# Epoch 57/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.8576 - dice_coeff: 0.1392 - loss: 0.5187 - mean_absolute_error: 0.4323 - mean_io_u_11: 0.4823 - precision_11: 0.1994 - recall_11: 0.9938
# Epoch 57: loss did not improve from 0.50668
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 435ms/step - accuracy: 0.8718 - dice_coeff: 0.1620 - loss: 0.5095 - mean_absolute_error: 0.4283 - mean_io_u_11: 0.4797 - precision_11: 0.2391 - recall_11: 0.9883 - val_accuracy: 0.8623 - val_dice_coeff: 0.2192 - val_loss: 0.4776 - val_mean_absolute_error: 0.4280 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-08
# Epoch 58/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.8750 - dice_coeff: 0.1361 - loss: 0.5202 - mean_absolute_error: 0.4326 - mean_io_u_11: 0.4827 - precision_11: 0.2157 - recall_11: 0.9953
# Epoch 58: loss did not improve from 0.50668
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 449ms/step - accuracy: 0.8781 - dice_coeff: 0.1622 - loss: 0.5085 - mean_absolute_error: 0.4273 - mean_io_u_11: 0.4797 - precision_11: 0.2493 - recall_11: 0.9949 - val_accuracy: 0.8623 - val_dice_coeff: 0.2193 - val_loss: 0.4776 - val_mean_absolute_error: 0.4282 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-08
# Epoch 59/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.8880 - dice_coeff: 0.1526 - loss: 0.5073 - mean_absolute_error: 0.4265 - mean_io_u_11: 0.4797 - precision_11: 0.2658 - recall_11: 0.9960
# Epoch 59: loss did not improve from 0.50668
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 431ms/step - accuracy: 0.8814 - dice_coeff: 0.1482 - loss: 0.5077 - mean_absolute_error: 0.4269 - mean_io_u_11: 0.4797 - precision_11: 0.2545 - recall_11: 0.9952 - val_accuracy: 0.8623 - val_dice_coeff: 0.2193 - val_loss: 0.4776 - val_mean_absolute_error: 0.4284 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-08
# Epoch 60/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.8728 - dice_coeff: 0.1386 - loss: 0.5169 - mean_absolute_error: 0.4312 - mean_io_u_11: 0.4819 - precision_11: 0.2227 - recall_11: 0.9963
# Epoch 60: loss did not improve from 0.50668
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 459ms/step - accuracy: 0.8798 - dice_coeff: 0.1536 - loss: 0.5080 - mean_absolute_error: 0.4270 - mean_io_u_11: 0.4797 - precision_11: 0.2519 - recall_11: 0.9951 - val_accuracy: 0.8623 - val_dice_coeff: 0.2194 - val_loss: 0.4776 - val_mean_absolute_error: 0.4286 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-08
# Epoch 61/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.8615 - dice_coeff: 0.1317 - loss: 0.5225 - mean_absolute_error: 0.4338 - mean_io_u_11: 0.4832 - precision_11: 0.1950 - recall_11: 0.9964
# Epoch 61: loss did not improve from 0.50668
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 437ms/step - accuracy: 0.8703 - dice_coeff: 0.1589 - loss: 0.5091 - mean_absolute_error: 0.4283 - mean_io_u_11: 0.4797 - precision_11: 0.2376 - recall_11: 0.9935 - val_accuracy: 0.8623 - val_dice_coeff: 0.2194 - val_loss: 0.4776 - val_mean_absolute_error: 0.4287 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-08
# Epoch 62/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.8876 - dice_coeff: 0.1593 - loss: 0.5055 - mean_absolute_error: 0.4255 - mean_io_u_11: 0.4793 - precision_11: 0.2707 - recall_11: 0.9978
# Epoch 62: loss did not improve from 0.50668
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 446ms/step - accuracy: 0.8849 - dice_coeff: 0.1598 - loss: 0.5072 - mean_absolute_error: 0.4262 - mean_io_u_11: 0.4797 - precision_11: 0.2605 - recall_11: 0.9979 - val_accuracy: 0.8623 - val_dice_coeff: 0.2195 - val_loss: 0.4776 - val_mean_absolute_error: 0.4289 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-09
# Epoch 63/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.8802 - dice_coeff: 0.1487 - loss: 0.5109 - mean_absolute_error: 0.4281 - mean_io_u_11: 0.4806 - precision_11: 0.2443 - recall_11: 0.9962
# Epoch 63: loss did not improve from 0.50668
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 437ms/step - accuracy: 0.8831 - dice_coeff: 0.1555 - loss: 0.5070 - mean_absolute_error: 0.4263 - mean_io_u_11: 0.4797 - precision_11: 0.2574 - recall_11: 0.9967 - val_accuracy: 0.8623 - val_dice_coeff: 0.2195 - val_loss: 0.4775 - val_mean_absolute_error: 0.4291 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-09
# Epoch 64/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.8803 - dice_coeff: 0.1588 - loss: 0.5053 - mean_absolute_error: 0.4262 - mean_io_u_11: 0.4790 - precision_11: 0.2621 - recall_11: 0.9954
# Epoch 64: loss did not improve from 0.50668
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 442ms/step - accuracy: 0.8726 - dice_coeff: 0.1559 - loss: 0.5081 - mean_absolute_error: 0.4276 - mean_io_u_11: 0.4797 - precision_11: 0.2413 - recall_11: 0.9958 - val_accuracy: 0.8623 - val_dice_coeff: 0.2195 - val_loss: 0.4775 - val_mean_absolute_error: 0.4292 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-09
# Epoch 65/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.8730 - dice_coeff: 0.1358 - loss: 0.5202 - mean_absolute_error: 0.4323 - mean_io_u_11: 0.4828 - precision_11: 0.2124 - recall_11: 0.9979
# Epoch 65: loss did not improve from 0.50668
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 437ms/step - accuracy: 0.8780 - dice_coeff: 0.1614 - loss: 0.5082 - mean_absolute_error: 0.4271 - mean_io_u_11: 0.4797 - precision_11: 0.2490 - recall_11: 0.9943 - val_accuracy: 0.8623 - val_dice_coeff: 0.2196 - val_loss: 0.4775 - val_mean_absolute_error: 0.4293 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-09
# Epoch 66/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.8708 - dice_coeff: 0.1563 - loss: 0.5060 - mean_absolute_error: 0.4267 - mean_io_u_11: 0.4792 - precision_11: 0.2428 - recall_11: 0.9934
# Epoch 66: loss did not improve from 0.50668
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 450ms/step - accuracy: 0.8757 - dice_coeff: 0.1528 - loss: 0.5077 - mean_absolute_error: 0.4273 - mean_io_u_11: 0.4797 - precision_11: 0.2455 - recall_11: 0.9942 - val_accuracy: 0.8623 - val_dice_coeff: 0.2196 - val_loss: 0.4775 - val_mean_absolute_error: 0.4295 - val_mean_io_u_11: 0.4312 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - learning_rate: 1.0000e-09
# Epoch 66: early stopping

# %% [markdown]
# # Evaluate the results

# %%
preds_train = model.predict(X_train[:int(X_train.shape[0]*(1-val_split))], verbose=1)
preds_x = model.predict(X_train, verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*(1-val_split)):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

gt_train = Y_train[:int(X_train.shape[0]*(1-val_split))].astype(np.float32)
gt_x = Y_train.astype(np.float32)
gt_val = Y_train[int(X_train.shape[0]*(1-val_split)):].astype(np.float32)
gt_test = Y_test.astype(np.float32)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 414ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 371ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 378ms/step

# %%
# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.float32)
preds_x_t = (preds_x > 0.5).astype(np.float32)
preds_val_t = (preds_val > 0.5).astype(np.float32)
preds_test_t = (preds_test > 0.5).astype(np.float32)

# %%
evalResult(gt_train, preds_train_t)
# Out:
# Accuracy= 0.9191301 Precision= 0.0 Recall= 0.0 MeanIoU= 0.45956504 DiceCoefficient= 0.15185519701416433 HD= 7.781250900099249 MyIoU= 0.0 MAE= 0.080869906

# %%
evalResult(gt_val, preds_val_t)
# Out:
# Accuracy= 0.9229087 Precision= 0.0 Recall= 0.0 MeanIoU= 0.46145436 DiceCoefficient= 0.16005210262651515 HD= 7.873824473409088 MyIoU= 0.0 MAE= 0.0770913

# %%
evalResult(gt_x, preds_x_t)
# Out:
# Accuracy= 0.92026854 Precision= 0.0 Recall= 0.0 MeanIoU= 0.46013427 DiceCoefficient= 0.15432477755121873 HD= 7.8091416561605405 MyIoU= 0.0 MAE= 0.07973148

# %%
evalResult(gt_test, preds_test_t)
# Out:
# Accuracy= 0.93308073 Precision= 0.0 Recall= 0.0 MeanIoU= 0.46654037 DiceCoefficient= 0.2376910116033683 HD= 6.805264635267055 MyIoU= 0.0 MAE= 0.066919275

# %% [markdown]
# # Output

# %%
x=0
xx = [115,10,15]
for i in range(3):
    plt.figure(figsize=(10,10))
    #ix = random.randint(0, len(preds_train))
    ix = xx[i]
    #print(ix)
    #ix = 58
    plt.subplot(3,3,x+1)
    imshow(X_train[:int(X_train.shape[0]*(1-val_split))][ix].astype('uint8'))
    #plt.title('Image')

    plt.subplot(3,3,x+2)
    imshow(np.squeeze(Y_train[:int(Y_train.shape[0]*(1-val_split))][ix]))
    #plt.title('Mask')

    plt.subplot(3,3,x+3)
    imshow(np.squeeze(preds_train_t[ix]))
    #plt.title('Predicted Mask')
    #plt.show()
    
    plt.show()
    evalResult(Y_train[:int(Y_train.shape[0]*(1-val_split))][ix], preds_train_t[ix])
    x = x+3
# Out:
# Accuracy= 0.9791107 Precision= 0.0 Recall= 0.0 MeanIoU= 0.48955536 DiceCoefficient= 0.8676389414613368 HD= 7.483314773547883 MyIoU= 0.0 MAE= 0.020889282
# Accuracy= 0.9113159 Precision= 0.0 Recall= 0.0 MeanIoU= 0.45565796 DiceCoefficient= 0.6079306298342999 HD= 8.660254037844387 MyIoU= 0.0 MAE= 0.08868408
# Accuracy= 0.93748474 Precision= 0.0 Recall= 0.0 MeanIoU= 0.46874237 DiceCoefficient= 0.7936963965403265 HD= 12.165525060596439 MyIoU= 0.0 MAE= 0.06251526

# %%
x=0
xx = [16,10,15]
for i in range(3):
    plt.figure(figsize=(10,10))
    #ix = random.randint(0, len(preds_train))
    ix = xx[i]
    #print(ix)
    #ix = 58
    plt.subplot(3,3,x+1)
    imshow(X_test[ix].astype('uint8'))
    #plt.title('Image')

    plt.subplot(3,3,x+2)
    imshow(np.squeeze(Y_test[ix]))
    #plt.title('Mask')

    plt.subplot(3,3,x+3)
    imshow(np.squeeze(preds_test_t[ix]))
    #plt.title('Predicted Mask')
    #plt.show()
    
    plt.show()
    evalResult(Y_test[ix], preds_test_t[ix])
    x = x+3
# Out:
# Accuracy= 0.99450684 Precision= 0.0 Recall= 0.0 MeanIoU= 0.49725342 DiceCoefficient= 0.933365909033455 HD= 5.0 MyIoU= 0.0 MAE= 0.005493164
# Accuracy= 0.950943 Precision= 0.0 Recall= 0.0 MeanIoU= 0.4754715 DiceCoefficient= 0.7180300443142187 HD= 7.681145747868608 MyIoU= 0.0 MAE= 0.049057007
# Accuracy= 0.98643494 Precision= 0.0 Recall= 0.0 MeanIoU= 0.49321747 DiceCoefficient= 0.8905224078553147 HD= 6.082762530298219 MyIoU= 0.0 MAE= 0.0135650635
